# %%
import numpy as np 
import matplotlib.pyplot as plt
from astropy.table import Table
import physics.read_mist_models as read_mist_models
# %matplotlib widget

# %%
# %ls
# Out:
#  Le volume dans le lecteur C n'a pas de nom.
#  Le num�ro de s�rie du volume est 2293-34C8
#
#  R�pertoire de c:\Users\antoi\Code\unif\MA2\thesis\notebooks\physics
#
# 24-11-25  15:52    <DIR>          .
# 19-11-25  14:22    <DIR>          ..
# 19-11-25  16:34         1.605.579 check_L_R.ipynb
# 24-11-25  16:38           168.083 compare_mist_parsec.ipynb
# 24-11-25  16:34         3.038.458 data_exploration.ipynb
# 24-11-25  14:54         2.913.336 MIST_data_checking.ipynb
# 23-11-25  16:41         1.942.434 MIST_data_exploration.ipynb
#                5 fichier(s)        9.667.890 octets
#                2 R�p(s)  150.934.855.680 octets libres

# %% [markdown]
# ## Read MIST isochrones

# %%
ifn_mist = '../../data/MIST_v1.2_vvcrit0.0_basic_isos/MIST_v1.2_feh_p0.00_afe_p0.0_vvcrit0.0_basic.iso'
t1 = read_mist_models.ISO(ifn_mist)
t1.hdr_list
print('version: ', t1.version)
print('abundances: ', t1.abun)
print('rotation: ', t1.rot)
print('ages: ', [round(x, 5) for x in t1.ages])
print('columns', t1.hdr_list)
# Out:
# Reading in: ../../data/MIST_v1.2_vvcrit0.0_basic_isos/MIST_v1.2_feh_p0.00_afe_p0.0_vvcrit0.0_basic.iso
# version:  {'MIST': '1.2', 'MESA': '7503'}
# abundances:  {'Yinit': 0.2703, 'Zinit': 0.0142857, '[Fe/H]': 0.0, '[a/Fe]': 0.0}
# rotation:  0.0
# ages:  [np.float64(5.0), np.float64(5.05), np.float64(5.1), np.float64(5.15), np.float64(5.2), np.float64(5.25), np.float64(5.3), np.float64(5.35), np.float64(5.4), np.float64(5.45), np.float64(5.5), np.float64(5.55), np.float64(5.6), np.float64(5.65), np.float64(5.7), np.float64(5.75), np.float64(5.8), np.float64(5.85), np.float64(5.9), np.float64(5.95), np.float64(6.0), np.float64(6.05), np.float64(6.1), np.float64(6.15), np.float64(6.2), np.float64(6.25), np.float64(6.3), np.float64(6.35), np.float64(6.4), np.float64(6.45), np.float64(6.5), np.float64(6.55), np.float64(6.6), np.float64(6.65), np.float64(6.7), np.float64(6.75), np.float64(6.8), np.float64(6.85), np.float64(6.9), np.float64(6.95), np.float64(7.0), np.float64(7.05), np.float64(7.1), np.float64(7.15), np.float64(7.2), np.float64(7.25), np.float64(7.3), np.float64(7.35), np.float64(7.4), np.float64(7.45), np.float64(7.5), np.float64(7.55), np.float64(7.6), np.float64(7.65), np.float64(7.7), np.float64(7.75), np.float64(7.8), np.float64(7.85), np.float64(7.9), np.float64(7.95), np.float64(8.0), np.float64(8.05), np.float64(8.1), np.float64(8.15), np.float64(8.2), np.float64(8.25), np.float64(8.3), np.float64(8.35), np.float64(8.4), np.float64(8.45), np.float64(8.5), np.float64(8.55), np.float64(8.6), np.float64(8.65), np.float64(8.7), np.float64(8.75), np.float64(8.8), np.float64(8.85), np.float64(8.9), np.float64(8.95), np.float64(9.0), np.float64(9.05), np.float64(9.1), np.float64(9.15), np.float64(9.2), np.float64(9.25), np.float64(9.3), np.float64(9.35), np.float64(9.4), np.float64(9.45), np.float64(9.5), np.float64(9.55), np.float64(9.6), np.float64(9.65), np.float64(9.7), np.float64(9.75), np.float64(9.8), np.float64(9.85), np.float64(9.9), np.float64(9.95), np.float64(10.0), np.float64(10.05), np.float64(10.1), np.float64(10.15), np.float64(10.2), np.float64(10.25), np.float64(10.3)]
# columns ['EEP', 'log10_isochrone_age_yr', 'initial_mass', 'star_mass', 'star_mdot', 'he_core_mass', 'c_core_mass', 'log_L', 'log_LH', 'log_LHe', 'log_Teff', 'log_R', 'log_g', 'surface_h1', 'surface_he3', 'surface_he4', 'surface_c12', 'surface_o16', 'log_center_T', 'log_center_Rho', 'center_gamma', 'center_h1', 'center_he4', 'center_c12', 'phase']

# %% [markdown]
# ## Read Parsec isochrones

# %%
ifn_parsec = '../../data/PARSEC/old_data/output_diff_check.dat'
ifn_2_parsec = '../../data/PARSEC/PARSEC_feh_p0.00.dat'
t2 = Table.read(ifn_parsec, format='ascii')
print(t2.colnames)
print('ages:',[round(x, 5) for x in sorted(set(t2['logAge']))])
display(t2[:100])
t3 = Table.read(ifn_2_parsec, format='ascii')
print('ages:',[round(x, 5) for x in sorted(set(t3['logAge']))])
display(t3[:100])
# Out:
# ['Zini', 'MH', 'logAge', 'Mini', 'int_IMF', 'Mass', 'logL', 'logTe', 'logg', 'label', 'McoreTP', 'C_O', 'period0', 'period1', 'period2', 'period3', 'period4', 'pmode', 'Mloss', 'tau1m', 'X', 'Y', 'Xc', 'Xn', 'Xo', 'Cexcess', 'Z', 'Teff0', 'omega', 'angvel', 'vtaneq', 'angmom', 'Rpol', 'Req', 'mbolmag', 'G_fSBmag', 'G_BP_fSBmag', 'G_RP_fSBmag', 'G_fSB', 'G_f0', 'G_fk', 'G_i00', 'G_i05', 'G_i10', 'G_i15', 'G_i20', 'G_i25', 'G_i30', 'G_i35', 'G_i40', 'G_i45', 'G_i50', 'G_i55', 'G_i60', 'G_i65', 'G_i70', 'G_i75', 'G_i80', 'G_i85', 'G_i90', 'G_BP_fSB', 'G_BP_f0', 'G_BP_fk', 'G_BP_i00', 'G_BP_i05', 'G_BP_i10', 'G_BP_i15', 'G_BP_i20', 'G_BP_i25', 'G_BP_i30', 'G_BP_i35', 'G_BP_i40', 'G_BP_i45', 'G_BP_i50', 'G_BP_i55', 'G_BP_i60', 'G_BP_i65', 'G_BP_i70', 'G_BP_i75', 'G_BP_i80', 'G_BP_i85', 'G_BP_i90', 'G_RP_fSB', 'G_RP_f0', 'G_RP_fk', 'G_RP_i00', 'G_RP_i05', 'G_RP_i10', 'G_RP_i15', 'G_RP_i20', 'G_RP_i25', 'G_RP_i30', 'G_RP_i35', 'G_RP_i40', 'G_RP_i45', 'G_RP_i50', 'G_RP_i55', 'G_RP_i60', 'G_RP_i65', 'G_RP_i70', 'G_RP_i75', 'G_RP_i80', 'G_RP_i85', 'G_RP_i90']
# float64 float64 float64   float64    ... float64 float64 float64 float64
# ------- ------- ------- ------------ ... ------- ------- ------- -------
# 0.01471     0.0     5.0 0.0900000036 ...   3.714   3.714   3.714   3.714
# 0.01471     0.0     5.0 0.0947237387 ...   3.626   3.626   3.626   3.626
# 0.01471     0.0     5.0 0.1000000015 ...   3.531   3.531   3.531   3.531
# 0.01471     0.0     5.0 0.1026951447 ...   3.485   3.485   3.485   3.485
# 0.01471     0.0     5.0 0.1087392494 ...   3.386   3.386   3.386   3.386
# 0.01471     0.0     5.0 0.1181974486 ...   3.241   3.241   3.241   3.241
# 0.01471     0.0     5.0 0.1200000048 ...   3.215   3.215   3.215   3.215
# 0.01471     0.0     5.0 0.1267423481 ...   3.121   3.121   3.121   3.121
# 0.01471     0.0     5.0  0.136525318 ...   2.994   2.994   2.994   2.994
#     ...     ...     ...          ... ...     ...     ...     ...     ...
# 0.01471     0.0     5.0 2.1960301399 ...  -1.163  -1.163  -1.163  -1.163
# 0.01471     0.0     5.0 2.2000000477 ...  -1.156  -1.156  -1.156  -1.156
# 0.01471     0.0     5.0  2.341889143 ...  -1.239  -1.239  -1.239  -1.239
# 0.01471     0.0     5.0 2.4000000954 ...  -1.274  -1.274  -1.274  -1.274
# 0.01471     0.0     5.0 2.5169420242 ...  -1.339  -1.339  -1.339  -1.339
# 0.01471     0.0     5.0 2.5999999046 ...  -1.384  -1.384  -1.384  -1.384
# 0.01471     0.0     5.0  2.716324091 ...  -1.448  -1.448  -1.448  -1.448
# 0.01471     0.0     5.0 2.7999999523 ...  -1.512  -1.512  -1.512  -1.512
# 0.01471     0.0     5.0 2.9813911915 ...  -1.656  -1.656  -1.656  -1.656
# 0.01471     0.0     5.0          3.0 ...  -1.669  -1.669  -1.669  -1.669

# %%
# f_1 = '../../data/PARSEC/PARSEC_feh_p0.50.dat'
# t1 = Table.read(f_1, format='ascii')
# f_2 = '../../data/PARSEC/PARSEC_feh_p0.25.dat'
# t2 = Table.read(f_2, format='ascii')
# f_3 = '../../data/PARSEC/PARSEC_feh_p0.00.dat'
# t3 = Table.read(f_3, format='ascii')
# print(t1.colnames)
# print(t2.colnames)
# print(t3.colnames)
# Out:
# ['Zini', 'MH', 'logAge', 'Mini', 'int_IMF', 'Mass', 'logL', 'logTe', 'logg', 'label', 'McoreTP', 'C_O', 'period0', 'period1', 'period2', 'period3', 'period4', 'pmode', 'Mloss', 'tau1m', 'X', 'Y', 'Xc', 'Xn', 'Xo', 'Cexcess', 'Z', 'Teff0', 'omega', 'angvel', 'vtaneq', 'angmom', 'Rpol', 'Req', 'mbolmag', 'U_fSBmag', 'B_fSBmag', 'V_fSBmag', 'R_fSBmag', 'I_fSBmag', 'J_fSBmag', 'H_fSBmag', 'K_fSBmag', 'U_fSB', 'U_f0', 'U_fk', 'U_i00', 'U_i05', 'U_i10', 'U_i15', 'U_i20', 'U_i25', 'U_i30', 'U_i35', 'U_i40', 'U_i45', 'U_i50', 'U_i55', 'U_i60', 'U_i65', 'U_i70', 'U_i75', 'U_i80', 'U_i85', 'U_i90', 'B_fSB', 'B_f0', 'B_fk', 'B_i00', 'B_i05', 'B_i10', 'B_i15', 'B_i20', 'B_i25', 'B_i30', 'B_i35', 'B_i40', 'B_i45', 'B_i50', 'B_i55', 'B_i60', 'B_i65', 'B_i70', 'B_i75', 'B_i80', 'B_i85', 'B_i90', 'V_fSB', 'V_f0', 'V_fk', 'V_i00', 'V_i05', 'V_i10', 'V_i15', 'V_i20', 'V_i25', 'V_i30', 'V_i35', 'V_i40', 'V_i45', 'V_i50', 'V_i55', 'V_i60', 'V_i65', 'V_i70', 'V_i75', 'V_i80', 'V_i85', 'V_i90', 'R_fSB', 'R_f0', 'R_fk', 'R_i00', 'R_i05', 'R_i10', 'R_i15', 'R_i20', 'R_i25', 'R_i30', 'R_i35', 'R_i40', 'R_i45', 'R_i50', 'R_i55', 'R_i60', 'R_i65', 'R_i70', 'R_i75', 'R_i80', 'R_i85', 'R_i90', 'I_fSB', 'I_f0', 'I_fk', 'I_i00', 'I_i05', 'I_i10', 'I_i15', 'I_i20', 'I_i25', 'I_i30', 'I_i35', 'I_i40', 'I_i45', 'I_i50', 'I_i55', 'I_i60', 'I_i65', 'I_i70', 'I_i75', 'I_i80', 'I_i85', 'I_i90', 'J_fSB', 'J_f0', 'J_fk', 'J_i00', 'J_i05', 'J_i10', 'J_i15', 'J_i20', 'J_i25', 'J_i30', 'J_i35', 'J_i40', 'J_i45', 'J_i50', 'J_i55', 'J_i60', 'J_i65', 'J_i70', 'J_i75', 'J_i80', 'J_i85', 'J_i90', 'H_fSB', 'H_f0', 'H_fk', 'H_i00', 'H_i05', 'H_i10', 'H_i15', 'H_i20', 'H_i25', 'H_i30', 'H_i35', 'H_i40', 'H_i45', 'H_i50', 'H_i55', 'H_i60', 'H_i65', 'H_i70', 'H_i75', 'H_i80', 'H_i85', 'H_i90', 'K_fSB', 'K_f0', 'K_fk', 'K_i00', 'K_i05', 'K_i10', 'K_i15', 'K_i20', 'K_i25', 'K_i30', 'K_i35', 'K_i40', 'K_i45', 'K_i50', 'K_i55', 'K_i60', 'K_i65', 'K_i70', 'K_i75', 'K_i80', 'K_i85', 'K_i90']
# ['Zini', 'MH', 'logAge', 'Mini', 'int_IMF', 'Mass', 'logL', 'logTe', 'logg', 'label', 'McoreTP', 'C_O', 'period0', 'period1', 'period2', 'period3', 'period4', 'pmode', 'Mloss', 'tau1m', 'X', 'Y', 'Xc', 'Xn', 'Xo', 'Cexcess', 'Z', 'Teff0', 'omega', 'angvel', 'vtaneq', 'angmom', 'Rpol', 'Req', 'mbolmag', 'U_fSBmag', 'B_fSBmag', 'V_fSBmag', 'R_fSBmag', 'I_fSBmag', 'J_fSBmag', 'H_fSBmag', 'K_fSBmag', 'U_fSB', 'U_f0', 'U_fk', 'U_i00', 'U_i05', 'U_i10', 'U_i15', 'U_i20', 'U_i25', 'U_i30', 'U_i35', 'U_i40', 'U_i45', 'U_i50', 'U_i55', 'U_i60', 'U_i65', 'U_i70', 'U_i75', 'U_i80', 'U_i85', 'U_i90', 'B_fSB', 'B_f0', 'B_fk', 'B_i00', 'B_i05', 'B_i10', 'B_i15', 'B_i20', 'B_i25', 'B_i30', 'B_i35', 'B_i40', 'B_i45', 'B_i50', 'B_i55', 'B_i60', 'B_i65', 'B_i70', 'B_i75', 'B_i80', 'B_i85', 'B_i90', 'V_fSB', 'V_f0', 'V_fk', 'V_i00', 'V_i05', 'V_i10', 'V_i15', 'V_i20', 'V_i25', 'V_i30', 'V_i35', 'V_i40', 'V_i45', 'V_i50', 'V_i55', 'V_i60', 'V_i65', 'V_i70', 'V_i75', 'V_i80', 'V_i85', 'V_i90', 'R_fSB', 'R_f0', 'R_fk', 'R_i00', 'R_i05', 'R_i10', 'R_i15', 'R_i20', 'R_i25', 'R_i30', 'R_i35', 'R_i40', 'R_i45', 'R_i50', 'R_i55', 'R_i60', 'R_i65', 'R_i70', 'R_i75', 'R_i80', 'R_i85', 'R_i90', 'I_fSB', 'I_f0', 'I_fk', 'I_i00', 'I_i05', 'I_i10', 'I_i15', 'I_i20', 'I_i25', 'I_i30', 'I_i35', 'I_i40', 'I_i45', 'I_i50', 'I_i55', 'I_i60', 'I_i65', 'I_i70', 'I_i75', 'I_i80', 'I_i85', 'I_i90', 'J_fSB', 'J_f0', 'J_fk', 'J_i00', 'J_i05', 'J_i10', 'J_i15', 'J_i20', 'J_i25', 'J_i30', 'J_i35', 'J_i40', 'J_i45', 'J_i50', 'J_i55', 'J_i60', 'J_i65', 'J_i70', 'J_i75', 'J_i80', 'J_i85', 'J_i90', 'H_fSB', 'H_f0', 'H_fk', 'H_i00', 'H_i05', 'H_i10', 'H_i15', 'H_i20', 'H_i25', 'H_i30', 'H_i35', 'H_i40', 'H_i45', 'H_i50', 'H_i55', 'H_i60', 'H_i65', 'H_i70', 'H_i75', 'H_i80', 'H_i85', 'H_i90', 'K_fSB', 'K_f0', 'K_fk', 'K_i00', 'K_i05', 'K_i10', 'K_i15', 'K_i20', 'K_i25', 'K_i30', 'K_i35', 'K_i40', 'K_i45', 'K_i50', 'K_i55', 'K_i60', 'K_i65', 'K_i70', 'K_i75', 'K_i80', 'K_i85', 'K_i90']
# ['Zini', 'MH', 'logAge', 'Mini', 'int_IMF', 'Mass', 'logL', 'logTe', 'logg', 'label', 'McoreTP', 'C_O', 'period0', 'period1', 'period2', 'period3', 'period4', 'pmode', 'Mloss', 'tau1m', 'X', 'Y', 'Xc', 'Xn', 'Xo', 'Cexcess', 'Z', 'Teff0', 'omega', 'angvel', 'vtaneq', 'angmom', 'Rpol', 'Req', 'mbolmag', 'U_fSBmag', 'B_fSBmag', 'V_fSBmag', 'R_fSBmag', 'I_fSBmag', 'J_fSBmag', 'H_fSBmag', 'K_fSBmag', 'U_fSB', 'U_f0', 'U_fk', 'U_i00', 'U_i05', 'U_i10', 'U_i15', 'U_i20', 'U_i25', 'U_i30', 'U_i35', 'U_i40', 'U_i45', 'U_i50', 'U_i55', 'U_i60', 'U_i65', 'U_i70', 'U_i75', 'U_i80', 'U_i85', 'U_i90', 'B_fSB', 'B_f0', 'B_fk', 'B_i00', 'B_i05', 'B_i10', 'B_i15', 'B_i20', 'B_i25', 'B_i30', 'B_i35', 'B_i40', 'B_i45', 'B_i50', 'B_i55', 'B_i60', 'B_i65', 'B_i70', 'B_i75', 'B_i80', 'B_i85', 'B_i90', 'V_fSB', 'V_f0', 'V_fk', 'V_i00', 'V_i05', 'V_i10', 'V_i15', 'V_i20', 'V_i25', 'V_i30', 'V_i35', 'V_i40', 'V_i45', 'V_i50', 'V_i55', 'V_i60', 'V_i65', 'V_i70', 'V_i75', 'V_i80', 'V_i85', 'V_i90', 'R_fSB', 'R_f0', 'R_fk', 'R_i00', 'R_i05', 'R_i10', 'R_i15', 'R_i20', 'R_i25', 'R_i30', 'R_i35', 'R_i40', 'R_i45', 'R_i50', 'R_i55', 'R_i60', 'R_i65', 'R_i70', 'R_i75', 'R_i80', 'R_i85', 'R_i90', 'I_fSB', 'I_f0', 'I_fk', 'I_i00', 'I_i05', 'I_i10', 'I_i15', 'I_i20', 'I_i25', 'I_i30', 'I_i35', 'I_i40', 'I_i45', 'I_i50', 'I_i55', 'I_i60', 'I_i65', 'I_i70', 'I_i75', 'I_i80', 'I_i85', 'I_i90', 'J_fSB', 'J_f0', 'J_fk', 'J_i00', 'J_i05', 'J_i10', 'J_i15', 'J_i20', 'J_i25', 'J_i30', 'J_i35', 'J_i40', 'J_i45', 'J_i50', 'J_i55', 'J_i60', 'J_i65', 'J_i70', 'J_i75', 'J_i80', 'J_i85', 'J_i90', 'H_fSB', 'H_f0', 'H_fk', 'H_i00', 'H_i05', 'H_i10', 'H_i15', 'H_i20', 'H_i25', 'H_i30', 'H_i35', 'H_i40', 'H_i45', 'H_i50', 'H_i55', 'H_i60', 'H_i65', 'H_i70', 'H_i75', 'H_i80', 'H_i85', 'H_i90', 'K_fSB', 'K_f0', 'K_fk', 'K_i00', 'K_i05', 'K_i10', 'K_i15', 'K_i20', 'K_i25', 'K_i30', 'K_i35', 'K_i40', 'K_i45', 'K_i50', 'K_i55', 'K_i60', 'K_i65', 'K_i70', 'K_i75', 'K_i80', 'K_i85', 'K_i90']

# %% [markdown]
# ## Compare isochrones

# %%
plt.close()
plt.rc('font', size=14)
plt.figure(1, figsize=(8, 6), tight_layout=True)

#Specify one or more ages
ages = [9.65]

#MIST
for age in ages: #age is in log scale
    i = t1.age_index(age) #returns the index for the desired age
    x = 10**t1.isos[i]['log_Teff']
    y = 10**t1.isos[i]['log_L']
    z = 10**t1.isos[i]['log_R']
    plt.scatter(x, y, s=z, color='b', lw=1, alpha=0.2,label='MIST')

#Parsec
#for age in list(set(t2['logAge']))[:2]:
for age in ages:
    m = abs(t2['logAge'] - age) < 0.02
    x = 10**t2[m]['logTe']
    y = 10**t2[m]['logL']
    z = t2[m]['Rpol']
    plt.scatter(x, y, s=z, color='r', lw=1, alpha=0.2,label='Parsec')    
    
plt.gca().invert_xaxis()
plt.xscale('log')
plt.yscale('log')
plt.xlabel('$T_\\mathrm{eff}$ [K]')
plt.ylabel('$L$ [L$_\\odot$]')
plt.legend(loc=3)
# plt.title(f'Isochrone at [Fe/H]={t1.abun["[Fe/H]"]}, age = {10**t1.ages[i]/1e9:4.2f} Ga')
plt.xlim(8e3, 2e3)
plt.savefig("C:/Users/antoi/Code/unif/MA2/thesis/img/mes_images/diff_MIST_PARSEC.pdf", format="pdf")
# plt.savefig("C:/Users/antoi/Code/unif/MA2/Thèse/img/mes_images/diff_MIST_PARSEC_titre.pdf", format="pdf")
plt.show()

print(f'MIST:   Zinit = {t1.abun["Zinit"]}')
print(f'Parsec: Zinit = {t2["Zini"][0]}')

print(f'MIST:   log age = {t1.ages[i]}, age = {10**t1.ages[i]/1e9} Ga')
print(f'Parsec: log age = {t2[m]["logAge"][0]}, age = {10**t2[m]["logAge"][0]/1e9} Ga')
# Out:
#       logAge
# ------------------
#              -4.65
#              -4.65
#              -4.65
#              -4.65
#              -4.65
#              -4.65
#              -4.65
#              -4.65
#              -4.65
#              -4.65
#                ...
# 0.6000199999999989
# 0.6000199999999989
# 0.6000199999999989
# 0.6000199999999989
# 0.6000199999999989
# 0.6000199999999989
# 0.6000199999999989
# 0.6000199999999989
# 0.6000199999999989
# 0.6000199999999989
# Length = 51570 rows
# [False False False ... False False False]
# MIST:   Zinit = 0.0142857
# Parsec: Zinit = 0.0142
# MIST:   log age = 9.650000000000002, age = 4.466835921509653 Ga
# Parsec: log age = 9.65002, age = 4.467041631642356 Ga

# %%
plt.close()
plt.rc('font', size=14)
plt.figure(1, figsize=(8, 6), tight_layout=True)

#Specify one or more ages
ages = [9.65]

#MIST
for age in ages: #age is in log scale
    i = t1.age_index(age) #returns the index for the desired age
    x = 10**t1.isos[i]['log_Teff']
    y = 10**t1.isos[i]['log_L']
    z = 10**t1.isos[i]['log_R']
    plt.scatter(x, y, s=z, color='b', lw=1, alpha=0.2,label='MIST')

#Parsec
#for age in list(set(t2['logAge']))[:2]:
for age in ages:
    m = abs(t3['logAge'] - age) < 0.02
    x = 10**t3[m]['logTe']
    y = 10**t3[m]['logL']
    z = t3[m]['Rpol']
    plt.scatter(x, y, s=z, color='r', lw=1, alpha=0.2,label='Parsec')    
    
plt.gca().invert_xaxis()
plt.xscale('log')
plt.yscale('log')
plt.xlabel('$T_\\mathrm{eff}$ [K]')
plt.ylabel('$L$ [L$_\\odot$]')
plt.legend(loc=3)
# plt.title(f'Isochrone at [Fe/H]={t1.abun["[Fe/H]"]}, age = {10**t1.ages[i]/1e9:4.2f} Ga')
plt.xlim(8e3, 2e3)
plt.savefig("C:/Users/antoi/Code/unif/MA2/thesis/img/mes_images/diff_MIST_PARSEC_v2.pdf", format="pdf")
# plt.savefig("C:/Users/antoi/Code/unif/MA2/Thèse/img/mes_images/diff_MIST_PARSEC_titre.pdf", format="pdf")
plt.show()

print(f'MIST:   Zinit = {t1.abun["Zinit"]}')
print(f'Parsec: Zinit = {t3["Zini"][0]}')

print(f'MIST:   log age = {t1.ages[i]}, age = {10**t1.ages[i]/1e9} Ga')
print(f'Parsec: log age = {t3[m]["logAge"][0]}, age = {10**t3[m]["logAge"][0]/1e9} Ga')
# Out:
# MIST:   Zinit = 0.0142857
# Parsec: Zinit = 0.01471
# MIST:   log age = 9.650000000000002, age = 4.466835921509653 Ga
# Parsec: log age = 9.65002, age = 4.467041631642356 Ga
