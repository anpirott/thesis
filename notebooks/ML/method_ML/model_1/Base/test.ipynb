# %%
import sys, os
print(sys.executable)
print(sys.path) # TODO régler le problème de path
print("In module products sys.path[0], __package__ ==", sys.path[0], __package__) # TODO régler le problème de path
# Out:
# c:\Users\antoi\Code\unif\MA2\thesis\.venv\Scripts\python.exe
# ['C:\\Users\\antoi\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'C:\\Users\\antoi\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'C:\\Users\\antoi\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'C:\\Users\\antoi\\AppData\\Local\\Programs\\Python\\Python312', 'c:\\Users\\antoi\\Code\\unif\\MA2\\thesis\\.venv', '', 'c:\\Users\\antoi\\Code\\unif\\MA2\\thesis\\.venv\\Lib\\site-packages', 'c:\\Users\\antoi\\Code\\unif\\MA2\\thesis\\src']
# In module products sys.path[0], __package__ == C:\Users\antoi\AppData\Local\Programs\Python\Python312\python312.zip None

# %%
import os
print(os.getcwd())
os.chdir(r"c:\Users\antoi\Code\unif\MA2\Thèse") 
print(os.getcwd())
# Out:
# c:\Users\antoi\Code\unif\MA2\Thèse\notebooks\ML\method_ML\model_1\Base
# c:\Users\antoi\Code\unif\MA2\Thèse

# %%
print(os.listdir("."))
print(os.listdir("./src"))
# Out:
# ['.git', '.gitignore', '.ipynb_checkpoints', 'data', 'img', 'model', 'notebooks', 'predictions', 'results', 'src', 'Thèse.code-workspace', '__init__.py', '__pycache__']
# ['ML', 'physics', '__init__.py', '__pycache__']

# %%
from ML.utils.utils import *
from ML.utils.Iso_data_handler import Iso_data_handler
from ML.utils.Data_preparator import Data_preparator
from ML.utils.Model_trainer import Model_trainer
from ML.utils.Model_evaluator import Model_evaluator
