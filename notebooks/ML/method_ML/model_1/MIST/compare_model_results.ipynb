# %% [markdown]
# # Results comparison for MIST filtering
#
# In this notebook, I will compare the results of the different models relative to how the data was filtered (only the MIST dataset).
#
# I will first look at how the filter on one value affected the other (if it didn't affect it, I will not write it) and then see how it affected the results of each model.

# %%
from ML.utils.utils import *

# %%
compare_metrics(r"C:\Users\antoi\Code\unif\MA2\thesis\results\K_fold", 
                output_parameters=["mass"], # output_parameters=["radius"],
                model_names=["decision_tree"],
                physical_models=["MIST"])
# Out:
#                                                                                         RVE  \
# model         physical_model filter                    output_parameter
# decision_tree MIST           age_filtered_bigger_7     mass               0.998835068792301
#                              age_filtered_smaller_9    mass              0.9947650018373563
#                              Base                      mass              0.9953484609461924
#                              log_g_filtered_bigger_1   mass               0.994764176138865
#                              log_g_filtered_bigger_3_5 mass              0.9922359015469233
#                              log_g_filtered_smaller_4  mass              0.9956958669362931
#                              mass_filtered_smaller_3   mass              0.9863740441698512
#                              mass_filtered_smaller_30  mass              0.9991056984251273
# ...

# %%
# TODO rajouter un plot qui montre plus en détail les hautes erreurs (jsp comment : les pourcentiles?, un cut sur les données pour voir les X plus grandes?, ...)
# TODO faire un plot qui montre l'erreur proportionnelement à la valeur qu'il fallait prédire

# %% [markdown]
# ## Base vs log_g_filtered

# %% [markdown]
# | Parameter      | Base                 | log_g_filtered_bigger_1 | log_g_filtered_smaller_3_5 | log_g_filtered_smaller_4 |
# | -------------  | -------------------- | ----------------------- | -------------------------- | ------------------------ |
# | age            | Range : 5.0 - 10.3 , Mean : 8.4657, Median : 8.55 | Range : 5.0 - 10.3 , Mean : 8.17641, Median : 8.25 | Range : 5.0 - 10.3 , Mean : 7.9558, Median : 8.0 | Range : 5.0 - 10.3 , Mean : 8.6342, Median : 8.7000 |
# | mass           | Range : 0.1000 - 298.5448, Mean : 7.5368, Median : 2.0818 | Range : 0.1000 - 298.5448, Mean : 10.7931, Median : 2.7211 | Range : 0.1000 - 298.5448, Mean : 9.6914, Median : 2.6440 | Range : 0.5087 - 296.5221, Mean : 7.3194, Median : 2.1036 |
# | log_teff       | Range : 3.3447 - 5.3788, Mean : 3.8298, Median : 3.6739 | Range : 3.3447 - 5.3788, Mean : 4.0163, Median : 3.9477 | Range : 3.3446 - 5.3788, Mean : 4.1227, Median : 4.1336 | Range : 3.3491 - 4.8081, Mean : 3.7429, Median : 3.6278 |
# | log_g          | Range : -1.1448 - 6.2594, Mean : 2.0665, Median : 2.0050 | Range : 1.0000 - 6.2594, Mean : 3.4433, Median : 3.7207 | Range : 3.5000 - 6.2594, Mean : 4.3511, Median : 4.3919 | Range : -1.1449 - 4.0000, Mean : 1.2311, Median : 0.6911 |
# | log_R          | Range : -0.9974 - 3.1298, Mean : 1.3949, Median : 1.5001 | Range : -0.9975 - 2.7462, Mean : 0.7586, Median : 0.7711 | Range : -0.9975 - 1.6971, Mean : 0.2781, Median : 0.2818 | Range : 0.1323 - 3.1298, Mean : 1.8212, Median : 2.0094 |

# %% [markdown]
# ### Mass parameter

# %%
compare_metrics(r"C:\Users\antoi\Code\unif\MA2\thesis\results\K_fold", 
                output_parameters=["mass"],
                physical_models=["MIST"],
                data_filters=["Base", "log_g_filtered_bigger_1", "log_g_filtered_bigger_3_5", "log_g_filtered_smaller_4"])
# Out:
#                                                                                              RVE  \
# model             physical_model filter                    output_parameter
# decision_tree     MIST           Base                      mass               0.9953484609461924
#                                  log_g_filtered_bigger_1   mass                0.994764176138865
#                                  log_g_filtered_bigger_3_5 mass               0.9922359015469233
#                                  log_g_filtered_smaller_4  mass               0.9956958669362931
# KNN               MIST           Base                      mass               0.9904012013411723
#                                  log_g_filtered_bigger_1   mass               0.9897472491155987
#                                  log_g_filtered_bigger_3_5 mass               0.9831652426689707
#                                  log_g_filtered_smaller_4  mass               0.9942848014119788
# ...

# %% [markdown]
# Linear regression :
# - log_g_filtered_bigger_1 : worse results than Base almost everywhere
# - log_g_filtered_bigger_3_5 : worse results than Base almost everywhere
# - log_g_filtered_smaller_4 : better results than Base almost everywhere
#
# Decision tree :
# - log_g_filtered_bigger_1 : similar results as Base almost everywhere, slightly better results until between the 90th and 95th percentile but worse results after
# - log_g_filtered_bigger_3_5 : similar results as Base almost everywhere, slightly better results until between the 90th and 95th percentile but worse results after
# - log_g_filtered_smaller_4 : similar results as Base almost everywhere, better results especially after 95th percentile
#
# KNN :
# - log_g_filtered_bigger_1 : similar results as Base almost everywhere, slightly better results until between the 90th and 95th percentile but worse results after
# - log_g_filtered_bigger_3_5 : similar results as Base almost everywhere, slightly better results until between the 90th and 95th percentile but worse results after
# - log_g_filtered_smaller_4 : similar results as Base almost everywhere, better results especially after 95th percentile
#
# Random forest :
# - log_g_filtered_bigger_1 : similar results as Base almost everywhere, slightly better results until between the 90th and 95th percentile but worse results after
# - log_g_filtered_bigger_3_5 : similar results as Base almost everywhere, slightly better results until between the 90th and 95th percentile but worse results after
# - log_g_filtered_smaller_4 : similar results as Base almost everywhere, better results especially after 95th percentile
#
# XGBoost :
# - log_g_filtered_bigger_1 : slightly worse results than Base almost everywhere
# - log_g_filtered_bigger_3_5 : similar results as Base almost everywhere, slightly better results until between the 90th and 95th percentile but worse results after
# - log_g_filtered_smaller_4 : slightly better results than Base everywhere except for MAX_ER
#
# MLP :
# - log_g_filtered_bigger_1 : slightly worse results than Base almost everywhere
# - log_g_filtered_bigger_3_5 : slightly better results than Base almost everywhere
# - log_g_filtered_smaller_4 : better results than Base everywhere

# %% [markdown]
# #### Conclusions on mass
#
# When filtering on the log_g by removing the values which are smaller than 1, the models predict better when below a point between the 90th and 95th percentile.
#
# &emsp; It has a worse RMSE in every model except MLP and a worse MAE in every model. But it has a better MedAE, percentiles 75 and 90 and smaller MAX_ER. => More big errors in the top 1 percentile but still maximum smaller.
#
# &emsp; => using this filter does not have much importance, might be better for some parts but having bigger errors in the outilers more often is not good for consistency.
#
#
# When filtering on the log_g by removing the values which are smaller than 3.5, the results are very similar to removing the values smaller than 1.
#
# &emsp; Same conclusion as above
#
#
# When filtering on the log_g by removing the values which are bigger than 4, the models mostly have better results than the base data.
#
# &emsp; => using this filter might be beneficial.

# %% [markdown]
# ### Radius parameter

# %%
compare_metrics(r"C:\Users\antoi\Code\unif\MA2\thesis\results\K_fold", 
                output_parameters=["radius"],
                physical_models=["MIST"],
                data_filters=["Base", "log_g_filtered_bigger_1", "log_g_filtered_bigger_3_5", "log_g_filtered_smaller_4"])
# Out:
#                                                                                             RVE  \
# model             physical_model filter                    output_parameter
# decision_tree     MIST           Base                      radius            0.9997899702074513
#                                  log_g_filtered_bigger_1   radius            0.9997904656760503
#                                  log_g_filtered_bigger_3_5 radius            0.9996932354309226
#                                  log_g_filtered_smaller_4  radius            0.9994516958544845
# KNN               MIST           Base                      radius             0.999833901666557
#                                  log_g_filtered_bigger_1   radius             0.999903078245907
#                                  log_g_filtered_bigger_3_5 radius            0.9997652821560189
#                                  log_g_filtered_smaller_4  radius            0.9995800993085868
# ...

# %% [markdown]
# Linear regression :
# - log_g_filtered_bigger_1 : slighlty better results than Base almost everywhere
# - log_g_filtered_bigger_3_5 : slighlty better results than Base almost everywhere
# - log_g_filtered_smaller_4 : slighlty better results than Base almost everywhere
#
# Decision tree :
# - log_g_filtered_bigger_1 : slighlty better results than Base everywhere
# - log_g_filtered_bigger_3_5 : better results than Base everywhere
# - log_g_filtered_smaller_4 : slighlty worse results than Base almost everywhere
#
# KNN :
# - log_g_filtered_bigger_1 : better results than Base everywhere
# - log_g_filtered_bigger_3_5 : better results than Base everywhere
# - log_g_filtered_smaller_4 : slighlty worse results than Base almost everywhere
#
# Random forest :
# - log_g_filtered_bigger_1 : better results than Base everywhere
# - log_g_filtered_bigger_3_5 : better results than Base everywhere
# - log_g_filtered_smaller_4 : slighlty worse results than Base almost everywhere
#
# XGBoost :
# - log_g_filtered_bigger_1 : slighlty better results than Base everywhere
# - log_g_filtered_bigger_3_5 : better results than Base everywhere
# - log_g_filtered_smaller_4 : similar results as Base everywhere
#
# MLP :
# - log_g_filtered_bigger_1 : slighlty worse results than Base everywhere
# - log_g_filtered_bigger_3_5 : slighlty worse results than Base everywhere
# - log_g_filtered_smaller_4 : slighlty worse results than Base everywhere

# %% [markdown]
# #### Conclusions on radius
#
# When using log_g_filtered_bigger_1 and log_g_filtered_bigger_3_5, almost all models have better results.
#
# When using log_g_filtered_smaller_4, almost all models have worse results.
#
# &emsp; => Might be interesting to use log_g_filtered_bigger_1 or log_g_filtered_bigger_3_5.

# %% [markdown]
# ### Conclusion on both
#
# The improvements in the results are opposite; better results for mass when using log_g_filtered_smaller_4 but worse results on radius. Same for log_g_filtered_bigger_1 and log_g_filtered_bigger_3_5 but the other way around.
#
# &emsp; => Might not be useful to use this filtering

# %% [markdown]
# ## Base vs age_filtered

# %% [markdown]
# | Parameter      | Base                 | age_filtered_bigger_7  | age_filtered_smaller_9 |
# | -------------  | -------------------- | ---------------------- | ---------------------- |
# | age            | Range : 5.0 - 10.3 , Mean : 8.4657, Median : 8.55  | Range : 7.05 - 10.3, Mean : 8.79, Median : 8.8 | Range : 5.0 - 8.95, Mean : 7.7619, Median : 7.95 |
# | mass           | Range : 0.1000 - 298.5448, Mean : 7.5368, Median : 2.0818 | Range : 0.1 - 22.912, Mean : 2.8084, Median : 1.7541 | Range : 0.11 - 298.5448, Mean : 11.4704, Median : 3.6371 |
# | log_teff       | Range : 3.3447 - 5.3788, Mean : 3.8298, Median : 3.6739 | Range : 3.34 - 4.6126, Mean : 3.7364, Median : 3.6412 | Range : 3.35 - 5.3788, Mean : 3.9507, Median : 3.8677 |
# | log_g          | Range : -1.1448 - 6.2594, Mean : 2.0665, Median : 2.0050 | Range : -1.14 - 5.4331, Mean : 1.8245, Median : 1.4334 | Range : -1.14 - 6.2594, Mean : 2.2863, Median : 2.6557 |
# | log_R          | Range : -0.9974 - 3.1298, Mean : 1.3949, Median : 1.5001 | Range : -1.0 - 3.046, Mean : 1.4436, Median : 1.6962 | Range : -0.95 - 3.1298, Mean : 1.4163, Median : 1.3648 |

# %% [markdown]
# ### Mass parameter

# %%
compare_metrics(r"C:\Users\antoi\Code\unif\MA2\thesis\results\K_fold", 
                output_parameters=["mass"], # output_parameters=["radius"],
                physical_models=["MIST"],
                data_filters=["Base", "age_filtered_bigger_7", "age_filtered_smaller_9"])
# Out:
#                                                                                           RVE  \
# model             physical_model filter                 output_parameter
# decision_tree     MIST           Base                   mass               0.9953484609461924
#                                  age_filtered_bigger_7  mass                0.998835068792301
#                                  age_filtered_smaller_9 mass               0.9947650018373563
# KNN               MIST           Base                   mass               0.9904012013411723
#                                  age_filtered_bigger_7  mass               0.9988667176770865
#                                  age_filtered_smaller_9 mass               0.9901399180104423
# linear_regression MIST           Base                   mass               0.3333512379514473
#                                  age_filtered_bigger_7  mass               0.6535102471927607
# ...

# %% [markdown]
# Linear regression :
# - age_filtered_bigger_7 : better results than Base (proportionally to the mass)
# - age_filtered_smaller_9 : worse results than Base
#
# Decision tree :
# - age_filtered_bigger_7 : similar results as Base (proportionally to the mass)
# - age_filtered_smaller_9 : worse results than Base
#
# KNN :
# - age_filtered_bigger_7 : slightly better results (proportionally to the mass)
# - age_filtered_smaller_9 : worse results than Base
#
# Random forest :
# - age_filtered_bigger_7 : slightly better results (proportionally to the mass)
# - age_filtered_smaller_9 : worse results than Base
#
# XGBoost :
# - age_filtered_bigger_7 : slightly better results (proportionally to the mass)
# - age_filtered_smaller_9 : worse results than Base
#
# MLP :
# - age_filtered_bigger_7 : slightly better results (proportionally to the mass)
# - age_filtered_smaller_9 : slightly worse results than Base

# %% [markdown]
# #### Conclusions on mass
#
# Filtering with age_filtered_smaller_7 gives slightly better results for all the models (proportionally to the mass).
#
# &emsp; => might be useful to use this filtering if the filtering on the masses only performs similarly to Base
#
#
# Filtering with age_filtered_smaller_9 gives worse results for all the models
#
# &emsp; => not useful to use this filtering

# %% [markdown]
# ### Radius parameter

# %%
compare_metrics(r"C:\Users\antoi\Code\unif\MA2\thesis\results\K_fold", 
                output_parameters=["radius"],
                physical_models=["MIST"],
                data_filters=["Base", "age_filtered_bigger_7", "age_filtered_smaller_9"])
# Out:
#                                                                                          RVE  \
# model             physical_model filter                 output_parameter
# decision_tree     MIST           Base                   radius            0.9997899702074513
#                                  age_filtered_bigger_7  radius            0.9997896846359009
#                                  age_filtered_smaller_9 radius            0.9998256621433711
# KNN               MIST           Base                   radius             0.999833901666557
#                                  age_filtered_bigger_7  radius            0.9998335910486641
#                                  age_filtered_smaller_9 radius            0.9998898256469749
# linear_regression MIST           Base                   radius            0.9897611137480969
#                                  age_filtered_bigger_7  radius            0.9941177619322793
# ...

# %% [markdown]
# Linear regression :
# - age_filtered_bigger_7 : better results than Base
# - age_filtered_smaller_9 : slightly worse results than Base
#
# Decision tree :
# - age_filtered_bigger_7 : similar results as Base but higher MAX_ER
# - age_filtered_smaller_9 : similar results as Base
#
# KNN :
# - age_filtered_bigger_7 : similar results as Base
# - age_filtered_smaller_9 : similar results as Base
#
# Random forest :
# - age_filtered_bigger_7 : similar results as Base
# - age_filtered_smaller_9 : slightly better results than Base
#
# XGBoost :
# - age_filtered_bigger_7 : slightly better results than Base
# - age_filtered_smaller_9 : similar results as Base
#
# MLP :
# - age_filtered_bigger_7 : better results than Base
# - age_filtered_smaller_9 : similar results as Base

# %% [markdown]
# #### Conclusions on radius

# %% [markdown]
# When filtering using age_filtered_bigger_7, the results are similar or slightly better than Base
#
# &emsp; => might be useful to use this filtering
#
# When filtering using age_filtered_smaller_9, the results are mostly similar to Base
#
# &emsp; => not useful to use this filter

# %% [markdown]
# ### Conclusion on both

# %% [markdown]
# Using age_filtered_bigger_7 improves the results of both parameters.
#
# &emsp; => need to check if it is only caused by the lower mass or if this filter is useful because of the change in multiple parameters
#
# Using age_filtered_smaller_9 gives similar results as the Base filtering.
#
# &emsp; => not useful to use this filtering over Base

# %% [markdown]
# ## Base vs mass_filtered

# %% [markdown]
# | Parameter      | Base                 | mass_filtered_smaller_30  | mass_filtered_smaller_3 |
# | -------------  | -------------------- | ---------------------- | ---------------------- |
# | age            | Range : Range : 5.0 - 10.3 , Mean : 8.4657, Median : 8.55  | Range : 5.0 - 10.3, Mean : 8.5822, Median : 8.65 | Range : 6.2 - 10.3, Mean : 9.1372, Median : 9.2 |
# | mass           | Range : 0.1000 - 298.5448, Mean : 7.5368, Median : 2.0818 | Range : 0.1 - 29.9991, Mean : 3.8515, Median : 1.953 | Range : 0.1 - 3.0, Mean : 1.4429, Median : 1.3194 |
# | log_teff       | Range : 3.3447 - 5.3788, Mean : 3.8298, Median : 3.6739 | Range : 3.34 - 5.3542, Mean : 3.7937, Median : 3.6586 | Range : 3.34 - 4.3013, Mean : 3.6671, Median : 3.6162 |
# | log_g          | Range : -1.1448 - 6.2594, Mean : 2.0665, Median : 2.0050 | Range : -1.14 - 6.2434, Mean : 2.0074, Median : 1.8495 | Range : -1.14 - 5.4331, Mean : 1.7423, Median : 0.9009 |
# | log_R          | Range : -0.9974 - 3.1298, Mean : 1.3949, Median : 1.5001 | Range : -1.0 - 3.1298, Mean : 1.387, Median : 1.5084 | Range : -1.0 - 2.8848, Mean : 1.3966, Median : 1.7973 |

# %% [markdown]
# ### Mass parameter

# %%
compare_metrics(r"C:\Users\antoi\Code\unif\MA2\thesis\results\K_fold", 
                output_parameters=["mass"],
                physical_models=["MIST"],
                data_filters=["Base", "mass_filtered_smaller_30", "mass_filtered_smaller_3"])
# Out:
#                                                                                            RVE  \
# model             physical_model filter                   output_parameter
# decision_tree     MIST           Base                     mass              0.9953484609461924
#                                  mass_filtered_smaller_30 mass              0.9991056984251273
#                                  mass_filtered_smaller_3  mass              0.9863740441698512
# KNN               MIST           Base                     mass              0.9904012013411723
#                                  mass_filtered_smaller_30 mass              0.9987882574795091
#                                  mass_filtered_smaller_3  mass              0.9851591018183086
# linear_regression MIST           Base                     mass              0.3333512379514473
#                                  mass_filtered_smaller_30 mass              0.6337762001906275
# ...

# %% [markdown]
# Linear regression :
# - mass_filtered_smaller_30 : similar results as Base (proportionnaly to the mass)
# - mass_filtered_smaller_3 : similar results as Base (proportionnaly to the mass)
#
# Decision tree :
# - mass_filtered_smaller_30 : worse results than Base (proportionnaly to the mass)
# - mass_filtered_smaller_3 : worse results than Base (proportionnaly to the mass)
#
# KNN :
# - mass_filtered_smaller_30 : slightly better results than Base (proportionnaly to the mass)
# - mass_filtered_smaller_3 : slightly worse results than Base (proportionnaly to the mass)
#
# Random forest :
# - mass_filtered_smaller_30 : similar results as Base (proportionnaly to the mass)
# - mass_filtered_smaller_3 : slightly worse results than Base (proportionnaly to the mass)
#
# XGBoost :
# - mass_filtered_smaller_30 : slightly worse results than Base (proportionnaly to the mass)
# - mass_filtered_smaller_3 : slightly worse results than Base (proportionnaly to the mass)
#
# MLP :
# - mass_filtered_smaller_30 : similar results as Base (proportionnaly to the mass)
# - mass_filtered_smaller_3 : similar results as Base (proportionnaly to the mass)

# %% [markdown]
# #### Conclusions on mass

# %% [markdown]
# Proportionnaly to the mass, both filtering give similar (sometimes slightly worse or better) results than Base
#
# &emsp; => not interesting to use as it also restricts what kind of stars the model can predict

# %% [markdown]
# ### Radius parameter

# %%
compare_metrics(r"C:\Users\antoi\Code\unif\MA2\thesis\results\K_fold", 
                output_parameters=["radius"],
                physical_models=["MIST"],
                data_filters=["Base", "mass_filtered_smaller_30", "mass_filtered_smaller_3"])
# Out:
#                                                                                            RVE  \
# model             physical_model filter                   output_parameter
# decision_tree     MIST           Base                     radius            0.9997899702074513
#                                  mass_filtered_smaller_30 radius            0.9998061270554189
#                                  mass_filtered_smaller_3  radius            0.9997980449596693
# KNN               MIST           Base                     radius             0.999833901666557
#                                  mass_filtered_smaller_30 radius             0.999845742270286
#                                  mass_filtered_smaller_3  radius            0.9998124002057707
# linear_regression MIST           Base                     radius            0.9897611137480969
#                                  mass_filtered_smaller_30 radius            0.9925428351690286
# ...

# %% [markdown]
# Linear regression :
# - mass_filtered_smaller_30 : slightly better results than Base
# - mass_filtered_smaller_3 : slightly better results than Base
#
# Decision tree :
# - mass_filtered_smaller_30 : similar results as Base but worse MAX_ER
# - mass_filtered_smaller_3 : slightly better results than Base
#
# KNN :
# - mass_filtered_smaller_30 : slightly better results than Base
# - mass_filtered_smaller_3 : similar results as Base
#
# Random forest :
# - mass_filtered_smaller_30 : slightly better results than Base
# - mass_filtered_smaller_3 : similar results as Base
#
# XGBoost :
# - mass_filtered_smaller_30 : slightly better results than Base
# - mass_filtered_smaller_3 : better results than Base
#
# MLP :
# - mass_filtered_smaller_30 : better results than Base
# - mass_filtered_smaller_3 : better results than Base

# %% [markdown]
# #### Conclusions on radius

# %% [markdown]
# The results of both filtering yielded are similar to Base.
#
# &emsp; => not useful to use these filtering instead of Base

# %% [markdown]
# ### Conclusion on both

# %% [markdown]
# Both parameter give similar results as Base while having the restriction on the mass that the model will be able to predict.
#
# &emsp; => It is not useful to use this filtering instead of Base

# %% [markdown]
# ## Base vs phase_filtered

# %% [markdown]
# | Parameter      | Base                 | phase_filtered  |
# | -------------  | -------------------- | ---------------------- |
# | age            | Range : Range : 5.0 - 10.3 , Mean : 8.4657, Median : 8.55  | Range : 5.0 - 10.3, Mean : 8.1154, Median : 8.15 |
# | mass           | Range : 0.1000 - 298.5448, Mean : 7.5368, Median : 2.0818 | Range : 0.1 - 298.5448, Mean : 11.4145, Median : 2.8996 |
# | log_teff       | Range : 3.3447 - 5.3788, Mean : 3.8298, Median : 3.6739 | Range : 3.34 - 5.3788, Mean : 4.0283, Median : 3.9761 |
# | log_g          | Range : -1.1448 - 6.2594, Mean : 2.0665, Median : 2.0050 | Range : -1.08 - 6.2594, Mean : 3.5075, Median : 3.8521 |
# | log_R          | Range : -0.9974 - 3.1298, Mean : 1.3949, Median : 1.5001 | Range : -1.0 - 3.1298, Mean : 0.735, Median : 0.7005 |
# | phase          | Values : 0, 2, 3, 4, 5 | Values : 0, 2, 3 |

# %% [markdown]
# ### Mass parameter

# %%
compare_metrics(r"C:\Users\antoi\Code\unif\MA2\thesis\results\K_fold", 
                output_parameters=["mass"],
                physical_models=["MIST"],
                data_filters=["Base", "phase_filtered"])
# Out:
#                                                                                  RVE  \
# model             physical_model filter         output_parameter
# decision_tree     MIST           Base           mass              0.9953484609461924
#                                  phase_filtered mass              0.9953844126878636
# KNN               MIST           Base           mass              0.9904012013411723
#                                  phase_filtered mass              0.9895916504979603
# linear_regression MIST           Base           mass              0.3333512379514473
#                                  phase_filtered mass              0.3042271481418729
# mlp               MIST           Base           mass              0.9483444177595798
#                                  phase_filtered mass              0.9830979294359462
# random_forest     MIST           Base           mass              0.9977643973789908
# ...

# %% [markdown]
# Linear regression :
# - phase_filtered : worse results than Base
#
# Decision tree :
# - phase_filtered : similar results as Base, better before 90th percentile, worse after
#
# KNN :
# - phase_filtered : similar results as Base, better before 90th percentile, worse after
#
# Random forest :
# - phase_filtered : similar results as Base, better before 90th percentile, worse after
#
# XGBoost :
# - phase_filtered : slightly worse results than Base
#
# MLP :
# - phase_filtered : slightly worse results than Base

# %% [markdown]
# #### Conclusions on mass
#
# Similar results as Base at best.
#
# &emsp; => not interesting to use this filtering instead of Base

# %% [markdown]
# ### Radius parameter

# %%
compare_metrics(r"C:\Users\antoi\Code\unif\MA2\thesis\results\K_fold", 
                output_parameters=["radius"],
                physical_models=["MIST"],
                data_filters=["Base", "phase_filtered"])
# Out:
#                                                                                         RVE  \
# model             physical_model filter                output_parameter
# decision_tree     MIST           Base                  radius            0.9997899702074513
#                                  age_filtered_bigger_7 radius            0.9997896846359009
# KNN               MIST           Base                  radius             0.999833901666557
#                                  age_filtered_bigger_7 radius            0.9998335910486641
# linear_regression MIST           Base                  radius            0.9897611137480969
#                                  age_filtered_bigger_7 radius            0.9941177619322793
# mlp               MIST           Base                  radius            0.9960419184441298
#                                  age_filtered_bigger_7 radius            0.9983262937093501
# ...

# %% [markdown]
# Linear regression :
# - phase_filtered : slightly better results than Base
#
# Decision tree :
# - phase_filtered : similar results as Base but worse MAX_ER
#
# KNN :
# - phase_filtered : similar results as Base
#
# Random forest :
# - phase_filtered : similar results as Base
#
# XGBoost :
# - phase_filtered : slightly better results than Base
#
# MLP :
# - phase_filtered : slightly better results than Base

# %% [markdown]
# #### Conclusions on radius
#
# Only slight improvements compared to Base
#
# &emsp; => not interesting to use this filtering instead of Base

# %% [markdown]
# ### Conclusion on both
#
# Mostly similar results as Base for all models
#
# &emsp; => not interesting to use this filtering instead of Base

# %% [markdown]
# ## Base vs radius_filtered

# %% [markdown]
# | Parameter      | Base                 | radius_bigger_0_5  | radius_smaller_2 |
# | -------------  | -------------------- | ---------------------- | ---------------------- |
# | age            | Range : Range : 5.0 - 10.3 , Mean : 8.4657, Median : 8.55  | Range : 5.0 - 10.3, Mean : 8.4736, Median : 8.55 | Range : 5.0 - 10.3, Mean : 8.331, Median : 8.45 |
# | mass           | Range : 0.1000 - 298.5448, Mean : 7.5368, Median : 2.0818 | Range : 0.51 - 298.5448, Mean : 8.9974, Median : 2.282 | Range : 0.1 - 298.5448, Mean : 9.0954, Median : 2.2499 |
# | log_teff       | Range : 3.3447 - 5.3788, Mean : 3.8298, Median : 3.6739 | Range : 3.35 - 5.1219, Mean : 3.7918, Median : 3.636 | Range : 3.34 - 5.3788, Mean : 3.9855, Median : 3.884 |
# | log_g          | Range : -1.1448 - 6.2594, Mean : 2.0665, Median : 2.0050 | Range : -1.14 - 5.2269, Mean : 1.37, Median : 0.8281 | Range : 0.15 - 6.2594, Mean : 3.2861, Median : 3.6218 |
# | log_R          | Range : -0.9974 - 3.1298, Mean : 1.3949, Median : 1.5001 | Range : 0.5 - 3.1298, Mean : 1.7821, Median : 1.9663 | Range : -1.0 - 2.0, Mean : 0.8043, Median : 0.8259 |

# %% [markdown]
# ### Mass parameter

# %%
compare_metrics(r"C:\Users\antoi\Code\unif\MA2\thesis\results\K_fold", 
                output_parameters=["mass"],
                physical_models=["MIST"],
                data_filters=["Base", "radius_bigger_0_5", "radius_smaller_2"])
# Out:
#                                                                                     RVE  \
# model             physical_model filter            output_parameter
# decision_tree     MIST           Base              mass              0.9953484609461924
#                                  radius_bigger_0_5 mass              0.9949260615701665
#                                  radius_smaller_2  mass              0.9943220153507675
# KNN               MIST           Base              mass              0.9904012013411723
#                                  radius_bigger_0_5 mass              0.9902978236861779
#                                  radius_smaller_2  mass              0.9888675271489861
# linear_regression MIST           Base              mass              0.3333512379514473
#                                  radius_bigger_0_5 mass              0.4277454650411461
#                                  radius_smaller_2  mass              0.3102467498185517
# ...

# %% [markdown]
# Linear regression :
# - radius_bigger_0_5 : worse results than Base
# - radius_smaller_2 : worse results than Base
#
# Decision tree :
# - radius_bigger_0_5 : worse results than Base
# - radius_smaller_2 : worse results than Base
#
# KNN :
# - radius_bigger_0_5 : worse results than Base
# - radius_smaller_2 : worse results than Base
#
# Random forest :
# - radius_bigger_0_5 : worse results than Base, except MAX_ER
# - radius_smaller_2 : slightly worse results than Base
#
# XGBoost :
# - radius_bigger_0_5 : worse results than Base
# - radius_smaller_2 : worse results than Base
#
# MLP :
# - radius_bigger_0_5 : slightly better results than Base
# - radius_smaller_2 : slightly better results than Base

# %% [markdown]
# #### Conclusions on mass

# %% [markdown]
# Except the MLP, every model has worse results than Base when using both filtering
#
# &emsp; => not interesting to use both filtering

# %% [markdown]
# ### Radius parameter

# %%
compare_metrics(r"C:\Users\antoi\Code\unif\MA2\thesis\results\K_fold", 
                output_parameters=["radius"],
                physical_models=["MIST"],
                data_filters=["Base", "radius_bigger_0_5", "radius_smaller_2"])
# Out:
#                                                                                     RVE  \
# model             physical_model filter            output_parameter
# decision_tree     MIST           Base              radius            0.9997899702074513
#                                  radius_bigger_0_5 radius            0.9994650629520062
#                                  radius_smaller_2  radius            0.9998115778518851
# KNN               MIST           Base              radius             0.999833901666557
#                                  radius_bigger_0_5 radius            0.9995902585445687
#                                  radius_smaller_2  radius            0.9999041333761592
# linear_regression MIST           Base              radius            0.9897611137480969
#                                  radius_bigger_0_5 radius            0.9845858982700071
#                                  radius_smaller_2  radius            0.9846531553265465
# ...

# %% [markdown]
# Linear regression :
# - radius_bigger_0_5 : slightly better results than Base
# - radius_smaller_2 : similar results as Base
#
# Decision tree :
# - radius_bigger_0_5 : worse results than Base
# - radius_smaller_2 : similar results as Base
#
# KNN :
# - radius_bigger_0_5 : worse results than Base
# - radius_smaller_2 : similar results as Base
#
# Random forest :
# - radius_bigger_0_5 : worse results than Base
# - radius_smaller_2 : better results than Base
#
# XGBoost :
# - radius_bigger_0_5 : similar results as Base
# - radius_smaller_2 : slightly better results than
#
# MLP :
# - radius_bigger_0_5 : worse results than Base
# - radius_smaller_2 : worse results than Base

# %% [markdown]
# #### Conclusions on radius

# %% [markdown]
# the radius_bigger_0_5 filtering gives only worse results except for linear regression.
#
# &emsp; => not interesting to use this filtering
#
# the radius_smaller_2 filtering gives only worse results except for Random forest and XGBoost which have better results
#
# &emsp; => might be interesting to use for XGBoost and Random forest

# %% [markdown]
# ### Conclusion on both

# %% [markdown]
# the radius_bigger_0_5 filtering gives worse results overall.
#
# &emsp; => not interesting to use this filtering
#
# the radius_smaller_2 filtering gives worst results overall and limits the kind of stars this model can predict.
#
# &emsp; => not interesting to use this filtering

# %% [markdown]
# ## Base vs Teff_filtered

# %% [markdown]
# | Parameter      | Base                 | T_eff_bigger_3_6  | T_eff_bigger_3_9 | T_eff_smaller_4 |
# | -------------  | -------------------- | ---------------------- | ---------------------- | ---------------------- |
# | age            | Range : Range : 5.0 - 10.3 , Mean : 8.4657, Median : 8.55  | Range : 5.0 - 10.3, Mean : 8.1805, Median : 8.25 | Range : 5.0 - 10.3, Mean : 7.3212, Median : 7.25 | Range : 6.45 - 10.3, Mean : 8.9612, Median : 9.0 |
# | mass           | Range : 0.1000 - 298.5448, Mean : 7.5368, Median : 2.0818 | Range : 0.1 - 298.5448, Mean : 10.266, Median : 2.7375 | Range : 0.65 - 298.5448, Mean : 18.8169, Median : 7.0142 | Range : 0.1 - 117.3869, Mean : 2.4687, Median : 1.4852 |
# | log_teff       | Range : 3.3447 - 5.3788, Mean : 3.8298, Median : 3.6739 | Range : 3.6 - 5.3788, Mean : 3.9766, Median : 3.8629 | Range : 3.9 - 5.3788, Mean : 4.2832, Median : 4.2747 | Range : 3.34 - 4.0, Mean : 3.6381, Median : 3.6117 |
# | log_g          | Range : -1.1448 - 6.2594, Mean : 2.0665, Median : 2.0050 | Range : -0.61 - 6.2594, Mean : 2.9438, Median : 3.2773 | Range : 0.48 - 6.2594, Mean : 3.7767, Median : 3.989 | Range : -1.14 - 5.4331, Mean : 1.3959, Median : 0.6166 |
# | log_R          | Range : -0.9974 - 3.1298, Mean : 1.3949, Median : 1.5001 | Range : -0.98 - 3.0541, Mean : 1.0184, Median : 0.9857 | Range : -0.35 - 2.8499, Mean : 0.7841, Median : 0.6863 | Range : -1.0 - 3.1298, Mean : 1.6236, Median : 2.0136 |

# %% [markdown]
# ### Mass parameter

# %%
compare_metrics(r"C:\Users\antoi\Code\unif\MA2\thesis\results\K_fold", 
                output_parameters=["mass"],
                physical_models=["MIST"],
                data_filters=["Base", "T_eff_bigger_3_6", "T_eff_bigger_3_9", "T_eff_smaller_4"])
# Out:
#                                                                                     RVE  \
# model             physical_model filter           output_parameter
# decision_tree     MIST           Base             mass               0.9953484609461924
#                                  T_eff_bigger_3_6 mass               0.9947872048017296
#                                  T_eff_bigger_3_9 mass               0.9939342314753172
#                                  T_eff_smaller_4  mass               0.9985464649834759
# KNN               MIST           Base             mass               0.9904012013411723
#                                  T_eff_bigger_3_6 mass               0.9900131287830239
#                                  T_eff_bigger_3_9 mass               0.9887020117783859
#                                  T_eff_smaller_4  mass               0.9971015459598264
# linear_regression MIST           Base             mass               0.3333512379514473
# ...

# %% [markdown]
# Linear regression :
# - T_eff_bigger_3_6 : worse results than Base
# - T_eff_bigger_3_9 : worse results than Base
# - T_eff_smaller_4_5 : similar results as Base (proportionally to the mass)
#
# Decision tree :
# - T_eff_bigger_3_6 : better results than Base before 95th percentile, worse after
# - T_eff_bigger_3_9 : worse results than Base
# - T_eff_smaller_4_5 : better results than Base (proportionally to the mass)
#
# KNN :
# - T_eff_bigger_3_6 : better results than Base before 95th percentile, worse after
# - T_eff_bigger_3_9 : worse results than Base
# - T_eff_smaller_4_5 : better results than Base (proportionally to the mass)
#
# Random forest :
# - T_eff_bigger_3_6 : better results than Base before 95th percentile, worse after
# - T_eff_bigger_3_9 : worse results than Base
# - T_eff_smaller_4_5 : better results than Base (proportionally to the mass)
#
# XGBoost :
# - T_eff_bigger_3_6 : slightly worse results than Base
# - T_eff_bigger_3_9 : worse results than Base
# - T_eff_smaller_4_5 : better results than Base (proportionally to the mass)
#
# MLP :
# - T_eff_bigger_3_6 : better results than Base
# - T_eff_bigger_3_9 : worse results than Base
# - T_eff_smaller_4_5 : better results than Base (proportionally to the mass)

# %% [markdown]
# #### Conclusions on mass

# %% [markdown]
# Using the T_eff_bigger_3_6 filtering gives better results before the 95th percentile but has more big errors.
#
# &emsp; => not useful to use this filtering
#
# Using the T_eff_bigger_3_9 filtering gives worse results than Base for every model.
#
# &emsp; => not useful to use this filtering
#
# Using the T_eff_bigger_3_9 filtering gives better results than Base (proportionally to the mass)
#
# &emsp; => might be useful to use this filtering

# %% [markdown]
# ### Radius parameter

# %%
compare_metrics(r"C:\Users\antoi\Code\unif\MA2\thesis\results\K_fold", 
                output_parameters=["radius"],
                physical_models=["MIST"],
                data_filters=["Base", "T_eff_bigger_3_6", "T_eff_bigger_3_9", "T_eff_smaller_4_5"])
# Out:
#                                                                                     RVE  \
# model             physical_model filter            output_parameter
# decision_tree     MIST           Base              radius            0.9997899702074513
#                                  T_eff_bigger_3_6  radius            0.9998290851240951
#                                  T_eff_bigger_3_9  radius             0.999622839291098
#                                  T_eff_smaller_4_5 radius            0.9997646853601904
# KNN               MIST           Base              radius             0.999833901666557
#                                  T_eff_bigger_3_6  radius            0.9999180008490599
#                                  T_eff_bigger_3_9  radius            0.9998304466176052
#                                  T_eff_smaller_4_5 radius            0.9998062106292361
# linear_regression MIST           Base              radius            0.9897611137480969
# ...

# %% [markdown]
# Linear regression :
# - T_eff_bigger_3_6 : similar results as Base
# - T_eff_bigger_3_9 : better results than Base
# - T_eff_smaller_4_5 : better results than Base
#
# Decision tree :
# - T_eff_bigger_3_6 : slightly better results than Base
# - T_eff_bigger_3_9 : better results than Base before 99th percentile, worse MAX_ER
# - T_eff_smaller_4_5 : worse results than Base
#
# KNN :
# - T_eff_bigger_3_6 : better results than Base
# - T_eff_bigger_3_9 : better results than Base
# - T_eff_smaller_4_5 : worse results than Base
#
# Random forest :
# - T_eff_bigger_3_6 : better results than Base
# - T_eff_bigger_3_9 : better results than Base
# - T_eff_smaller_4_5 : worse results than Base
#
# XGBoost :
# - T_eff_bigger_3_6 : slightly better results than Base
# - T_eff_bigger_3_9 : better results than Base, worse MAX_ER
# - T_eff_smaller_4_5 : better results than Base
#
# MLP :
# - T_eff_bigger_3_6 : worse results than Base
# - T_eff_bigger_3_9 : worse results than Base
# - T_eff_smaller_4_5 : slightly worse results than Base

# %% [markdown]
# #### Conclusions on radius

# %% [markdown]
# The T_eff_bigger_3_6 and T_eff_bigger_3_9 filtering gives better results for most models
#
# &emsp; => might useful to use this filtering
#
# The T_eff_smaller_4_5 filtering give worse results for most models
#
# &emsp; => not useful to use this filtering

# %% [markdown]
# ### Conclusion on both

# %% [markdown]
# The T_eff_bigger_3_6 and T_eff_bigger_3_9 filtering gives worse results for mass but better results for radius
#
# &emsp; => not useful to use this filtering
#
# The T_eff_smaller_4_5 filtering gives better results for mass but worse results for radius.
#
# &emsp; => not useful to use this filtering

# %% [markdown]
# ## Final conclusion on the filters

# %% [markdown]
# Filtering on the log_g => not useful as the results of the two parameters go in opposite directions (when one improves, the other worsens)
#
# Filtering on the age => age_filtered_bigger_7 improves the results of both parameters compared to Base and might be useful to use if we are fine with losing the possibility to predict for stars below 10.000.000 years
#
# Filtering on the mass => not useful to use this filtering as it gives similar results as Base while being restricted in the kind of stars it can predict
#
# Filtering on the phase => not useful to use this filtering as it gives similar results as Base while being restricted in the kind of stars it can predict
#
# Filtering on the radius => not useful to use this filtering as it gives worse results than Base overall
#
# Filtering on the Teff => not useful as the results of the two parameters go in opposite directions (when one improves, the other worsens)
