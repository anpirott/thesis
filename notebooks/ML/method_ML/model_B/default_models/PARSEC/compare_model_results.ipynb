# %% [markdown]
# # Results comparison for PARSEC
#
# In this notebook, I will compare the results of the different models.

# %%
from ML.utils.utils import *

# %%
pre_path = "../../../../../../"
path = pre_path + "results/model_B/default_models"

# %%
compare_metrics(path,
                output_parameters=["T_eff", "log_g", "radius"],
                physical_models=["PARSEC"],
                data_filters=["Base"])
# Out:
# Results for the Global category with a value of 1.0
# {'': 'logTe',
#  'value range': '3.3621 - 4.5177',
#  'RVE': '0.9451742472012191',
#  'RMSE': '0.042554292673794465',
#  'MAE': '0.012520623599939452',
#  'MedAE': '0.001191428571428066',
#  'CORR': '0.9724235183367057',
#  'MAX_ER': '0.8407',
#  'Percentiles': '{75: np.float64(0.006600000000000161), 90: np.float64(0.026200000000000223), 95: np.float64(0.0647000000000002), 99: np.float64(0.19772900000000096)}'}
# {'': 'logg',
#  'value range': '-0.384 - 5.345',
#  'RVE': '0.7536570738013006',
#  'RMSE': '0.5190543242870183',
#  'MAE': '0.15060909496410327',
#  'MedAE': '0.01100000000000012',
#  'CORR': '0.8738266108931796',
#  'MAX_ER': '4.779999999999999',
#  'Percentiles': '{75: np.float64(0.057719017094017055), 90: np.float64(0.22266666666666612), 95: np.float64(0.8953333333333333), 99: np.float64(2.907)}'}
# {'': 'Rpol',
#  'value range': '-0.9763360818022064 - 2.8372727025023003',
#  'RVE': '0.8188802537475399',
#  'RMSE': '0.25948245112260193',
#  'MAE': '0.07527911151810734',
#  'MedAE': '0.0056727093489148395',
#  'CORR': '0.9078549079572853',
#  'MAX_ER': '2.390815363619212',
#  'Percentiles': '{75: np.float64(0.02877384124018234), 90: np.float64(0.11128851752036972), 95: np.float64(0.4465009441071157), 99: np.float64(1.4536289854473723)}'}
# {'': 'logTe',
#  'value range': '3.3621 - 4.5177',
#  'RVE': '0.9289910884078197',
#  'RMSE': '0.04851081543113413',
#  'MAE': '0.0162096969395537',
#  'MedAE': '0.0018799999999998818',
#  'CORR': '0.9638581868639022',
#  'MAX_ER': '0.8291399999999998',
#  'Percentiles': '{75: np.float64(0.013300000000000534), 90: np.float64(0.03979999999999961), 95: np.float64(0.07538), 99: np.float64(0.20008579999999995)}'}
# {'': 'logg',
#  'value range': '-0.384 - 5.345',
#  'RVE': '0.7969225275315691',
#  'RMSE': '0.47145630056607196',
#  'MAE': '0.16864683262044497',
#  'MedAE': '0.013200000000000323',
#  'CORR': '0.8935178759114629',
#  'MAX_ER': '4.6354',
#  'Percentiles': '{75: np.float64(0.08860000000000001), 90: np.float64(0.44619999999999993), 95: np.float64(1.0346), 99: np.float64(2.242058000000002)}'}
# {'': 'Rpol',
#  'value range': '-0.9763360818022064 - 2.8372727025023003',
#  'RVE': '0.8504530694492762',
#  'RMSE': '0.2358770846024068',
#  'MAE': '0.0846864913145467',
#  'MedAE': '0.007272808772476278',
#  'CORR': '0.9227969605947961',
#  'MAX_ER': '2.3172378341427184',
#  'Percentiles': '{75: np.float64(0.04507146205035209), 90: np.float64(0.22251607129010623), 95: np.float64(0.5175618219414548), 99: np.float64(1.12183384943983)}'}
# {'': 'logTe',
#  'value range': '3.3621 - 4.5177',
#  'RVE': '0.34445841658008647',
#  'RMSE': '0.14714610399062228',
#  'MAE': '0.10806443419089096',
#  'MedAE': '0.07505188017050912',
#  'CORR': '0.5869057992445806',
#  'MAX_ER': '0.5457108330954776',
#  'Percentiles': '{75: np.float64(0.14234102599238696), 90: np.float64(0.27293111872202047), 95: np.float64(0.32015839447669814), 99: np.float64(0.4286755659768055)}'}
# {'': 'logg',
#  'value range': '-0.384 - 5.345',
#  'RVE': '0.1740171909362369',
#  'RMSE': '0.950442888851383',
#  'MAE': '0.7507155523234634',
#  'MedAE': '0.5052899263280148',
#  'CORR': '0.41715368143690107',
#  'MAX_ER': '3.3549603792326215',
#  'Percentiles': '{75: np.float64(1.13118681430233), 90: np.float64(1.6221145970875757), 95: np.float64(1.8834090505757763), 99: np.float64(2.4110734525384423)}'}
# {'': 'Rpol',
#  'value range': '-0.9763360818022064 - 2.8372727025023003',
#  'RVE': '0.306153058491456',
#  'RMSE': '0.507872479197307',
#  'MAE': '0.39753794061010017',
#  'MedAE': '0.2745446720480792',
#  'CORR': '0.5533109976788975',
#  'MAX_ER': '1.781259161764016',
#  'Percentiles': '{75: np.float64(0.5881260007881461), 90: np.float64(0.8392251970149618), 95: np.float64(1.0203742560287077), 99: np.float64(1.4215143805808375)}'}
# {'': 'logTe',
#  'value range': '3.3621 - 4.5177',
#  'RVE': '0.45667538004833186',
#  'RMSE': '0.13410280662162238',
#  'MAE': '0.09348296889333235',
#  'MedAE': '0.06409550839974631',
#  'CORR': '0.6876406178694955',
#  'MAX_ER': '0.8323897989412399',
#  'Percentiles': '{75: np.float64(0.11521844792614189), 90: np.float64(0.20537524309431038), 95: np.float64(0.28500067164103254), 99: np.float64(0.5006921296295106)}'}
# {'': 'logg',
#  'value range': '-0.384 - 5.345',
#  'RVE': '0.5075863573833721',
#  'RMSE': '0.7345510679198198',
#  'MAE': '0.5010944235421306',
#  'MedAE': '0.25958360258796387',
#  'CORR': '0.7124610004519873',
#  'MAX_ER': '3.893785889637569',
#  'Percentiles': '{75: np.float64(0.733109940823991), 90: np.float64(1.4177864582268356), 95: np.float64(1.6572262157401294), 99: np.float64(2.180193272888835)}'}
# {'': 'Rpol',
#  'value range': '-0.9763360818022064 - 2.8372727025023003',
#  'RVE': '0.6228554128105982',
#  'RMSE': '0.37498636922431416',
#  'MAE': '0.25364283689755424',
#  'MedAE': '0.13319718920440615',
#  'CORR': '0.7892150515996972',
#  'MAX_ER': '1.9906768274128068',
#  'Percentiles': '{75: np.float64(0.3794897682511303), 90: np.float64(0.7157360345885051), 95: np.float64(0.850219536783381), 99: np.float64(1.0896763321743037)}'}
# {'': 'logTe',
#  'value range': '3.3621 - 4.5177',
#  'RVE': '0.9566608469406531',
#  'RMSE': '0.03783483575687937',
#  'MAE': '0.01219639278844237',
#  'MedAE': '0.0015007253298946477',
#  'CORR': '0.9781241008271904',
#  'MAX_ER': '0.8289985333333334',
#  'Percentiles': '{75: np.float64(0.007235958017391186), 90: np.float64(0.029086720655177915), 95: np.float64(0.06464142577536748), 99: np.float64(0.1703621809543765)}'}
# {'': 'logg',
#  'value range': '-0.384 - 5.345',
#  'RVE': '0.8074266704690882',
#  'RMSE': '0.4589248718978013',
#  'MAE': '0.14624083345990166',
#  'MedAE': '0.012716574855699436',
#  'CORR': '0.8998465625312148',
#  'MAX_ER': '4.620864250000007',
#  'Percentiles': '{75: np.float64(0.06499948214285545), 90: np.float64(0.2822953455266947), 95: np.float64(0.9114782158730169), 99: np.float64(2.3747310131929207)}'}
# {'': 'Rpol',
#  'value range': '-0.9763360818022064 - 2.8372727025023003',
#  'RVE': '0.8584173604243724',
#  'RMSE': '0.22941978755764808',
#  'MAE': '0.07306790793549578',
#  'MedAE': '0.006440088206492278',
#  'CORR': '0.9271725495364581',
#  'MAX_ER': '2.310296151725146',
#  'Percentiles': '{75: np.float64(0.03242411283486865), 90: np.float64(0.1405651917149896), 95: np.float64(0.45529244954880643), 99: np.float64(1.1874947054148173)}'}
# {'': 'logTe',
#  'value range': '3.3621 - 4.5177',
#  'RVE': '0.7726322878335125',
#  'RMSE': '0.08665888725371604',
#  'MAE': '0.044921245386785554',
#  'MedAE': '0.012216230392456007',
#  'CORR': '0.879158545551974',
#  'MAX_ER': '0.6862123130798343',
#  'Percentiles': '{75: np.float64(0.05361874027252189), 90: np.float64(0.13639078788757342), 95: np.float64(0.2019528767013548), 99: np.float64(0.34633857157134995)}'}
# {'': 'logg',
#  'value range': '-0.384 - 5.345',
#  'RVE': '0.7207144464742739',
#  'RMSE': '0.5526686841050604',
#  'MAE': '0.313614388728856',
#  'MedAE': '0.10713393402099625',
#  'CORR': '0.8494127272684615',
#  'MAX_ER': '4.357620960235596',
#  'Percentiles': '{75: np.float64(0.4028454666137694), 90: np.float64(0.9517127717018127), 95: np.float64(1.2855033573150634), 99: np.float64(2.013638725395205)}'}
# {'': 'Rpol',
#  'value range': '-0.9763360818022064 - 2.8372727025023003',
#  'RVE': '0.7945230921341289',
#  'RMSE': '0.27637866309651515',
#  'MAE': '0.156982113190067',
#  'MedAE': '0.05423633153337293',
#  'CORR': '0.8915692177111999',
#  'MAX_ER': '2.261232186873491',
#  'Percentiles': '{75: np.float64(0.19951854021180607), 90: np.float64(0.47688872666573384), 95: np.float64(0.6406879632583389), 99: np.float64(1.0085054919424687)}'}
# {'decision_tree': {'PARSEC': {'Base': {}}}, 'KNN': {'PARSEC': {'Base': {}}}, 'linear_regression': {'PARSEC': {'Base': {}}}, 'mlp': {'PARSEC': {'Base': {}}}, 'random_forest': {'PARSEC': {'Base': {}}}, 'xgboost': {'PARSEC': {'Base': {}}}}
# No results to show, please make sure that the output parameters are correct.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
