# %% [markdown]
# # Results comparison for PARSEC
#
# In this notebook, I will compare the results of the different models.

# %%
from ML.utils.utils import *

# %%
pre_path = "../../../../../../"
path = pre_path + "results/model_B/default_models"

# %%
compare_metrics(path, value_rounding=3,
                output_parameters=["T_eff", "log_g", "radius"],
                physical_models=["PARSEC"],
                data_filters=["Base"])
# Out:
#                                                             RVE    RMSE  \
# model             physical_model filter output_parameter
# decision_tree     PARSEC         Base   T_eff             0.925   0.043
#                                         log_g             0.759   0.513
#                                         radius            0.833  33.496
# KNN               PARSEC         Base   T_eff             0.912   0.047
#                                         log_g             0.782   0.488
#                                         radius            0.853  31.462
# linear_regression PARSEC         Base   T_eff             0.248   0.137
#                                         log_g             0.133   0.973
#                                         radius            0.321  67.535
# mlp               PARSEC         Base   T_eff             0.293   0.133
#                                         log_g             0.398   0.814
# ...
