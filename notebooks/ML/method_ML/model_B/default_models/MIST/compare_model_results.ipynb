# %% [markdown]
# # Results comparison for MIST filtering of model B
#
# In this notebook, I will compare the results of the different models relative to how the data was filtered (only the MIST dataset).
#
# I will first look at how the filter on one value affected the other (if it didn't affect it, I will not write it) and then see how it affected the results of each model.

# %%
from ML.utils.utils import *
from physics.Iso_data_handler import Iso_data_handler
from ML.utils.Data_preparator import Data_preparator

# %%
pre_path = "../../../../../../"
path = pre_path + "results/model_B/default_models"

# %%
compare_metrics(path, value_rounding=3,
                output_parameters=["T_eff"], # output_parameters=["radius"],
                model_names=["random_forest"],
                physical_models=["MIST"],
                data_filters = ["Base", "mass_smaller_3", "mass_smaller_14", "mass_smaller_30"])
# Out:
# Results for the Global category with a value of 1.0
#                                                                  value range  \
# model         physical_model filter          output_parameter
# random_forest MIST           Base            T_eff             3.345 - 5.379
#                              mass_smaller_3  T_eff             3.345 - 4.301
#                              mass_smaller_14 T_eff             3.345 - 4.634
#                              mass_smaller_30 T_eff             3.345 - 5.354
#
#                                                                  RVE   RMSE  \
# model         physical_model filter          output_parameter
# random_forest MIST           Base            T_eff             0.967  0.063
#                              mass_smaller_3  T_eff             0.957  0.038
#                              mass_smaller_14 T_eff             0.967  0.052
#                              mass_smaller_30 T_eff             0.964  0.060
#
# ...

# %%
compare_metrics(path, value_rounding=3,
                output_parameters=["T_eff", "radius", "log_g"], # output_parameters=["radius"],
                physical_models=["MIST"],
                data_filters=["Base"])
# Out:
# Results for the Global category with a value of 1.0
#                                                              value range  \
# model             physical_model filter output_parameter
# decision_tree     MIST           Base   T_eff              3.345 - 5.379
#                                         log_g             -1.083 - 6.259
#                                         radius            -0.997 - 3.129
# KNN               MIST           Base   T_eff              3.345 - 5.379
#                                         log_g             -1.083 - 6.259
#                                         radius            -0.997 - 3.129
# linear_regression MIST           Base   T_eff              3.345 - 5.379
#                                         log_g             -1.083 - 6.259
#                                         radius            -0.997 - 3.129
# mlp               MIST           Base   T_eff              3.345 - 5.379
# ...

# %% [markdown]
# ## Getting the ranges for the values

# %%
iso_handler = Iso_data_handler("C:/Users/antoi/Code/unif/MA2/thesis/data/MIST_v1.2_vvcrit0.0_basic_isos/", 
                                    ['log10_isochrone_age_yr', 'log_Teff', 'log_g', 'phase', 'metallicity', 'star_mass', 'log_R', 'log_L'], 
                                    "MIST", reclassify=True)

iso_df = iso_handler.get_isochrone_dataframe()
display(iso_df)
# Out:
# Reading MIST dataframe from MIST_reclassified_iso_full_data.csv file...
#          log10_isochrone_age_yr  log_Teff     log_g  phase  metallicity  \
# 0                           5.0  3.486221  3.131342   -1.0        -0.25
# 1                           5.0  3.487362  3.126808   -1.0        -0.25
# 2                           5.0  3.489243  3.119367   -1.0        -0.25
# 3                           5.0  3.491102  3.112165   -1.0        -0.25
# 4                           5.0  3.492937  3.105143   -1.0        -0.25
# ...                         ...       ...       ...    ...          ...
# 1467117                    10.3  4.402490  7.777159    6.0         0.50
# 1467118                    10.3  4.387132  7.783242    6.0         0.50
# 1467119                    10.3  4.371789  7.789130    6.0         0.50
# 1467120                    10.3  4.356480  7.794844    6.0         0.50
# 1467121                    10.3  4.341226  7.800376    6.0         0.50
#
# ...

# %%
phase_filtered_iso_df = Data_preparator.filter_data(iso_df, {'phase':[0, 2, 3], 'star_mass':('<', 3)})
print_all_uniques(phase_filtered_iso_df)
# Out:
# log10_isochrone_age_yr  : Range : 6.2 - 10.3, Mean : 9.0993, Median : 9.2
#
# log_Teff  : Range : 3.34 - 4.3013, Mean : 3.795, Median : 3.7533
#
# log_g  : Range : -1.08 - 5.4331, Mean : 3.6429, Median : 4.1661
#
# Values in phase column : 0.0, 2.0, 3.0
#
# Values in metallicity column : -0.25, -0.5, -0.75, -1.0, -1.25, -1.5, -1.75, -2.0, -2.5, -3.0, -3.5, -4.0, 0.0, 0.25, 0.5
#
# star_mass  : Range : 0.1 - 3.0, Mean : 1.3237, Median : 1.1896
#
# log_R  : Range : -1.0 - 2.7813, Mean : 0.4164, Median : 0.2391
#
# log_L  : Range : -3.33 - 4.02, Mean : 0.9675, Median : 1.3998

# %% [markdown]
# ## Comparing each model's results to keep the best ones with MIST dataset

# %% [markdown]
# ### Linear regression

# %% [markdown]
# #### T_eff parameter

# %%
compare_metrics(path, value_rounding=3, relative_values=True, 
                output_parameters=["T_eff"],
                physical_models=["MIST"],
                model_names=["linear_regression"],
                categories=["Global"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                                        value range  \
# model             physical_model filter            output_parameter
# linear_regression MIST           Base              T_eff             3.345 - 5.379
#                                  Base_old          T_eff             3.345 - 5.379
#                                  mass_smaller_14   T_eff             3.345 - 4.634
#                                  mass_smaller_3    T_eff             3.345 - 4.301
#                                  mass_smaller_30   T_eff             3.345 - 5.354
#                                  scale_power       T_eff             3.345 - 5.379
#                                  scale_power_14    T_eff             3.345 - 4.634
#                                  scale_quantile    T_eff             3.345 - 5.379
#                                  scale_quantile_14 T_eff             3.345 - 4.634
# ...

# %% [markdown]
# Aucun modèle n'est vraiment très performant. scale_power donne les meilleurs résultats => MAX_ER, RMSE et percentiles dans les plus bas

# %% [markdown]
# #### log_g parameter

# %%
compare_metrics(path, value_rounding=3, relative_values=True, 
                output_parameters=["log_g"],
                physical_models=["MIST"],
                model_names=["linear_regression"],
                categories=["Global"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                                         value range  \
# model             physical_model filter            output_parameter
# linear_regression MIST           Base              log_g             -1.083 - 6.259
#                                  Base_old          log_g             -1.145 - 6.259
#                                  mass_smaller_14   log_g             -1.083 - 5.433
#                                  mass_smaller_3    log_g             -1.075 - 5.433
#                                  mass_smaller_30   log_g             -1.075 - 6.243
#                                  scale_power       log_g             -1.083 - 6.259
#                                  scale_power_14    log_g             -1.083 - 5.433
#                                  scale_quantile    log_g             -1.083 - 6.259
#                                  scale_quantile_14 log_g             -1.083 - 5.433
# ...

# %% [markdown]
# Aucun modèle n'est vraiment très performant. scale_power donne les meilleurs résultats => MAX_ER, RMSE et percentiles dans les plus bas

# %% [markdown]
# #### Radius parameter

# %%
compare_metrics(path, value_rounding=3, relative_values=True, 
                output_parameters=["radius"],
                physical_models=["MIST"],
                model_names=["linear_regression"],
                categories=["Global"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                                         value range  \
# model             physical_model filter            output_parameter
# linear_regression MIST           Base              radius            -0.997 - 3.129
#                                  Base_old          radius            -0.997 - 3.129
#                                  mass_smaller_14   radius            -0.997 - 3.082
#                                  mass_smaller_3    radius            -0.997 - 2.781
#                                  mass_smaller_30   radius             -0.997 - 3.13
#                                  scale_power       radius            -0.997 - 3.129
#                                  scale_power_14    radius            -0.997 - 3.082
#                                  scale_quantile    radius            -0.997 - 3.129
#                                  scale_quantile_14 radius            -0.997 - 3.082
# ...

# %% [markdown]
# Aucun modèle n'est vraiment très performant. scale_power donne les meilleurs résultats => MAX_ER, RMSE et percentiles dans les plus bas

# %% [markdown]
# #### Filtre choisi
#
# Le filtre scale_power est choisi parce qu'il donne les meilleurs résultats pour la masse et est l'un des deux meilleurs filtre pour le rayon.
#
# linear_regression	MIST	scale_power	T_eff	3.345 - 5.379	0.774	8.08%	6.191%	5.401%	0.880	46.38%	75 : 8.004% / 90 : 11.298% / 95 : 16.575% / 99 : 26.884%	10.220
#
# linear_regression	MIST	scale_power	log_g	-1.083 - 6.259	0.411	12.707%	10.177%	9.067%	0.641	63.136%	75 : 13.159% / 90 : 20.09% / 95 : 25.591% / 99 : 35.715%	10.220
#
# linear_regression	MIST	scale_power	radius	-0.997 - 3.129	0.602	11.286%	9.059%	8.273%	0.776	57.275%	75 : 11.683% / 90 : 17.719% / 95 : 22.492% / 99 : 31.794%	10.220

# %% [markdown]
# ### Decision tree

# %% [markdown]
# #### T_eff parameter

# %%
compare_metrics(path, value_rounding=3, relative_values=True, 
                output_parameters=["T_eff"],
                physical_models=["MIST"],
                model_names=["decision_tree"],
                categories=["Global"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                                    value range  \
# model         physical_model filter            output_parameter
# decision_tree MIST           Base              T_eff             3.345 - 5.379
#                              Base_old          T_eff             3.345 - 5.379
#                              mass_smaller_14   T_eff             3.345 - 4.634
#                              mass_smaller_3    T_eff             3.345 - 4.301
#                              mass_smaller_30   T_eff             3.345 - 5.354
#                              scale_power       T_eff             3.345 - 5.379
#                              scale_power_14    T_eff             3.345 - 4.634
#                              scale_quantile    T_eff             3.345 - 5.379
#                              scale_quantile_14 T_eff             3.345 - 4.634
# ...

# %% [markdown]
# Filtre Base donne les meilleurs résultats relatif, mass_smaller_14 et ses scaling donne les meilleurs résultats absolus

# %% [markdown]
# #### log_g parameter

# %%
compare_metrics(path, value_rounding=3, relative_values=True, 
                output_parameters=["log_g"],
                physical_models=["MIST"],
                model_names=["decision_tree"],
                categories=["Global"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                                     value range  \
# model         physical_model filter            output_parameter
# decision_tree MIST           Base              log_g             -1.083 - 6.259
#                              Base_old          log_g             -1.145 - 6.259
#                              mass_smaller_14   log_g             -1.083 - 5.433
#                              mass_smaller_3    log_g             -1.075 - 5.433
#                              mass_smaller_30   log_g             -1.075 - 6.243
#                              scale_power       log_g             -1.083 - 6.259
#                              scale_power_14    log_g             -1.083 - 5.433
#                              scale_quantile    log_g             -1.083 - 6.259
#                              scale_quantile_14 log_g             -1.083 - 5.433
# ...

# %% [markdown]
# Filtre Base donne les meilleurs résultats relatif, mass_smaller_14 et ses scaling donne des résultats similaires en absolu

# %% [markdown]
# #### Radius parameter

# %%
compare_metrics(path, value_rounding=3, relative_values=True, 
                output_parameters=["radius"],
                physical_models=["MIST"],
                model_names=["decision_tree"],
                categories=["Global"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                                     value range  \
# model         physical_model filter            output_parameter
# decision_tree MIST           Base              radius            -0.997 - 3.129
#                              Base_old          radius            -0.997 - 3.129
#                              mass_smaller_14   radius            -0.997 - 3.082
#                              mass_smaller_3    radius            -0.997 - 2.781
#                              mass_smaller_30   radius             -0.997 - 3.13
#                              scale_power       radius            -0.997 - 3.129
#                              scale_power_14    radius            -0.997 - 3.082
#                              scale_quantile    radius            -0.997 - 3.129
#                              scale_quantile_14 radius            -0.997 - 3.082
# ...

# %% [markdown]
# Filtre Base donne les meilleurs résultats relatif, mass_smaller_14 et ses scaling donne des résultats similaires en absolu

# %% [markdown]
# #### Filtre choisi
#
# Le filtre Base est choisi parce qu'il donne les meilleurs résultats pour les trois paramètres.
#
# decision_tree	MIST	Base	T_eff	3.345 - 5.379	0.950	3.794%	0.913%	0.086%	0.975	46.738%	75 : 0.21% / 90 : 1.065% / 95 : 4.791% / 99 : 20.817%	17.940
#
# decision_tree	MIST	Base	log_g	-1.083 - 6.259	0.729	8.63%	2.373%	0.104%	0.865	77.218%	75 : 0.262% / 90 : 2.885% / 95 : 18.53% / 99 : 45.586%	17.940
#
# decision_tree	MIST	Base	radius	-0.997 - 3.129	0.816	7.681%	2.124%	0.113%	0.908	68.704%	75 : 0.249% / 90 : 2.572% / 95 : 16.512% / 99 : 40.591%	17.940

# %% [markdown]
# ### KNN

# %% [markdown]
# #### T_eff parameter

# %%
compare_metrics(path, value_rounding=3, relative_values=True, 
                output_parameters=["T_eff"],
                physical_models=["MIST"],
                model_names=["KNN"],
                categories=["Global"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                            value range    RVE  \
# model physical_model filter            output_parameter
# KNN   MIST           Base              T_eff             3.345 - 5.379  0.967
#                      Base_old          T_eff             3.345 - 5.379  0.869
#                      mass_smaller_14   T_eff             3.345 - 4.634  0.974
#                      mass_smaller_3    T_eff             3.345 - 4.301  0.969
#                      mass_smaller_30   T_eff             3.345 - 5.354  0.970
#                      scale_power       T_eff             3.345 - 5.379  0.977
#                      scale_power_14    T_eff             3.345 - 4.634  0.977
#                      scale_quantile    T_eff             3.345 - 5.379  0.977
#                      scale_quantile_14 T_eff             3.345 - 4.634  0.977
#                      scale_robust      T_eff             3.345 - 5.379  0.973
# ...

# %% [markdown]
# Filtre Base donne les meilleurs résultats relatif, mass_smaller_14 et ses scaling donne les meilleurs résultats absolus

# %%
compare_metrics(path, value_rounding=3, relative_values=True, 
                output_parameters=["T_eff"],
                physical_models=["MIST"],
                model_names=["KNN"],
                categories=["Global"],
                data_filters=["mass_smaller_14", "scale_standard_14", "scale_robust_14", "scale_quantile_14", "scale_power_14"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                            value range    RVE  \
# model physical_model filter            output_parameter
# KNN   MIST           mass_smaller_14   T_eff             3.345 - 4.634  0.974
#                      scale_standard_14 T_eff             3.345 - 4.634  0.977
#                      scale_robust_14   T_eff             3.345 - 4.634  0.976
#                      scale_quantile_14 T_eff             3.345 - 4.634  0.977
#                      scale_power_14    T_eff             3.345 - 4.634  0.977
#
#                                                            RMSE     MAE  \
# model physical_model filter            output_parameter
# KNN   MIST           mass_smaller_14   T_eff             3.579%  0.979%
#                      scale_standard_14 T_eff             3.384%  0.914%
#                      scale_robust_14   T_eff             3.404%   0.92%
# ...

# %% [markdown]
# Le scaling semble améliorer les résultats. Le meilleur scaling est le power scaling

# %% [markdown]
# #### log_g parameter

# %%
compare_metrics(path, value_rounding=3, relative_values=False, 
                output_parameters=["log_g"],
                physical_models=["MIST"],
                model_names=["KNN"],
                categories=["Global"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                             value range  \
# model physical_model filter            output_parameter
# KNN   MIST           Base              log_g             -1.083 - 6.259
#                      Base_old          log_g             -1.145 - 6.259
#                      mass_smaller_14   log_g             -1.083 - 5.433
#                      mass_smaller_3    log_g             -1.075 - 5.433
#                      mass_smaller_30   log_g             -1.075 - 6.243
#                      scale_power       log_g             -1.083 - 6.259
#                      scale_power_14    log_g             -1.083 - 5.433
#                      scale_quantile    log_g             -1.083 - 6.259
#                      scale_quantile_14 log_g             -1.083 - 5.433
#                      scale_robust      log_g             -1.083 - 6.259
# ...

# %% [markdown]
# Le filtre Base et ses scaling donne les meilleurs résultats, mass_smaller_14 n'est pas loin derrière

# %%
compare_metrics(path, value_rounding=3, relative_values=True, 
                output_parameters=["log_g"],
                physical_models=["MIST"],
                model_names=["KNN"],
                categories=["Global"],
                data_filters=["Base", "scale_standard", "scale_robust", "scale_quantile", "scale_power"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                          value range    RVE  \
# model physical_model filter         output_parameter
# KNN   MIST           Base           log_g             -1.083 - 6.259  0.859
#                      scale_standard log_g             -1.083 - 6.259  0.874
#                      scale_robust   log_g             -1.083 - 6.259  0.869
#                      scale_quantile log_g             -1.083 - 6.259  0.875
#                      scale_power    log_g             -1.083 - 6.259  0.875
#
#                                                         RMSE     MAE   MedAE  \
# model physical_model filter         output_parameter
# KNN   MIST           Base           log_g             6.216%  2.049%  0.085%
#                      scale_standard log_g             5.884%  1.774%  0.072%
#                      scale_robust   log_g             5.998%  1.869%  0.076%
# ...

# %% [markdown]
# Le filtre scale_quantile donne les meilleurs résultats

# %% [markdown]
# #### Radius parameter

# %%
compare_metrics(path, value_rounding=3, relative_values=False, 
                output_parameters=["radius"],
                physical_models=["MIST"],
                model_names=["KNN"],
                categories=["Global"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                             value range  \
# model physical_model filter            output_parameter
# KNN   MIST           Base              radius            -0.997 - 3.129
#                      Base_old          radius            -0.997 - 3.129
#                      mass_smaller_14   radius            -0.997 - 3.082
#                      mass_smaller_3    radius            -0.997 - 2.781
#                      mass_smaller_30   radius             -0.997 - 3.13
#                      scale_power       radius            -0.997 - 3.129
#                      scale_power_14    radius            -0.997 - 3.082
#                      scale_quantile    radius            -0.997 - 3.129
#                      scale_quantile_14 radius            -0.997 - 3.082
#                      scale_robust      radius            -0.997 - 3.129
# ...

# %% [markdown]
# les scaling de Base donne les meilleurs résultats

# %%
compare_metrics(path, value_rounding=3, relative_values=True, 
                output_parameters=["radius"],
                physical_models=["MIST"],
                model_names=["KNN"],
                categories=["Global"],
                data_filters=["Base", "scale_standard", "scale_robust", "scale_quantile", "scale_power"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                          value range    RVE  \
# model physical_model filter         output_parameter
# KNN   MIST           Base           radius            -0.997 - 3.129  0.904
#                      scale_standard radius            -0.997 - 3.129  0.914
#                      scale_robust   radius            -0.997 - 3.129  0.911
#                      scale_quantile radius            -0.997 - 3.129  0.915
#                      scale_power    radius            -0.997 - 3.129  0.915
#
#                                                         RMSE     MAE   MedAE  \
# model physical_model filter         output_parameter
# KNN   MIST           Base           radius            5.534%  1.838%  0.092%
#                      scale_standard radius            5.237%    1.6%  0.091%
#                      scale_robust   radius            5.339%   1.68%  0.087%
# ...

# %% [markdown]
# Le filtre scale_quantile est le meileur scaling

# %% [markdown]
# #### Filtre choisi
#
# Le filtre scale_quantile est choisi parce qu'il donne des bons résultats pour la T_eff et les meilleurs résultats pour le log_g et le rayon.
#
# KNN	MIST	scale_quantile	T_eff	3.345 - 5.379	0.977	2.601%	0.69%	0.083%	0.988	45.011%	75 : 0.216% / 90 : 1.38% / 95 : 3.595% / 99 : 12.027%	7.903
#
# KNN	MIST	scale_quantile	log_g	-1.083 - 6.259	0.875	5.861%	1.746%	0.073%	0.936	77.199%	75 : 0.265% / 90 : 4.349% / 95 : 12.511% / 99 : 28.675%	7.903
#
# KNN	MIST	scale_quantile	radius	-0.997 - 3.129	0.915	5.217%	1.575%	0.09%	0.957	68.651%	75 : 0.282% / 90 : 3.872% / 95 : 11.135% / 99 : 25.516%	7.903

# %% [markdown]
# ### Random forest

# %% [markdown]
# #### T_eff parameter

# %%
compare_metrics(path, value_rounding=3, relative_values=False, 
                output_parameters=["T_eff"],
                physical_models=["MIST"],
                model_names=["random_forest"],
                categories=["Global"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                                    value range  \
# model         physical_model filter            output_parameter
# random_forest MIST           Base              T_eff             3.345 - 5.379
#                              Base_old          T_eff             3.345 - 5.379
#                              mass_smaller_14   T_eff             3.345 - 4.634
#                              mass_smaller_3    T_eff             3.345 - 4.301
#                              mass_smaller_30   T_eff             3.345 - 5.354
#                              scale_power       T_eff             3.345 - 5.379
#                              scale_power_14    T_eff             3.345 - 4.634
#                              scale_quantile    T_eff             3.345 - 5.379
#                              scale_quantile_14 T_eff             3.345 - 4.634
# ...

# %% [markdown]
# Filtre Base donne les meilleurs résultats relatif, mass_smaller_14 et ses scaling donne les meilleurs résultats absolus

# %%
compare_metrics(path, value_rounding=3, relative_values=True, 
                output_parameters=["T_eff"],
                physical_models=["MIST"],
                model_names=["random_forest"],
                categories=["Global"],
                data_filters=["Base", "scale_standard", "scale_robust", "scale_quantile", "scale_power"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                                 value range  \
# model         physical_model filter         output_parameter
# random_forest MIST           Base           T_eff             3.345 - 5.379
#                              scale_standard T_eff             3.345 - 5.379
#                              scale_robust   T_eff             3.345 - 5.379
#                              scale_quantile T_eff             3.345 - 5.379
#                              scale_power    T_eff             3.345 - 5.379
#
#                                                                 RVE    RMSE  \
# model         physical_model filter         output_parameter
# random_forest MIST           Base           T_eff             0.967  3.079%
#                              scale_standard T_eff             0.967  3.079%
#                              scale_robust   T_eff             0.967  3.079%
# ...

# %% [markdown]
# Tous les filtres sont équivalents

# %% [markdown]
# #### log_g parameter

# %%
compare_metrics(path, value_rounding=3, relative_values=True, 
                output_parameters=["log_g"],
                physical_models=["MIST"],
                model_names=["random_forest"],
                categories=["Global"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                                     value range  \
# model         physical_model filter            output_parameter
# random_forest MIST           Base              log_g             -1.083 - 6.259
#                              Base_old          log_g             -1.145 - 6.259
#                              mass_smaller_14   log_g             -1.083 - 5.433
#                              mass_smaller_3    log_g             -1.075 - 5.433
#                              mass_smaller_30   log_g             -1.075 - 6.243
#                              scale_power       log_g             -1.083 - 6.259
#                              scale_power_14    log_g             -1.083 - 5.433
#                              scale_quantile    log_g             -1.083 - 6.259
#                              scale_quantile_14 log_g             -1.083 - 5.433
# ...

# %% [markdown]
# le filtre Base et ses scaling donne les meilleurs résultats

# %%
compare_metrics(path, value_rounding=3, relative_values=True, 
                output_parameters=["log_g"],
                physical_models=["MIST"],
                model_names=["random_forest"],
                categories=["Global"],
                data_filters=["Base", "scale_standard", "scale_robust", "scale_quantile", "scale_power"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                                  value range  \
# model         physical_model filter         output_parameter
# random_forest MIST           Base           log_g             -1.083 - 6.259
#                              scale_standard log_g             -1.083 - 6.259
#                              scale_robust   log_g             -1.083 - 6.259
#                              scale_quantile log_g             -1.083 - 6.259
#                              scale_power    log_g             -1.083 - 6.259
#
#                                                                RVE    RMSE  \
# model         physical_model filter         output_parameter
# random_forest MIST           Base           log_g             0.82  7.031%
#                              scale_standard log_g             0.82  7.031%
#                              scale_robust   log_g             0.82  7.031%
# ...

# %% [markdown]
# Tous les filtres sont équivalents

# %% [markdown]
# #### Radius parameter

# %%
compare_metrics(path, value_rounding=3, relative_values=False, 
                output_parameters=["radius"],
                physical_models=["MIST"],
                model_names=["random_forest"],
                categories=["Global"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                                     value range  \
# model         physical_model filter            output_parameter
# random_forest MIST           Base              radius            -0.997 - 3.129
#                              Base_old          radius            -0.997 - 3.129
#                              mass_smaller_14   radius            -0.997 - 3.082
#                              mass_smaller_3    radius            -0.997 - 2.781
#                              mass_smaller_30   radius             -0.997 - 3.13
#                              scale_power       radius            -0.997 - 3.129
#                              scale_power_14    radius            -0.997 - 3.082
#                              scale_quantile    radius            -0.997 - 3.129
#                              scale_quantile_14 radius            -0.997 - 3.082
# ...

# %% [markdown]
# Filtre Base et ses scaling donne les meilleurs résultats

# %%
compare_metrics(path, value_rounding=3, relative_values=True, 
                output_parameters=["radius"],
                physical_models=["MIST"],
                model_names=["random_forest"],
                categories=["Global"],
                data_filters=["Base", "scale_standard", "scale_robust", "scale_quantile", "scale_power"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                                  value range  \
# model         physical_model filter         output_parameter
# random_forest MIST           Base           radius            -0.997 - 3.129
#                              scale_standard radius            -0.997 - 3.129
#                              scale_robust   radius            -0.997 - 3.129
#                              scale_quantile radius            -0.997 - 3.129
#                              scale_power    radius            -0.997 - 3.129
#
#                                                                 RVE    RMSE  \
# model         physical_model filter         output_parameter
# random_forest MIST           Base           radius            0.878  6.257%
#                              scale_standard radius            0.878  6.258%
#                              scale_robust   radius            0.878  6.257%
# ...

# %% [markdown]
# Tous les filtres sont équivalents

# %% [markdown]
# #### Filtre choisi
#
# Le filtre scale_quantile est choisi parce qu'il donne des résultats un peu meilleurs que les autres filtres pour le log_g et le rayon et est donne des bons résultats pour la T_eff.
#
# random_forest	MIST	scale_quantile	T_eff	3.345 - 5.379	0.967	3.074%	0.79%	0.051%	0.984	45.473%	75 : 0.193% / 90 : 1.528% / 95 : 4.278% / 99 : 15.537%	284.082
#
# random_forest	MIST	scale_quantile	log_g	-1.083 - 6.259	0.82	7.024%	2.072%	0.056%	0.908	77.229%	75 : 0.251% / 90 : 4.517% / 95 : 15.624% / 99 : 35.338%	284.082
#
# random_forest	MIST	scale_quantile	radius	-0.997 - 3.129	0.878	6.251%	1.849%	0.057%	0.938	68.713%	75 : 0.232% / 90 : 4.024% / 95 : 13.903% / 99 : 31.453%	284.082

# %% [markdown]
# ### XGBoost

# %% [markdown]
# #### T_eff parameter

# %%
compare_metrics(path, value_rounding=3, relative_values=False, 
                output_parameters=["T_eff"],
                physical_models=["MIST"],
                model_names=["XGBoost"],
                categories=["Global"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                              value range  \
# model   physical_model filter            output_parameter
# XGBoost MIST           Base              T_eff             3.345 - 5.379
#                        Base_old          T_eff             3.345 - 5.379
#                        mass_smaller_14   T_eff             3.345 - 4.634
#                        mass_smaller_3    T_eff             3.345 - 4.301
#                        mass_smaller_30   T_eff             3.345 - 5.354
#                        scale_power       T_eff             3.345 - 5.379
#                        scale_power_14    T_eff             3.345 - 4.634
#                        scale_quantile    T_eff             3.345 - 5.379
#                        scale_quantile_14 T_eff             3.345 - 4.634
#                        scale_robust      T_eff             3.345 - 5.379
# ...

# %% [markdown]
# Filtre Base donne les meilleurs résultats relatif, mass_smaller_14 et ses scaling donne les meilleurs résultats absolus

# %%
compare_metrics(path, value_rounding=3, relative_values=True, 
                output_parameters=["T_eff"],
                physical_models=["MIST"],
                model_names=["XGBoost"],
                categories=["Global"],
                data_filters=["Base", "scale_standard", "scale_robust", "scale_quantile", "scale_power"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                           value range    RVE  \
# model   physical_model filter         output_parameter
# XGBoost MIST           Base           T_eff             3.345 - 5.379  0.901
#                        scale_standard T_eff             3.345 - 5.379  0.901
#                        scale_robust   T_eff             3.345 - 5.379  0.901
#                        scale_quantile T_eff             3.345 - 5.379  0.901
#                        scale_power    T_eff             3.345 - 5.379  0.901
#
#                                                           RMSE     MAE  \
# model   physical_model filter         output_parameter
# XGBoost MIST           Base           T_eff             5.357%  3.387%
#                        scale_standard T_eff             5.354%  3.384%
#                        scale_robust   T_eff             5.355%  3.382%
# ...

# %% [markdown]
# Tous les filtres sont équivalents

# %% [markdown]
# #### log_g parameter

# %%
compare_metrics(path, value_rounding=3, relative_values=False, 
                output_parameters=["log_g"],
                physical_models=["MIST"],
                model_names=["XGBoost"],
                categories=["Global"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                               value range  \
# model   physical_model filter            output_parameter
# XGBoost MIST           Base              log_g             -1.083 - 6.259
#                        Base_old          log_g             -1.145 - 6.259
#                        mass_smaller_14   log_g             -1.083 - 5.433
#                        mass_smaller_3    log_g             -1.075 - 5.433
#                        mass_smaller_30   log_g             -1.075 - 6.243
#                        scale_power       log_g             -1.083 - 6.259
#                        scale_power_14    log_g             -1.083 - 5.433
#                        scale_quantile    log_g             -1.083 - 6.259
#                        scale_quantile_14 log_g             -1.083 - 5.433
#                        scale_robust      log_g             -1.083 - 6.259
# ...

# %% [markdown]
# Filtre Base donne les meilleurs résultats

# %%
compare_metrics(path, value_rounding=3, relative_values=True, 
                output_parameters=["log_g"],
                physical_models=["MIST"],
                model_names=["XGBoost"],
                categories=["Global"],
                data_filters=["Base", "scale_standard", "scale_robust", "scale_quantile", "scale_power"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                            value range    RVE  \
# model   physical_model filter         output_parameter
# XGBoost MIST           Base           log_g             -1.083 - 6.259  0.743
#                        scale_standard log_g             -1.083 - 6.259  0.743
#                        scale_robust   log_g             -1.083 - 6.259  0.742
#                        scale_quantile log_g             -1.083 - 6.259  0.744
#                        scale_power    log_g             -1.083 - 6.259  0.743
#
#                                                           RMSE     MAE  \
# model   physical_model filter         output_parameter
# XGBoost MIST           Base           log_g             8.391%  5.419%
#                        scale_standard log_g              8.39%  5.415%
#                        scale_robust   log_g             8.405%   5.43%
# ...

# %% [markdown]
# Tous les filtres sont équivalents

# %% [markdown]
# #### Radius parameter

# %%
compare_metrics(path, value_rounding=3, relative_values=False, 
                output_parameters=["radius"],
                physical_models=["MIST"],
                model_names=["XGBoost"],
                categories=["Global"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                               value range  \
# model   physical_model filter            output_parameter
# XGBoost MIST           Base              radius            -0.997 - 3.129
#                        Base_old          radius            -0.997 - 3.129
#                        mass_smaller_14   radius            -0.997 - 3.082
#                        mass_smaller_3    radius            -0.997 - 2.781
#                        mass_smaller_30   radius             -0.997 - 3.13
#                        scale_power       radius            -0.997 - 3.129
#                        scale_power_14    radius            -0.997 - 3.082
#                        scale_quantile    radius            -0.997 - 3.129
#                        scale_quantile_14 radius            -0.997 - 3.082
#                        scale_robust      radius            -0.997 - 3.129
# ...

# %% [markdown]
# Filtre Base donne les meilleurs résultats

# %%
compare_metrics(path, value_rounding=3, relative_values=True, 
                output_parameters=["radius"],
                physical_models=["MIST"],
                model_names=["XGBoost"],
                categories=["Global"],
                data_filters=["Base", "scale_standard", "scale_robust", "scale_quantile", "scale_power"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                            value range    RVE  \
# model   physical_model filter         output_parameter
# XGBoost MIST           Base           radius            -0.997 - 3.129  0.825
#                        scale_standard radius            -0.997 - 3.129  0.825
#                        scale_robust   radius            -0.997 - 3.129  0.825
#                        scale_quantile radius            -0.997 - 3.129  0.825
#                        scale_power    radius            -0.997 - 3.129  0.825
#
#                                                           RMSE     MAE  \
# model   physical_model filter         output_parameter
# XGBoost MIST           Base           radius            7.479%  4.815%
#                        scale_standard radius            7.478%   4.82%
#                        scale_robust   radius            7.485%  4.825%
# ...

# %% [markdown]
# Tous les filtres sont équivalents

# %% [markdown]
# #### Filtre choisi
#
# Le filtre Base est choisi parce qu'il donne les meilleurs résultats pour le log_g et la masse et donne des bons résultats pour la T_eff.
#
# XGBoost	MIST	Base	T_eff	3.345 - 5.379	0.901	5.357%	3.387%	1.698%	0.949	42.951%	75 : 4.819% / 90 : 9.016% / 95 : 12.372% / 99 : 18.363%	17.973
#
# XGBoost	MIST	Base	log_g	-1.083 - 6.259	0.743	8.391%	5.419%	2.76%	0.863	68.084%	75 : 8.239% / 90 : 14.63% / 95 : 18.601% / 99 : 26.672%	17.973
#
# XGBoost	MIST	Base	radius	-0.997 - 3.129	0.825	7.479%	4.815%	2.424%	0.909	62.531%	75 : 7.315% / 90 : 13.043% / 95 : 16.629% / 99 : 23.855%	17.973

# %% [markdown]
# ### MLP

# %% [markdown]
# #### T_eff parameter

# %%
compare_metrics(path, value_rounding=3, relative_values=False, 
                output_parameters=["T_eff"],
                physical_models=["MIST"],
                model_names=["mlp"],
                categories=["Global"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                            value range    RVE  \
# model physical_model filter            output_parameter
# mlp   MIST           Base              T_eff             3.345 - 5.379  0.850
#                      Base_old          T_eff             3.345 - 5.379  0.761
#                      mass_smaller_14   T_eff             3.345 - 4.634  0.802
#                      mass_smaller_3    T_eff             3.345 - 4.301  0.732
#                      mass_smaller_30   T_eff             3.345 - 5.354  0.719
#                      scale_power       T_eff             3.345 - 5.379  0.899
#                      scale_power_14    T_eff             3.345 - 4.634  0.868
#                      scale_quantile    T_eff             3.345 - 5.379  0.883
#                      scale_quantile_14 T_eff             3.345 - 4.634  0.856
#                      scale_robust      T_eff             3.345 - 5.379  0.888
# ...

# %% [markdown]
# Filtre Base donne les meilleurs résultats relatif, mass_smaller_14 et ses scaling donne les meilleurs résultats absolus

# %%
compare_metrics(path, value_rounding=3, relative_values=True, 
                output_parameters=["T_eff"],
                physical_models=["MIST"],
                model_names=["mlp"],
                categories=["Global"],
                data_filters=["Base", "scale_standard", "scale_robust", "scale_quantile", "scale_power"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                         value range    RVE  \
# model physical_model filter         output_parameter
# mlp   MIST           Base           T_eff             3.345 - 5.379  0.850
#                      scale_standard T_eff             3.345 - 5.379  0.864
#                      scale_robust   T_eff             3.345 - 5.379  0.888
#                      scale_quantile T_eff             3.345 - 5.379  0.883
#                      scale_power    T_eff             3.345 - 5.379  0.899
#
#                                                         RMSE     MAE   MedAE  \
# model physical_model filter         output_parameter
# mlp   MIST           Base           T_eff             6.617%  4.513%  2.709%
#                      scale_standard T_eff             6.327%  4.459%  2.965%
#                      scale_robust   T_eff             5.692%  3.682%  2.148%
# ...

# %% [markdown]
# Le fitre scale_power donne les meilleurs résultats.

# %% [markdown]
# #### log_g parameter

# %%
compare_metrics(path, value_rounding=3, relative_values=False, 
                output_parameters=["log_g"],
                physical_models=["MIST"],
                model_names=["mlp"],
                categories=["Global"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                             value range  \
# model physical_model filter            output_parameter
# mlp   MIST           Base              log_g             -1.083 - 6.259
#                      Base_old          log_g             -1.145 - 6.259
#                      mass_smaller_14   log_g             -1.083 - 5.433
#                      mass_smaller_3    log_g             -1.075 - 5.433
#                      mass_smaller_30   log_g             -1.075 - 6.243
#                      scale_power       log_g             -1.083 - 6.259
#                      scale_power_14    log_g             -1.083 - 5.433
#                      scale_quantile    log_g             -1.083 - 6.259
#                      scale_quantile_14 log_g             -1.083 - 5.433
#                      scale_robust      log_g             -1.083 - 6.259
# ...

# %% [markdown]
# Filtre Base donne les meilleurs résultats

# %%
compare_metrics(path, value_rounding=3, relative_values=True, 
                output_parameters=["log_g"],
                physical_models=["MIST"],
                model_names=["mlp"],
                categories=["Global"],
                data_filters=["Base", "scale_standard", "scale_robust", "scale_quantile", "scale_power"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                          value range    RVE  \
# model physical_model filter         output_parameter
# mlp   MIST           Base           log_g             -1.083 - 6.259  0.642
#                      scale_standard log_g             -1.083 - 6.259  0.683
#                      scale_robust   log_g             -1.083 - 6.259  0.734
#                      scale_quantile log_g             -1.083 - 6.259  0.718
#                      scale_power    log_g             -1.083 - 6.259  0.766
#
#                                                         RMSE     MAE   MedAE  \
# model physical_model filter         output_parameter
# mlp   MIST           Base           log_g             9.966%  6.544%  3.418%
#                      scale_standard log_g             9.328%  5.952%  2.765%
#                      scale_robust   log_g             8.553%  5.051%  1.777%
# ...

# %% [markdown]
# Le fitre scale_power donne les meilleurs résultats.

# %% [markdown]
# #### Radius parameter

# %%
compare_metrics(path, value_rounding=3, relative_values=False, 
                output_parameters=["radius"],
                physical_models=["MIST"],
                model_names=["mlp"],
                categories=["Global"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                             value range  \
# model physical_model filter            output_parameter
# mlp   MIST           Base              radius            -0.997 - 3.129
#                      Base_old          radius            -0.997 - 3.129
#                      mass_smaller_14   radius            -0.997 - 3.082
#                      mass_smaller_3    radius            -0.997 - 2.781
#                      mass_smaller_30   radius             -0.997 - 3.13
#                      scale_power       radius            -0.997 - 3.129
#                      scale_power_14    radius            -0.997 - 3.082
#                      scale_quantile    radius            -0.997 - 3.129
#                      scale_quantile_14 radius            -0.997 - 3.082
#                      scale_robust      radius            -0.997 - 3.129
# ...

# %% [markdown]
# Filtre Base donne les meilleurs résultats

# %%
compare_metrics(path, value_rounding=3, relative_values=True, 
                output_parameters=["radius"],
                physical_models=["MIST"],
                model_names=["mlp"],
                categories=["Global"],
                data_filters=["Base", "scale_standard", "scale_robust", "scale_quantile", "scale_power"]
                )
# Out:
# Results for the Global category with a value of 1.0
#                                                          value range    RVE  \
# model physical_model filter         output_parameter
# mlp   MIST           Base           radius            -0.997 - 3.129  0.757
#                      scale_standard radius            -0.997 - 3.129  0.780
#                      scale_robust   radius            -0.997 - 3.129  0.817
#                      scale_quantile radius            -0.997 - 3.129  0.808
#                      scale_power    radius            -0.997 - 3.129  0.841
#
#                                                         RMSE     MAE   MedAE  \
# model physical_model filter         output_parameter
# mlp   MIST           Base           radius            8.875%  5.857%  3.046%
#                      scale_standard radius            8.383%  5.465%  2.774%
#                      scale_robust   radius            7.652%  4.642%  1.947%
# ...

# %% [markdown]
# Le fitre scale_power donne les meilleurs résultats.

# %% [markdown]
# #### Filtre choisi
#
# Le filtre scale_power est choisi parce qu'il donne les meilleurs résultats pour le log_g et le rayon et donne de bons résultats pour la T_eff.
#
# mlp	MIST	scale_power	T_eff	3.345 - 5.379	0.899	5.441%	3.674%	2.518%	0.948	45.953%	75 : 4.436% / 90 : 8.279% / 95 : 12.388% / 99 : 19.627%	431.956
#
# mlp	MIST	scale_power	log_g	-1.083 - 6.259	0.766	8.004%	4.61%	1.574%	0.876	76.124%	75 : 5.932% / 90 : 13.815% / 95 : 19.027% / 99 : 28.256%	431.956
#
# mlp	MIST	scale_power	radius	-0.997 - 3.129	0.841	7.126%	4.128%	1.472%	0.917	66.437%	75 : 5.295% / 90 : 12.279% / 95 : 16.946% / 99 : 25.033%	431.956

# %% [markdown]
# ### Compilation des meilleurs modèles

# %% [markdown]
# #### T_eff parameter

# %% [markdown]
# | model | physical_model | filter | output_parameter | value range | RVE | RMSE | MAE | MedAE | CORR | MAX_ER | Percentiles | time |
# |---|---|---|---|---|---|---|---|---|---|---|---|---|
# | linear_regression | MIST | scale_power | T_eff | 3.345 - 5.379 | 0.774 | 8.08% | 6.191% | 5.401% | 0.880 | 46.38% | 75 : 8.004% / 90 : 11.298% / 95 : 16.575% / 99 : 26.884% | 10.220 |
# | decision_tree | MIST | Base | T_eff | 3.345 - 5.379 | 0.950 | 3.794% | 0.913% | 0.086% | 0.975 | 46.738% | 75 : 0.21% / 90 : 1.065% / 95 : 4.791% / 99 : 20.817% | 17.940 |
# | KNN | MIST | scale_quantile | T_eff | 3.345 - 5.379 | 0.977 | 2.601% | 0.69% | 0.083% | 0.988 | 45.011% | 75 : 0.216% / 90 : 1.38% / 95 : 3.595% / 99 : 12.027% | 7.903 |
# | random_forest | MIST | scale_quantile | T_eff | 3.345 - 5.379 | 0.967 | 3.074% | 0.79% | 0.051% | 0.984 | 45.473% | 75 : 0.193% / 90 : 1.528% / 95 : 4.278% / 99 : 15.537% | 284.082 |
# | XGBoost | MIST | Base | T_eff | 3.345 - 5.379 | 0.901 | 5.357% | 3.387% | 1.698% | 0.949 | 42.951% | 75 : 4.819% / 90 : 9.016% / 95 : 12.372% / 99 : 18.363% | 17.973 |
# | mlp | MIST | scale_power | T_eff | 3.345 - 5.379 | 0.899 | 5.441% | 3.674% | 2.518% | 0.948 | 45.953% | 75 : 4.436% / 90 : 8.279% / 95 : 12.388% / 99 : 19.627% | 431.956 |

# %% [markdown]
# The best models in order for the T_eff from best to worst are:
#
# 1. KNN
# 2. Random forest
# 3. Decision Tree
# 4. XGBoost
# 5. MLP
# 6. Linear regression (worse results than any other modelon all metrics)

# %% [markdown]
# #### log_g parameter

# %% [markdown]
# | model | physical_model | filter | output_parameter | value range | RVE | RMSE | MAE | MedAE | CORR | MAX_ER | Percentiles | time |
# |---|---|---|---|---|---|---|---|---|---|---|---|---|
# | linear_regression | MIST | scale_power | log_g | -1.083 - 6.259 | 0.411 | 12.707% | 10.177% | 9.067% | 0.641 | 63.136% | 75 : 13.159% / 90 : 20.09% / 95 : 25.591% / 99 : 35.715% | 10.220 |
# | decision_tree | MIST | Base | log_g | -1.083 - 6.259 | 0.729 | 8.63% | 2.373% | 0.104% | 0.865 | 77.218% | 75 : 0.262% / 90 : 2.885% / 95 : 18.53% / 99 : 45.586% | 17.940 |
# | KNN | MIST | scale_quantile | log_g | -1.083 - 6.259 | 0.875 | 5.861% | 1.746% | 0.073% | 0.936 | 77.199% | 75 : 0.265% / 90 : 4.349% / 95 : 12.511% / 99 : 28.675% | 7.903 |
# | random_forest | MIST | scale_quantile | log_g | -1.083 - 6.259 | 0.82 | 7.024% | 2.072% | 0.056% | 0.908 | 77.229% | 75 : 0.251% / 90 : 4.517% / 95 : 15.624% / 99 : 35.338% | 284.082 |
# | XGBoost | MIST | Base | log_g | -1.083 - 6.259 | 0.743 | 8.391% | 5.419% | 2.76% | 0.863 | 68.084% | 75 : 8.239% / 90 : 14.63% / 95 : 18.601% / 99 : 26.672% | 17.973 |
# | mlp | MIST | scale_power | log_g | -1.083 - 6.259 | 0.766 | 8.004% | 4.61% | 1.574% | 0.876 | 76.124% | 75 : 5.932% / 90 : 13.815% / 95 : 19.027% / 99 : 28.256% | 431.956 |

# %% [markdown]
# The best models in order for the log_g from best to worst are:
#
# 1. KNN
# 2. Random forest
# 3. Decision Tree
# 4. XGBoost
# 5. MLP
# 6. Linear regression (worse results than any other modelon all metrics)

# %% [markdown]
# #### Radius parameter

# %% [markdown]
# | model | physical_model | filter | output_parameter | value range | RVE | RMSE | MAE | MedAE | CORR | MAX_ER | Percentiles | time |
# |---|---|---|---|---|---|---|---|---|---|---|---|---|
# | linear_regression | MIST | scale_power | radius | -0.997 - 3.129 | 0.602 | 11.286% | 9.059% | 8.273% | 0.776 | 57.275% | 75 : 11.683% / 90 : 17.719% / 95 : 22.492% / 99 : 31.794% | 10.220 |
# | decision_tree | MIST | Base | radius | -0.997 - 3.129 | 0.816 | 7.681% | 2.124% | 0.113% | 0.908 | 68.704% | 75 : 0.249% / 90 : 2.572% / 95 : 16.512% / 99 : 40.591% | 17.940 |
# | KNN | MIST | scale_quantile | radius | -0.997 - 3.129 | 0.915 | 5.217% | 1.575% | 0.09% | 0.957 | 68.651% | 75 : 0.282% / 90 : 3.872% / 95 : 11.135% / 99 : 25.516% | 7.903 |
# | random_forest | MIST | scale_quantile | radius | -0.997 - 3.129 | 0.878 | 6.251% | 1.849% | 0.057% | 0.938 | 68.713% | 75 : 0.232% / 90 : 4.024% / 95 : 13.903% / 99 : 31.453% | 284.082 |
# | XGBoost | MIST | Base | radius | -0.997 - 3.129 | 0.825 | 7.479% | 4.815% | 2.424% | 0.909 | 62.531% | 75 : 7.315% / 90 : 13.043% / 95 : 16.629% / 99 : 23.855% | 17.973 |
# | mlp | MIST | scale_power | radius | -0.997 - 3.129 | 0.841 | 7.126% | 4.128% | 1.472% | 0.917 | 66.437% | 75 : 5.295% / 90 : 12.279% / 95 : 16.946% / 99 : 25.033% | 431.956 |

# %% [markdown]
# The best models in order for the radius from best to worst are:
#
# 1. KNN
# 2. Random forest
# 3. Decision Tree
# 4. XGBoost
# 5. MLP
# 6. Linear regression (worse results than any other modelon all metrics)

# %% [markdown]
# ### Models to be fine-tuned
#
# KNN with scale_quantile and Random forest with scale_quantile

# %% [markdown]
# ## Base vs scaling

# %% [markdown]
# ### T_eff parameter

# %%
compare_metrics(path, value_rounding=3, relative_values=True,
                output_parameters=["T_eff"],
                physical_models=["MIST"],
                data_filters=["Base", "scale_standard", "scale_robust", "scale_power", "scale_quantile"])
# Out:
# Results for the Global category with a value of 1.0
#                                                                                             value range  \
# model             physical_model filter         output_parameter
# decision_tree     MIST           Base           T_eff             3.344668191350628 - 5.378801600728572
#                                  scale_standard T_eff             3.344668191350628 - 5.378801600728572
#                                  scale_robust   T_eff             3.344668191350628 - 5.378801600728572
#                                  scale_power    T_eff             3.344668191350628 - 5.378801600728572
#                                  scale_quantile T_eff             3.344668191350628 - 5.378801600728572
# KNN               MIST           Base           T_eff             3.344668191350628 - 5.378801600728572
#                                  scale_standard T_eff             3.344668191350628 - 5.378801600728572
# ...

# %% [markdown]
# ### log_g parameter

# %%
compare_metrics(path, value_rounding=3, relative_values=True,
                output_parameters=["log_g"],
                physical_models=["MIST"],
                data_filters=["Base", "scale_standard", "scale_robust", "scale_power", "scale_quantile"])
# Out:
# Results for the Global category with a value of 1.0
#                                                                                               value range  \
# model             physical_model filter         output_parameter
# decision_tree     MIST           Base           log_g             -1.0828963170617296 - 6.259434356871683
#                                  scale_standard log_g             -1.0828963170617296 - 6.259434356871683
#                                  scale_robust   log_g             -1.0828963170617296 - 6.259434356871683
#                                  scale_power    log_g             -1.0828963170617296 - 6.259434356871683
#                                  scale_quantile log_g             -1.0828963170617296 - 6.259434356871683
# KNN               MIST           Base           log_g             -1.0828963170617296 - 6.259434356871683
#                                  scale_standard log_g             -1.0828963170617296 - 6.259434356871683
# ...

# %% [markdown]
# ### Radius parameter

# %%
compare_metrics(path, value_rounding=3, relative_values=True,
                output_parameters=["radius"],
                physical_models=["MIST"],
                data_filters=["Base", "scale_standard", "scale_robust", "scale_power", "scale_quantile"])
# Out:
# Results for the Global category with a value of 1.0
#                                                                                               value range  \
# model             physical_model filter         output_parameter
# decision_tree     MIST           Base           radius            -0.9974628481553472 - 3.129269620812593
#                                  scale_standard radius            -0.9974628481553472 - 3.129269620812593
#                                  scale_robust   radius            -0.9974628481553472 - 3.129269620812593
#                                  scale_power    radius            -0.9974628481553472 - 3.129269620812593
#                                  scale_quantile radius            -0.9974628481553472 - 3.129269620812593
# KNN               MIST           Base           radius            -0.9974628481553472 - 3.129269620812593
#                                  scale_standard radius            -0.9974628481553472 - 3.129269620812593
# ...

# %% [markdown]
# les résultats avec du scaling sont très proche de Base, il n'y a pas d'intérêt à utilise le scaling pour ce modèle

# %% [markdown]
# ## Base vs Base_old

# %% [markdown]
# | Parameter      | Base                                                    | Base_old                                               |
# | -------------  | ------------------------------------------------------- | ------------------------------------------------------ |
# | age            | Range : 5.0 - 10.3, Mean : 8.1222, Median : 8.15        | Range : 5.0 - 10.3, Mean : 8.4794, Median : 8.6        |
# | mass           | Range : 0.1 - 298.5448, Mean : 11.3677, Median : 2.8697 | Range : 0.1 - 298.5448, Mean : 7.3915, Median : 2.0304 |
# | log_teff       | Range : 3.34 - 5.3788, Mean : 4.0309, Median : 3.8557   | Range : 3.34 - 5.5871, Mean : 3.8475, Median : 3.6808  |
# | log_g          | Range : -1.08 - 7.9405, Mean : 3.515, Median : 3.8557   | Range : -1.14 - 8.6121, Mean : 2.1347, Median : 2.0681 |
# | log_R          | Range : -1.86 - 3.1298, Mean : 0.7296, Median : 0.6976  | Range : -2.09 - 3.1298, Mean : 1.3543, Median : 1.4604 |

# %%
compare_metrics(path, value_rounding=5,
                output_parameters=["T_eff", "log_g", "radius"],
                physical_models=["MIST"],
                model_names=["random_forest"],
                data_filters=["Base_old"])
# Out:
# Results for the Global category with a value of 1.0
#                                                                value range  \
# model         physical_model filter   output_parameter
# random_forest MIST           Base_old T_eff              3.34467 - 5.37868
#                                       log_g              -1.1449 - 6.25943
#                                       radius            -0.99747 - 3.12927
#
#                                                             RVE     RMSE  \
# model         physical_model filter   output_parameter
# random_forest MIST           Base_old T_eff             0.84057  0.13893
#                                       log_g             0.53144  1.30405
#                                       radius            0.52940  0.65205
#
#                                                             MAE    MedAE  \
# model         physical_model filter   output_parameter
# random_forest MIST           Base_old T_eff             0.06595  0.00496
# ...

# %%
compare_metrics(path, value_rounding=5,
                output_parameters=["T_eff", "log_g", "radius"],
                physical_models=["MIST"],
                model_names=["random_forest"],
                data_filters=["Base", "Base_old"])
# Out:
# Results for the Global category with a value of 1.0
#                                                                value range  \
# model         physical_model filter   output_parameter
# random_forest MIST           Base     T_eff               3.34467 - 5.3788
#                                       log_g              -1.0829 - 6.25943
#                                       radius            -0.99746 - 3.12927
#                              Base_old T_eff              3.34467 - 5.37868
#                                       log_g              -1.1449 - 6.25943
#                                       radius            -0.99747 - 3.12927
#
#                                                             RVE     RMSE  \
# model         physical_model filter   output_parameter
# random_forest MIST           Base     T_eff             0.96719  0.06264
#                                       log_g             0.81983  0.51625
# ...

# %%
compare_metrics(path, value_rounding=5, relative_values=True,
                output_parameters=["T_eff", "log_g", "radius"],
                physical_models=["MIST"],
                model_names=["random_forest"],
                data_filters=["Base", "Base_old"])
# Out:
# Results for the Global category with a value of 1.0
#                                                                                     value range  \
# model         physical_model filter   output_parameter
# random_forest MIST           Base     T_eff               3.344668191350628 - 5.378801600728572
#                                       log_g             -1.0828963170617296 - 6.259434356871683
#                                       radius            -0.9974628481553472 - 3.129269620812593
#                              Base_old T_eff               3.344668191350628 - 5.378675973625695
#                                       log_g               -1.14489780699774 - 6.259434356871683
#                                       radius            -0.9974747647513328 - 3.129269620812593
#
#                                                                        RVE  \
# model         physical_model filter   output_parameter
# ...

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Removing phase 4 and 5 (EAGB and TPAGB) improves the results by a lot.
#
# Since there are no more superposition possible between phase 0 and 5 (MS and TPAGB), the results for the phase 0 drastically improved (2x to 4x better results for different statistics)
#
# Phase 2 also improved (RGB), although not as much as phase 0.
#
# Same with phase 3 (CHeB).

# %% [markdown]
# However, the results are not that good. Even for Random forest, the RMSE is quite high (3, 7 and 6% relative error).

# %% [markdown]
# ## Base vs mass_filtered

# %% [markdown]
# | Parameter      | Base                                                    | mass_filtered_smaller_3                                | mass_filtered_smaller_14                               | mass_filtered_smaller_30                               |
# | -------------  | ------------------------------------------------------- | ------------------------------------------------------ | ------------------------------------------------------ | ------------------------------------------------------ |
# | age            | Range : 5.0 - 10.3, Mean : 8.1222, Median : 8.15        | Range : 6.2 - 10.3, Mean : 9.1366, Median : 9.2        | Range : 5.0 - 10.3, Mean : 8.4693, Median : 8.5        | Range : 0.1 - 29.9991, Mean : 5.0208, Median : 2.4047  |
# | mass           | Range : 0.1 - 298.5448, Mean : 11.3677, Median : 2.8697 | Range : 0.1 - 3.0, Mean : 1.3172, Median : 1.1821      | Range : 0.1 - 13.9995, Mean : 3.3831, Median : 2.0289  | Range : 0.1 - 3.0, Mean : 1.4429, Median : 1.3194      |
# | log_teff       | Range : 3.34 - 5.3788, Mean : 4.0309, Median : 3.8557   | Range : 3.34 - 5.2138, Mean : 3.8022, Median : 3.7554  | Range : 3.34 - 5.2138, Mean : 3.9383, Median : 3.867   | Range : 3.34 - 5.3542, Mean : 3.9845, Median : 3.9191  |
# | log_g          | Range : -1.08 - 7.9405, Mean : 3.515, Median : 3.8557   | Range : -1.08 - 7.9405, Mean : 3.6564, Median : 4.1712 | Range : -1.08 - 7.9405, Mean : 3.5574, Median : 3.9537 | Range : -1.08 - 7.9405, Mean : 3.5437, Median : 3.9117 |
# | log_R          | Range : -1.86 - 3.1298, Mean : 0.7296, Median : 0.6976  | Range : -1.86 - 2.7813, Mean : 0.4084, Median : 0.2349 | Range : -1.86 - 3.0828, Mean : 0.6007, Median : 0.5357 | Range : -1.86 - 3.1298, Mean : 0.6537, Median : 0.6118 |

# %% [markdown]
# ### T_eff parameter

# %%
compare_metrics(path, value_rounding=5, relative_values=False,
                output_parameters=["T_eff"],
                physical_models=["MIST"],
                data_filters=["Base", "mass_smaller_3", "mass_smaller_14", "mass_smaller_30"])
# Out:
# Results for the Global category with a value of 1.0
#                                                                          value range  \
# model             physical_model filter          output_parameter
# decision_tree     MIST           Base            T_eff              3.34467 - 5.3788
#                                  mass_smaller_3  T_eff             3.34467 - 4.30134
#                                  mass_smaller_14 T_eff             3.34467 - 4.63449
#                                  mass_smaller_30 T_eff             3.34467 - 5.35417
# KNN               MIST           Base            T_eff              3.34467 - 5.3788
#                                  mass_smaller_3  T_eff             3.34467 - 4.30134
#                                  mass_smaller_14 T_eff             3.34467 - 4.63449
#                                  mass_smaller_30 T_eff             3.34467 - 5.35417
# linear_regression MIST           Base            T_eff              3.34467 - 5.3788
# ...

# %% [markdown]
# Every comparison is proportional to the mass.
#
# Linear regression :
# - mass_smaller_3 : worse results than Base on every metric except MAX_ER
# - mass_smaller_14 : worse results than Base on every metric
# - mass_smaller_30 : better results than Base on every metric except P99
#
# Decision tree :
# - mass_smaller_3 : worse results than Base on every metric
# - mass_smaller_14 : worse results than Base on every metric
# - mass_smaller_30 : better/similar results than Base on every metric
#
# KNN :
# - mass_smaller_3 : worse results than Base on every metric except MAX_ER and P99
# - mass_smaller_14 : worse results than Base on every metric except MAX_ER, P90 and P99
# - mass_smaller_30 : better/similar results than Base on every metric
#
# Random forest :
# - mass_smaller_3 : worse results than Base on every metric except MAX_ER
# - mass_smaller_14 : worse results than Base on every metric except P99
# - mass_smaller_30 : better/similar results than Base on every metric
#
# XGBoost :
# - mass_smaller_3 : worse results than Base on every metric except MedAE and MAX_ER
# - mass_smaller_14 : worse results than Base on every metric
# - mass_smaller_30 : better/similar results than Base on every metric
#
# MLP :
# - mass_smaller_3 : worse results than Base on every metric
# - mass_smaller_14 : worse results than Base on every metric
# - mass_smaller_30 : worse results than Base on every metric

# %% [markdown]
# #### Conclusions on T_eff

# %% [markdown]
# mass_smaller_3 is always worse than Base.
#
# mass_smaller_14 is always worse than Base.
#
# mass_smaller_30 is always better or similar to Base.
#
# But it is important to note that the range does not change a lot and the errors without relativity to the range do not have that much of a difference.

# %% [markdown]
# #### Best models for the T_eff parameter
#
# The three best performing models in order for the mass parameter are Random forest, KNN and decision tree.

# %% [markdown]
# ### Radius parameter

# %%
compare_metrics(path, value_rounding=5, relative_values=True,
                output_parameters=["radius"],
                physical_models=["MIST"],
                data_filters=["Base", "mass_smaller_3", "mass_smaller_14", "mass_smaller_30"])
# Out:
# Results for the Global category with a value of 1.0
#                                                                                                 value range  \
# model             physical_model filter          output_parameter
# decision_tree     MIST           Base            radius             -0.9974628481553472 - 3.129269620812593
#                                  mass_smaller_3  radius            -0.9974747647513328 - 2.7813065611193197
#                                  mass_smaller_14 radius             -0.9974747647513328 - 3.082068881511837
#                                  mass_smaller_30 radius            -0.9974628481553472 - 3.1297545143214007
# KNN               MIST           Base            radius             -0.9974628481553472 - 3.129269620812593
#                                  mass_smaller_3  radius            -0.9974747647513328 - 2.7813065611193197
# ...

# %% [markdown]
# Linear regression :
# - mass_smaller_3 : better results than Base on every metric except P99 and MAX_ER
# - mass_smaller_14 : better results than Base on every metric except MAX_ER
# - mass_smaller_30 : better results than Base on every metric
#
# Decision tree :
# - mass_smaller_3 : worse results than Base on every metric
# - mass_smaller_14 : very slightly worse results than Base on every metric
# - mass_smaller_30 : similar results than Base on every metric
#
# KNN :
# - mass_smaller_3 : worse results than Base on every metric
# - mass_smaller_14 : very slightly better results than Base on every metric
# - mass_smaller_30 : very slightly better results than Base on every metric
#
# Random forest :
# - mass_smaller_3 : worse results than Base on every metric
# - mass_smaller_14 : slightly worse/similar results to Base on every metric
# - mass_smaller_30 : similar results to Base on every metric
#
# XGBoost :
# - mass_smaller_3 : similar results to Base on every metric
# - mass_smaller_14 : similar results to Base on every metric
# - mass_smaller_30 : similar results to Base on every metric
#
# MLP :
# - mass_smaller_3 : worse results than Base on every metric
# - mass_smaller_14 : slightly worse/similar results to Base on every metric
# - mass_smaller_30 : worse results than Base on every metric except MAX_ER

# %% [markdown]
# #### Conclusions on radius

# %% [markdown]
# mass_smaller_3 almost always gives worse results than Base.
#
# mass_smaller_14 and mass_smaller_30 give very similar results to Base.
#
# All the results are pretty bad, 5% and more RMSE, 1-2% MAE, very high MAX_ER,...

# %% [markdown]
# #### Best models for the radius parameter
#
# The three best performing models in order for the radius parameter are KNN, Random forest and Decision tree.

# %% [markdown]
# ### log_g parameter

# %%
compare_metrics(path, value_rounding=5, relative_values=True,
                output_parameters=["log_g"],
                physical_models=["MIST"],
                data_filters=["Base", "mass_smaller_3", "mass_smaller_14", "mass_smaller_30"])
# Out:
# Results for the Global category with a value of 1.0
#                                                                                                value range  \
# model             physical_model filter          output_parameter
# decision_tree     MIST           Base            log_g             -1.0828963170617296 - 6.259434356871683
#                                  mass_smaller_3  log_g              -1.074853654540692 - 5.433094523832443
#                                  mass_smaller_14 log_g             -1.0828963170617296 - 5.433094523832443
#                                  mass_smaller_30 log_g               -1.074853654540692 - 6.24337664072263
# KNN               MIST           Base            log_g             -1.0828963170617296 - 6.259434356871683
#                                  mass_smaller_3  log_g              -1.074853654540692 - 5.433094523832443
#                                  mass_smaller_14 log_g             -1.0828963170617296 - 5.433094523832443
# ...

# %% [markdown]
# Linear regression :
# - mass_smaller_3 : similar results to Base on every metric
# - mass_smaller_14 : similar results to Base on every metric
# - mass_smaller_30 : similar results to Base on every metric
#
# Decision tree :
# - mass_smaller_3 : worse results than Base on every metric
# - mass_smaller_14 : worse results than Base on every metric
# - mass_smaller_30 : similar results to Base on every metric
#
# KNN :
# - mass_smaller_3 : worse results than Base on every metric
# - mass_smaller_14 : slightly worse results than Base on every metric
# - mass_smaller_30 : very slightly better results than Base on every metric
#
# Random forest :
# - mass_smaller_3 : worse results than Base on every metric except MAX_ER
# - mass_smaller_14 : slightly worse results than Base on every metric
# - mass_smaller_30 : similar results to Base on every metric
#
# XGBoost :
# - mass_smaller_3 : slightly worse results to Base on every metric
# - mass_smaller_14 : slightly worse results to Base on every metric
# - mass_smaller_30 : similar results to Base on every metric
#
# MLP :
# - mass_smaller_3 : worse results than Base on every metric
# - mass_smaller_14 : worse results than Base on every metric
# - mass_smaller_30 : worse results than Base on every metric

# %% [markdown]
# #### Conclusions on log_g

# %% [markdown]
# mass_smaller_3 almost always gives worse results than Base.
#
# mass_smaller_14 give slightly worse results than Base.
#
# mass_smaller_30 give worse/similar results to Base.
#
# All the results are pretty bad. Same as above, very high MAX_ER, high RMSE,...

# %% [markdown]
# #### Best models for the log_g parameter
#
# The three best performing models in order for the radius parameter are KNN, Random forest and Decision tree.

# %% [markdown]
# ### Conclusion on both

# %% [markdown]
# Using the Base filtering seems to be the best solution for most parameters.
#
# Since mass_smaller_14 is used for model_A_partial, it might still be interesting to use mass_smaller_14; also making it easier to compare with PARSEC
#
# The three models that need to be used are : KNN, Random forest and Decision tree
