# %% [markdown]
# # Results comparison for MIST
#
# In this notebook, I will compare the results of the different models.

# %%
from ML.utils.utils import *

# %%
pre_path = "../../../../../../"
path = pre_path + "results/model_B/default_models"

# %%
compare_metrics(path, value_rounding=3,
                output_parameters=["T_eff", "log_g", "radius"],
                physical_models=["MIST"],
                data_filters=["Base"])
# Out:
#                                                             RVE   RMSE    MAE  \
# model             physical_model filter output_parameter
# decision_tree     MIST           Base   T_eff             0.745  0.176  0.073
#                                         log_g             0.245  1.655  0.729
#                                         radius            0.242  0.827  0.365
# KNN               MIST           Base   T_eff             0.869  0.126  0.059
#                                         log_g             0.625  1.168  0.581
#                                         radius            0.623  0.584  0.291
# linear_regression MIST           Base   T_eff             0.608  0.218  0.182
#                                         log_g             0.124  1.783  1.547
#                                         radius            0.039  0.932  0.799
# mlp               MIST           Base   T_eff             0.755  0.173  0.124
#                                         log_g             0.487  1.367  1.020
#                                         radius            0.483  0.684  0.512
# random_forest     MIST           Base   T_eff             0.841  0.139  0.066
#                                         log_g             0.531  1.304  0.664
#                                         radius            0.529  0.652  0.332
# xgboost           MIST           Base   T_eff             0.805  0.154  0.110
#                                         log_g             0.531  1.304  0.971
#                                         radius            0.527  0.654  0.488
#
#                                                           MedAE   CORR  \
# model             physical_model filter output_parameter
# decision_tree     MIST           Base   T_eff             0.002  0.873
#                                         log_g             0.016  0.623
#                                         radius            0.008  0.621
# KNN               MIST           Base   T_eff             0.005  0.932
#                                         log_g             0.038  0.794
#                                         radius            0.020  0.793
# linear_regression MIST           Base   T_eff             0.173  0.780
#                                         log_g             1.440  0.352
#                                         radius            0.744  0.196
# mlp               MIST           Base   T_eff             0.082  0.869
#                                         log_g             0.817  0.698
#                                         radius            0.407  0.695
# random_forest     MIST           Base   T_eff             0.005  0.918
#                                         log_g             0.044  0.741
#                                         radius            0.022  0.740
# xgboost           MIST           Base   T_eff             0.077  0.897
#                                         log_g             0.799  0.729
#                                         radius            0.402  0.726
#
#                                                           MAX_ER  \
# model             physical_model filter output_parameter
# decision_tree     MIST           Base   T_eff              0.965
#                                         log_g              5.670
#                                         radius             2.835
# KNN               MIST           Base   T_eff              0.978
#                                         log_g              5.668
#                                         radius             2.833
# linear_regression MIST           Base   T_eff              1.116
#                                         log_g              4.388
#                                         radius             2.591
# mlp               MIST           Base   T_eff              0.989
#                                         log_g              5.720
#                                         radius             2.887
# random_forest     MIST           Base   T_eff              0.919
#                                         log_g              5.670
#                                         radius             2.835
# xgboost           MIST           Base   T_eff              0.823
#                                         log_g              5.458
#                                         radius             2.723
#
#                                                                                                           Percentiles  \
# model             physical_model filter output_parameter
# decision_tree     MIST           Base   T_eff              75 : 0.02035 / 90 : 0.31523 / 95 : 0.49769 / 99 : 0.65795
#                                         log_g              75 : 0.19153 / 90 : 3.81959 / 95 : 4.58752 / 99 : 5.14975
#                                         radius             75 : 0.09615 / 90 : 1.90982 / 95 : 2.29252 / 99 : 2.57601
# KNN               MIST           Base   T_eff               75 : 0.0738 / 90 : 0.18674 / 95 : 0.29598 / 99 : 0.55233
#                                         log_g              75 : 0.83595 / 90 : 1.91355 / 95 : 2.98864 / 99 : 4.62544
#                                         radius             75 : 0.41796 / 90 : 0.95684 / 95 : 1.49404 / 99 : 2.31101
# linear_regression MIST           Base   T_eff              75 : 0.28185 / 90 : 0.33888 / 95 : 0.36379 / 99 : 0.45386
#                                         log_g              75 : 2.23264 / 90 : 2.71868 / 95 : 3.04942 / 99 : 3.71545
#                                         radius             75 : 1.15412 / 90 : 1.36507 / 95 : 1.64842 / 99 : 2.13086
# mlp               MIST           Base   T_eff              75 : 0.17438 / 90 : 0.29978 / 95 : 0.37771 / 99 : 0.53169
#                                         log_g              75 : 1.41538 / 90 : 2.24659 / 95 : 2.98849 / 99 : 4.02513
#                                         radius              75 : 0.70845 / 90 : 1.12315 / 95 : 1.49637 / 99 : 2.0207
# random_forest     MIST           Base   T_eff              75 : 0.07244 / 90 : 0.23282 / 95 : 0.35013 / 99 : 0.55785
#                                         log_g              75 : 0.85034 / 90 : 2.47767 / 95 : 3.35985 / 99 : 4.50992
#                                         radius             75 : 0.42522 / 90 : 1.23892 / 95 : 1.68023 / 99 : 2.25488
# xgboost           MIST           Base   T_eff              75 : 0.15376 / 90 : 0.26733 / 95 : 0.33968 / 99 : 0.46983
#                                         log_g               75 : 1.34081 / 90 : 2.09475 / 95 : 2.85642 / 99 : 3.9318
#                                         radius             75 : 0.67425 / 90 : 1.05149 / 95 : 1.42933 / 99 : 1.96479
#
#                                                               time
# model             physical_model filter output_parameter
# decision_tree     MIST           Base   T_eff               34.762
#                                         log_g               34.762
#                                         radius              34.762
# KNN               MIST           Base   T_eff               15.048
#                                         log_g               15.048
#                                         radius              15.048
# linear_regression MIST           Base   T_eff                1.013
#                                         log_g                1.013
#                                         radius               1.013
# mlp               MIST           Base   T_eff             1899.188
#                                         log_g             1899.188
#                                         radius            1899.188
# random_forest     MIST           Base   T_eff              545.453
#                                         log_g              545.453
#                                         radius             545.453
# xgboost           MIST           Base   T_eff               30.673
#                                         log_g               30.673
#                                         radius              30.673
