# %% [markdown]
# # Results comparison for PARSEC with final models of model B

# %%
from ML.utils.utils import *
from physics.Iso_data_handler import Iso_data_handler
from ML.utils.Data_preparator import Data_preparator

# %%
pre_path = "../../../../../../"
path_default = pre_path + "results/model_B/default_models"
path_fine_tuned = pre_path + "results/model_B/fine_tuned_models"
path_final = pre_path + "results/model_B/final_models"

# %% [markdown]
# ## Final model results

# %%
compare_metrics(path_final, value_rounding=3, relative_values=False,
                output_parameters=["T_eff", "log_g", "radius"],
                physical_models=["PARSEC"],
                model_names=["decision_tree"],
                data_filters=["scale_power"],
                categories=["Global"])
# Out:
# Results for the Global category with a value of 1.0
#                                                               value range  \
# model         physical_model filter      output_parameter
# decision_tree PARSEC         scale_power T_eff              3.362 - 4.518
#                                          log_g             -0.347 - 5.345
#                                          radius            -0.976 - 2.832
#
#                                                              RVE   RMSE  \
# model         physical_model filter      output_parameter
# decision_tree PARSEC         scale_power T_eff             0.953  0.039
#                                          log_g             0.829  0.432
#                                          radius            0.874  0.216
#
#                                                              MAE  MedAE  \
# model         physical_model filter      output_parameter
# decision_tree PARSEC         scale_power T_eff             0.013  0.002
#                                          log_g             0.147  0.018
#                                          radius            0.074  0.009
#
#                                                             CORR  MAX_ER  \
# model         physical_model filter      output_parameter
# decision_tree PARSEC         scale_power T_eff             0.976   0.810
#                                          log_g             0.911   4.770
#                                          radius            0.935   2.386
#
#                                                                                                  Percentiles  \
# model         physical_model filter      output_parameter
# decision_tree PARSEC         scale_power T_eff             75 : 0.009 / 90 : 0.035 / 95 : 0.067 / 99 : 0.164
#                                          log_g             75 : 0.073 / 90 : 0.328 / 95 : 0.925 / 99 : 2.093
#                                          radius            75 : 0.037 / 90 : 0.164 / 95 : 0.462 / 99 : 1.047
#
#                                                             time
# model         physical_model filter      output_parameter
# decision_tree PARSEC         scale_power T_eff             0.413
#                                          log_g             0.413
#                                          radius            0.413

# %%
compare_metrics(path_final, value_rounding=3, relative_values=False,
                output_parameters=["T_eff", "log_g", "radius"],
                physical_models=["PARSEC"],
                model_names=["KNN"],
                data_filters=["scale_power"],
                categories=["Global"])
# Out:
# Results for the Global category with a value of 1.0
#                                                       value range    RVE  \
# model physical_model filter      output_parameter
# KNN   PARSEC         scale_power T_eff              3.362 - 4.518  0.950
#                                  log_g             -0.347 - 5.345  0.818
#                                  radius            -0.976 - 2.832  0.866
#
#                                                     RMSE    MAE  MedAE   CORR  \
# model physical_model filter      output_parameter
# KNN   PARSEC         scale_power T_eff             0.041  0.016  0.003  0.975
#                                  log_g             0.446  0.169  0.018  0.905
#                                  radius            0.223  0.085  0.010  0.931
#
#                                                    MAX_ER  \
# model physical_model filter      output_parameter
# KNN   PARSEC         scale_power T_eff              0.785
#                                  log_g              4.412
#                                  radius             2.206
#
#                                                                                          Percentiles  \
# model physical_model filter      output_parameter
# KNN   PARSEC         scale_power T_eff             75 : 0.015 / 90 : 0.046 / 95 : 0.077 / 99 : 0.168
#                                  log_g              75 : 0.127 / 90 : 0.412 / 95 : 0.993 / 99 : 2.09
#                                  radius            75 : 0.063 / 90 : 0.206 / 95 : 0.497 / 99 : 1.046
#
#                                                     time
# model physical_model filter      output_parameter
# KNN   PARSEC         scale_power T_eff             5.096
#                                  log_g             5.096
#                                  radius            5.096

# %%
compare_metrics(path_final, value_rounding=3, relative_values=False,
                output_parameters=["T_eff", "log_g", "radius"],
                physical_models=["PARSEC"],
                model_names=["random_forest"],
                data_filters=["scale_quantile"],
                categories=["Global"])
# Out:
# Results for the Global category with a value of 1.0
#                                                                  value range  \
# model         physical_model filter         output_parameter
# random_forest PARSEC         scale_quantile T_eff              3.362 - 4.518
#                                             log_g             -0.347 - 5.345
#                                             radius            -0.976 - 2.832
#
#                                                                 RVE   RMSE  \
# model         physical_model filter         output_parameter
# random_forest PARSEC         scale_quantile T_eff             0.959  0.037
#                                             log_g             0.841  0.418
#                                             radius            0.882  0.209
#
#                                                                 MAE  MedAE  \
# model         physical_model filter         output_parameter
# random_forest PARSEC         scale_quantile T_eff             0.013  0.002
#                                             log_g             0.147  0.019
#                                             radius            0.073  0.010
#
#                                                                CORR  MAX_ER  \
# model         physical_model filter         output_parameter
# random_forest PARSEC         scale_quantile T_eff             0.979   0.792
#                                             log_g             0.917   4.366
#                                             radius            0.939   2.183
#
#                                                                                                     Percentiles  \
# model         physical_model filter         output_parameter
# random_forest PARSEC         scale_quantile T_eff             75 : 0.009 / 90 : 0.034 / 95 : 0.064 / 99 : 0.156
#                                             log_g             75 : 0.075 / 90 : 0.351 / 95 : 0.909 / 99 : 1.987
#                                             radius            75 : 0.038 / 90 : 0.175 / 95 : 0.454 / 99 : 0.994
#
#                                                                 time
# model         physical_model filter         output_parameter
# random_forest PARSEC         scale_quantile T_eff             14.808
#                                             log_g             14.808
#                                             radius            14.808
