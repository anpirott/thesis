# %% [markdown]
# ## Import

# %%
import joblib

# %%
pre_path = "../../../../../../"
physical_model = "PARSEC"
path_to_final_models_B = 'model/final_models/Model_B/PARSEC/'
path_to_final_models_B_power_scaler = 'model/final_models/Model_B/PARSEC/scalers/power_scaler.pkl'
path_to_final_models_B_quantile_scaler = 'model/final_models/Model_B/PARSEC/scalers/quantile_scaler.pkl'

# %%
# star_mass en masse solaire, log_age en log_10 de l'age en année, metallicity en dex, 
# log_T_eff en log_10 de la température en Kelvin, log_g en log_10 de la gravité en cm/s^2, 
# log_R en log_10 du rayon en rayon solaire, log_L en log_10 de la luminosité en luminosité solaire

sun_params = {"star_mass" : 1, "log_age" : 9.65, "metallicity" : 0, "log_Teff" : 3.76, "log_g" : 4.44, "log_R" : 0, "log_L" : 0}

arcturus_params = {"star_mass" : 1.08, "log_age" : 9.89, "metallicity" : -0.5, "log_Teff" : 3.63, "log_g" : 1.66, "log_R" : 1.39, "log_L" : 2.23}

# %%
def test_second_model(log_age, metallicity, mass, model_B_path, scaler_B_path=None):
    model_B = joblib.load(model_B_path)

    model_B_inputs = [[log_age, metallicity, mass]]
    if scaler_B_path is not None: # apply a scaling to the data if provided
        model_B_scaler = joblib.load(scaler_B_path)
        model_B_inputs = model_B_scaler.transform(model_B_inputs)
    # Predict the effective temperature, surface gravity and radius of the secondary star
    log_Teff2, log_g2, log_R2 = model_B.predict(model_B_inputs).flatten()

    return log_Teff2, log_g2, log_R2

# %% [markdown]
# ## Model testing

# %% [markdown]
# ### KNN

# %%
# age, metallicity, log_Teff, log_g, q, model_A_path, model_B_path

# %%
log_Teff2, log_g2, log_R2 = test_second_model(sun_params["log_age"], sun_params["metallicity"], sun_params["star_mass"], 
                                              pre_path + path_to_final_models_B + "KNN_scale_power_compress_0.pkl",
                                              pre_path + path_to_final_models_B_power_scaler)

# %%
print(f"Known Sun parameters : log_age : {sun_params["log_age"]}, metallicity : {sun_params["metallicity"]}, star_mass : {sun_params["star_mass"]}")
print(f"Predicted Sun parameters : log_teff2 : {log_Teff2}, log_g2 : {log_g2}, log_R2 : {log_R2}")
print(f"Expected Sun parameters : log_teff2 : {sun_params["log_Teff"]}, log_g2 : {sun_params["log_g"]}, log_R2 : {sun_params["log_R"]}")

print()
# Out:
# Known Sun parameters : log_age : 9.65, metallicity : 0, star_mass : 1
# Predicted Sun parameters : log_teff2 : 3.77033, log_g2 : 4.4215, log_R2 : 0.009706236938652739
# Expected Sun parameters : log_teff2 : 3.76, log_g2 : 4.44, log_R2 : 0

# %%
# print(f"Known Sun parameters : log_age : {sun_params["log_age"]}, metallicity : {sun_params["metallicity"]}, star_mass : {sun_params["star_mass"]}")
# print(f"Predicted Sun parameters : log_teff2 : {log_Teff2}, log_g2 : {log_g2}, log_R2 : {log_R2}")
# print(f"Expected Sun parameters : log_teff2 : {sun_params["log_Teff"]}, log_g2 : {sun_params["log_g"]}, log_R2 : {sun_params["log_R"]}")

# print()
# Out:
# Known Sun parameters : log_age : 9.65, metallicity : 0, star_mass : 1
# Predicted Sun parameters : log_teff2 : 3.67808, log_g2 : 2.5466, log_R2 : 0.8953221059444804
# Expected Sun parameters : log_teff2 : 3.76, log_g2 : 4.44, log_R2 : 0

# %%
log_Teff2, log_g2, log_R2 = test_second_model(arcturus_params["log_age"], arcturus_params["metallicity"], arcturus_params["star_mass"], 
                                              pre_path + path_to_final_models_B + "KNN_scale_power_compress_0.pkl",
                                              pre_path + path_to_final_models_B_power_scaler)

# %%
print(f"Known Sun parameters : log_age : {arcturus_params["log_age"]}, metallicity : {arcturus_params["metallicity"]}, star_mass : {arcturus_params["star_mass"]}")
print(f"Predicted Sun parameters : log_teff2 : {log_Teff2}, log_g2 : {log_g2}, log_R2 : {log_R2}")
print(f"Expected Sun parameters : log_teff2 : {arcturus_params["log_Teff"]}, log_g2 : {arcturus_params["log_g"]}, log_R2 : {arcturus_params["log_R"]}")

print()
# Out:
# Known Sun parameters : log_age : 9.89, metallicity : -0.5, star_mass : 1.08
# Predicted Sun parameters : log_teff2 : 3.6808800000000006, log_g2 : 2.4876, log_R2 : 0.9818010457095921
# Expected Sun parameters : log_teff2 : 3.63, log_g2 : 1.66, log_R2 : 1.39

# %%
# print(f"Known Sun parameters : log_age : {arcturus_params["log_age"]}, metallicity : {arcturus_params["metallicity"]}, star_mass : {arcturus_params["star_mass"]}")
# print(f"Predicted Sun parameters : log_teff2 : {log_Teff2}, log_g2 : {log_g2}, log_R2 : {log_R2}")
# print(f"Expected Sun parameters : log_teff2 : {arcturus_params["log_Teff"]}, log_g2 : {arcturus_params["log_g"]}, log_R2 : {arcturus_params["log_R"]}")

# print()
# Out:
# Known Sun parameters : log_age : 9.89, metallicity : -0.5, star_mass : 1.08
# Predicted Sun parameters : log_teff2 : 3.6994599999999993, log_g2 : 2.7065000000000006, log_R2 : 0.8034826599317842
# Expected Sun parameters : log_teff2 : 3.63, log_g2 : 1.66, log_R2 : 1.39

# %% [markdown]
# ### Decision tree

# %%
log_Teff2, log_g2, log_R2 = test_second_model(sun_params["log_age"], sun_params["metallicity"], sun_params["star_mass"], 
                                              pre_path + path_to_final_models_B + "DT_scale_power_compress_0.pkl",
                                              pre_path + path_to_final_models_B_power_scaler)

# %%
print(f"Known Sun parameters : log_age : {sun_params["log_age"]}, metallicity : {sun_params["metallicity"]}, star_mass : {sun_params["star_mass"]}")
print(f"Predicted Sun parameters : log_teff2 : {log_Teff2}, log_g2 : {log_g2}, log_R2 : {log_R2}")
print(f"Expected Sun parameters : log_teff2 : {sun_params["log_Teff"]}, log_g2 : {sun_params["log_g"]}, log_R2 : {sun_params["log_R"]}")

print()
# Out:
# Known Sun parameters : log_age : 9.65, metallicity : 0, star_mass : 1
# Predicted Sun parameters : log_teff2 : 3.775066666666667, log_g2 : 4.4190000000000005, log_R2 : 0.008224059544064834
# Expected Sun parameters : log_teff2 : 3.76, log_g2 : 4.44, log_R2 : 0

# %%
# print(f"Known Sun parameters : log_age : {sun_params["log_age"]}, metallicity : {sun_params["metallicity"]}, star_mass : {sun_params["star_mass"]}")
# print(f"Predicted Sun parameters : log_teff2 : {log_Teff2}, log_g2 : {log_g2}, log_R2 : {log_R2}")
# print(f"Expected Sun parameters : log_teff2 : {sun_params["log_Teff"]}, log_g2 : {sun_params["log_g"]}, log_R2 : {sun_params["log_R"]}")

# print()
# Out:
# Known Sun parameters : log_age : 9.65, metallicity : 0, star_mass : 1
# Predicted Sun parameters : log_teff2 : 3.6920640625000005, log_g2 : 2.354859375, log_R2 : 1.0505276872617415
# Expected Sun parameters : log_teff2 : 3.76, log_g2 : 4.44, log_R2 : 0

# %%
log_Teff2, log_g2, log_R2 = test_second_model(arcturus_params["log_age"], arcturus_params["metallicity"], arcturus_params["star_mass"], 
                                              pre_path + path_to_final_models_B + "DT_scale_power_compress_0.pkl",
                                              pre_path + path_to_final_models_B_power_scaler)

# %%
print(f"Known Sun parameters : log_age : {arcturus_params["log_age"]}, metallicity : {arcturus_params["metallicity"]}, star_mass : {arcturus_params["star_mass"]}")
print(f"Predicted Sun parameters : log_teff2 : {log_Teff2}, log_g2 : {log_g2}, log_R2 : {log_R2}")
print(f"Expected Sun parameters : log_teff2 : {arcturus_params["log_Teff"]}, log_g2 : {arcturus_params["log_g"]}, log_R2 : {arcturus_params["log_R"]}")

print()
# Out:
# Known Sun parameters : log_age : 9.89, metallicity : -0.5, star_mass : 1.08
# Predicted Sun parameters : log_teff2 : 3.6717, log_g2 : 2.9511428571428575, log_R2 : 0.7601213477837584
# Expected Sun parameters : log_teff2 : 3.63, log_g2 : 1.66, log_R2 : 1.39

# %%
# print(f"Known Sun parameters : log_age : {arcturus_params["log_age"]}, metallicity : {arcturus_params["metallicity"]}, star_mass : {arcturus_params["star_mass"]}")
# print(f"Predicted Sun parameters : log_teff2 : {log_Teff2}, log_g2 : {log_g2}, log_R2 : {log_R2}")
# print(f"Expected Sun parameters : log_teff2 : {arcturus_params["log_Teff"]}, log_g2 : {arcturus_params["log_g"]}, log_R2 : {arcturus_params["log_R"]}")

# print()
# Out:
# Known Sun parameters : log_age : 9.89, metallicity : -0.5, star_mass : 1.08
# Predicted Sun parameters : log_teff2 : 3.6920640625, log_g2 : 2.3548593749999998, log_R2 : 1.0505276872617408
# Expected Sun parameters : log_teff2 : 3.63, log_g2 : 1.66, log_R2 : 1.39

# %% [markdown]
# ### Random forest

# %%
log_Teff2, log_g2, log_R2 = test_second_model(sun_params["log_age"], sun_params["metallicity"], sun_params["star_mass"], 
                                              pre_path + path_to_final_models_B + "RF_scale_quantile_compress_3.pkl",
                                              pre_path + path_to_final_models_B_quantile_scaler)

# %%
print(f"Known Sun parameters : log_age : {sun_params["log_age"]}, metallicity : {sun_params["metallicity"]}, star_mass : {sun_params["star_mass"]}")
print(f"Predicted Sun parameters : log_teff2 : {log_Teff2}, log_g2 : {log_g2}, log_R2 : {log_R2}")
print(f"Expected Sun parameters : log_teff2 : {sun_params["log_Teff"]}, log_g2 : {sun_params["log_g"]}, log_R2 : {sun_params["log_R"]}")

print()
# Out:
# Known Sun parameters : log_age : 9.65, metallicity : 0, star_mass : 1
# Predicted Sun parameters : log_teff2 : 3.763709311538986, log_g2 : 4.463297981593953, log_R2 : -0.017135695124152094
# Expected Sun parameters : log_teff2 : 3.76, log_g2 : 4.44, log_R2 : 0

# %%
# print(f"Known Sun parameters : log_age : {sun_params["log_age"]}, metallicity : {sun_params["metallicity"]}, star_mass : {sun_params["star_mass"]}")
# print(f"Predicted Sun parameters : log_teff2 : {log_Teff2}, log_g2 : {log_g2}, log_R2 : {log_R2}")
# print(f"Expected Sun parameters : log_teff2 : {sun_params["log_Teff"]}, log_g2 : {sun_params["log_g"]}, log_R2 : {sun_params["log_R"]}")

# print()
# Out:
# Known Sun parameters : log_age : 9.65, metallicity : 0, star_mass : 1
# Predicted Sun parameters : log_teff2 : 3.692173597510185, log_g2 : 2.388654032047885, log_R2 : 1.0264135676632644
# Expected Sun parameters : log_teff2 : 3.76, log_g2 : 4.44, log_R2 : 0

# %%
log_Teff2, log_g2, log_R2 = test_second_model(arcturus_params["log_age"], arcturus_params["metallicity"], arcturus_params["star_mass"], 
                                              pre_path + path_to_final_models_B + "RF_scale_quantile_compress_3.pkl",
                                              pre_path + path_to_final_models_B_quantile_scaler)

# %%
print(f"Known Sun parameters : log_age : {arcturus_params["log_age"]}, metallicity : {arcturus_params["metallicity"]}, star_mass : {arcturus_params["star_mass"]}")
print(f"Predicted Sun parameters : log_teff2 : {log_Teff2}, log_g2 : {log_g2}, log_R2 : {log_R2}")
print(f"Expected Sun parameters : log_teff2 : {arcturus_params["log_Teff"]}, log_g2 : {arcturus_params["log_g"]}, log_R2 : {arcturus_params["log_R"]}")

print()
# Out:
# Known Sun parameters : log_age : 9.89, metallicity : -0.5, star_mass : 1.08
# Predicted Sun parameters : log_teff2 : 3.651049577769501, log_g2 : 2.172208976402964, log_R2 : 1.150211735624019
# Expected Sun parameters : log_teff2 : 3.63, log_g2 : 1.66, log_R2 : 1.39

# %%
# print(f"Known Sun parameters : log_age : {arcturus_params["log_age"]}, metallicity : {arcturus_params["metallicity"]}, star_mass : {arcturus_params["star_mass"]}")
# print(f"Predicted Sun parameters : log_teff2 : {log_Teff2}, log_g2 : {log_g2}, log_R2 : {log_R2}")
# print(f"Expected Sun parameters : log_teff2 : {arcturus_params["log_Teff"]}, log_g2 : {arcturus_params["log_g"]}, log_R2 : {arcturus_params["log_R"]}")

# print()
# Out:
# Known Sun parameters : log_age : 9.89, metallicity : -0.5, star_mass : 1.08
# Predicted Sun parameters : log_teff2 : 3.692173597510185, log_g2 : 2.3886540320478855, log_R2 : 1.0264135676632644
# Expected Sun parameters : log_teff2 : 3.63, log_g2 : 1.66, log_R2 : 1.39
