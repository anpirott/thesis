# %% [markdown]
# # Results comparison for PARSEC with final models of model A partial

# %%
from ML.utils.utils import *
from physics.Iso_data_handler import Iso_data_handler
from ML.utils.Data_preparator import Data_preparator

# %%
pre_path = "../../../../../../"
path_default = pre_path + "results/model_A_partial/default_models"
path_fine_tuned = pre_path + "results/model_A_partial/fine_tuned_models"
path_final = pre_path + "results/model_A_partial/final_models"

# %% [markdown]
# ## Final model results

# %%
compare_metrics(path_final, value_rounding=3, relative_values=False,
                output_parameters=["mass", "radius"],
                physical_models=["PARSEC"],
                model_names=["decision_tree"],
                data_filters=["scale_quantile"],
                categories=["Global"])
# Out:
# Results for the Global category with a value of 1.0
#                                                                  value range  \
# model         physical_model filter         output_parameter
# decision_tree PARSEC         scale_quantile mass               0.09 - 13.952
#                                             radius            -0.976 - 2.832
#
#                                                               RVE   RMSE  \
# model         physical_model filter         output_parameter
# decision_tree PARSEC         scale_quantile mass              1.0  0.032
#                                             radius            1.0  0.008
#
#                                                                 MAE  MedAE  \
# model         physical_model filter         output_parameter
# decision_tree PARSEC         scale_quantile mass              0.006    0.0
#                                             radius            0.002    0.0
#
#                                                               CORR  MAX_ER  \
# model         physical_model filter         output_parameter
# decision_tree PARSEC         scale_quantile mass               1.0   1.113
#                                             radius             1.0   0.315
#
#                                                                                                     Percentiles  \
# model         physical_model filter         output_parameter
# decision_tree PARSEC         scale_quantile mass                75 : 0.0 / 90 : 0.007 / 95 : 0.032 / 99 : 0.147
#                                             radius            75 : 0.001 / 90 : 0.007 / 95 : 0.016 / 99 : 0.031
#
#                                                                time
# model         physical_model filter         output_parameter
# decision_tree PARSEC         scale_quantile mass              0.691
#                                             radius            0.691

# %%
compare_metrics(path_final, value_rounding=10, relative_values=False,
                output_parameters=["mass", "radius"],
                physical_models=["PARSEC"],
                model_names=["random_forest"],
                data_filters=["Base"],
                categories=["Global"])
# Out:
# Results for the Global category with a value of 1.0
#                                                                        value range  \
# model         physical_model filter output_parameter
# random_forest PARSEC         Base   mass                             0.09 - 13.952
#                                     radius            -0.9763360818 - 2.8319976772
#
#                                                            RVE      RMSE  \
# model         physical_model filter output_parameter
# random_forest PARSEC         Base   mass              0.999961  0.017763
#                                     radius            0.999958  0.003928
#
#                                                            MAE     MedAE  \
# model         physical_model filter output_parameter
# random_forest PARSEC         Base   mass              0.004781  0.000212
#                                     radius            0.001196  0.000207
#
#                                                           CORR    MAX_ER  \
# model         physical_model filter output_parameter
# random_forest PARSEC         Base   mass              0.999981  0.817185
#                                     radius            0.999979  0.143109
#
#                                                                                                     Percentiles  \
# model         physical_model filter output_parameter
# random_forest PARSEC         Base   mass               75 : 0.00179 / 90 : 0.0112 / 95 : 0.02499 / 99 : 0.07841
#                                     radius            75 : 0.00067 / 90 : 0.00294 / 95 : 0.00587 / 99 : 0.01595
#
#                                                            time
# model         physical_model filter output_parameter
# random_forest PARSEC         Base   mass              17.090892
#                                     radius            17.090892
