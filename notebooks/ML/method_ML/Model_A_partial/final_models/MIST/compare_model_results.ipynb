# %% [markdown]
# # Results comparison for MIST with final models of model A partial

# %%
from ML.utils.utils import *
from physics.Iso_data_handler import Iso_data_handler
from ML.utils.Data_preparator import Data_preparator

# %%
pre_path = "../../../../../../"
path_default = pre_path + "results/model_A_partial/default_models"
path_fine_tuned = pre_path + "results/model_A_partial/fine_tuned_models"
path_final = pre_path + "results/model_A_partial/final_models"

# %% [markdown]
# ## Final model results

# %%
compare_metrics(path_final, value_rounding=3, relative_values=False,
                output_parameters=["mass", "radius"],
                physical_models=["MIST"],
                model_names=["KNN"],
                data_filters=["scale_standard_14"],
                categories=["Global"])
# Out:
# Results for the Global category with a value of 1.0
#                                                             value range  RVE  \
# model physical_model filter            output_parameter
# KNN   MIST           scale_standard_14 mass                0.1 - 13.999  1.0
#                                        radius            -0.997 - 3.083  1.0
#
#                                                           RMSE    MAE  MedAE  \
# model physical_model filter            output_parameter
# KNN   MIST           scale_standard_14 mass              0.044  0.015  0.003
#                                        radius            0.005  0.003  0.002
#
#                                                          CORR  MAX_ER  \
# model physical_model filter            output_parameter
# KNN   MIST           scale_standard_14 mass               1.0   1.945
#                                        radius             1.0   0.130
#
# ...

# %%
compare_metrics(path_final, value_rounding=3, relative_values=True,
                output_parameters=["mass", "radius"],
                physical_models=["MIST"],
                model_names=["random_forest"],
                data_filters=["scale_standard_14"],
                categories=["Global"])
# Out:
# Results for the Global category with a value of 1.0
#                                                                     value range  \
# model         physical_model filter            output_parameter
# random_forest MIST           scale_standard_14 mass                0.1 - 13.999
#                                                radius            -0.997 - 3.083
#
#                                                                  RVE    RMSE  \
# model         physical_model filter            output_parameter
# random_forest MIST           scale_standard_14 mass              1.0  0.219%
#                                                radius            1.0  0.099%
#
#                                                                     MAE  \
# model         physical_model filter            output_parameter
# random_forest MIST           scale_standard_14 mass              0.076%
#                                                radius            0.047%
#
# ...
