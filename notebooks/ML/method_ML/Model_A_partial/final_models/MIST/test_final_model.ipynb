# %% [markdown]
# ## Import

# %%
import joblib

# %%
from ML.first_method.first_method import first_method

# %%
pre_path = "../../../../../../"
physical_model = "MIST"
path_to_final_models_A = 'model/final_models/Model_A_partial/MIST/'
path_to_final_models_B = 'model/final_models/Model_B/MIST/'

# %%
# star_mass en masse solaire, log_age en log_10 de l'age en année, metallicity en dex, 
# log_T_eff en log_10 de la température en Kelvin, log_g en log_10 de la gravité en cm/s^2, 
# log_R en log_10 du rayon en rayon solaire, log_L en log_10 de la luminosité en luminosité solaire

sun_params = {"star_mass" : 1, "log_age" : 9.65, "metallicity" : 0, "log_Teff" : 3.76, "log_g" : 4.44, "log_R" : 0, "log_L" : 0}

arcturus_params = {"star_mass" : 1.08, "log_age" : 9.89, "metallicity" : -0.5, "log_Teff" : 3.63, "log_g" : 1.66, "log_R" : 1.39, "log_L" : 2.23}

# %% [markdown]
# ## Model testing

# %% [markdown]
# ### Random forest

# %%
# age, metallicity, log_Teff, log_g, q, model_A_path, model_B_path

# %%
star_mass1, log_R1, log_Teff2, log_g2, log_R2 = first_method(sun_params["log_age"], sun_params["metallicity"], sun_params["log_Teff"], sun_params["log_g"], 1, 
                                                             pre_path + path_to_final_models_A + "RF_500_estimators_compress_3.pkl",
                                                             pre_path + path_to_final_models_B + "KNN_compress_0.pkl")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 star_mass1, log_R1, log_Teff2, log_g2, log_R2 = first_method(sun_params["log_age"], sun_params["metallicity"], sun_params["log_Teff"], sun_params["log_g"], 1,
#       2                                                              pre_path + path_to_final_models_A + "RF_500_estimators_compress_3.pkl",
#       3                                                              pre_path + path_to_final_models_B + "KNN_compress_0.pkl")
#
# File c:\Users\antoi\Code\unif\MA2\thesis\src\ML\first_method\first_method.py:51, in first_method(log_age, metallicity, log_Teff, log_g, q, model_A_path, model_B_path)
#      31 """
#      32 First method to compute Teff, log_g and log_R of a secondary star given the log_age, metallicity, T_eff and log_g of the primary star as well as a mass ratio.
#      33
#    (...)     48     log_R2 (float) : log10 of the radius of the secondary star
#      49 """
#      50 # Load the models
# ---> 51 model_A = joblib.load(model_A_path)
#      52 model_B = joblib.load(model_B_path)
#      53 # TODO dans un deuxième temps, pour les modèles, donner l'erreur associé quand on l'utilise
#      54
#      55 # Predict the mass and radius of the primary star
#
# File c:\Users\antoi\Code\unif\MA2\thesis\.venv\Lib\site-packages\joblib\numpy_pickle.py:749, in load(filename, mmap_mode, ensure_native_byte_order)
#     744                 return load_compatibility(fobj)
#     746             # A memory-mapped array has to be mapped with the endianness
#     747             # it has been written with. Other arrays are coerced to the
#     748             # native endianness of the host system.
# --> 749             obj = _unpickle(
#     750                 fobj,
#     751                 ensure_native_byte_order=ensure_native_byte_order,
#     752                 filename=filename,
#     753                 mmap_mode=validated_mmap_mode,
#     754             )
#     756 return obj
#
# File c:\Users\antoi\Code\unif\MA2\thesis\.venv\Lib\site-packages\joblib\numpy_pickle.py:626, in _unpickle(fobj, ensure_native_byte_order, filename, mmap_mode)
#     624 obj = None
#     625 try:
# --> 626     obj = unpickler.load()
#     627     if unpickler.compat_mode:
#     628         warnings.warn(
#     629             "The file '%s' has been generated with a "
#     630             "joblib version less than 0.10. "
#    (...)    633             stacklevel=3,
#     634         )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\pickle.py:1255, in _Unpickler.load(self)
#    1253             raise EOFError
#    1254         assert isinstance(key, bytes_types)
# -> 1255         dispatch[key[0]](self)
#    1256 except _Stop as stopinst:
#    1257     return stopinst.value
#
# File c:\Users\antoi\Code\unif\MA2\thesis\.venv\Lib\site-packages\joblib\numpy_pickle.py:462, in NumpyUnpickler.load_build(self)
#     460     _array_payload = array_wrapper.read(self)
#     461 else:
# --> 462     _array_payload = array_wrapper.read(self, self.ensure_native_byte_order)
#     464 self.stack.append(_array_payload)
#
# File c:\Users\antoi\Code\unif\MA2\thesis\.venv\Lib\site-packages\joblib\numpy_pickle.py:284, in NumpyArrayWrapper.read(self, unpickler, ensure_native_byte_order)
#     282     array = self.read_mmap(unpickler)
#     283 else:
# --> 284     array = self.read_array(unpickler, ensure_native_byte_order)
#     286 # Manage array subclass case
#     287 if hasattr(array, "__array_prepare__") and self.subclass not in (
#     288     unpickler.np.ndarray,
#     289     unpickler.np.memmap,
#     290 ):
#     291     # We need to reconstruct another subclass
#
# File c:\Users\antoi\Code\unif\MA2\thesis\.venv\Lib\site-packages\joblib\numpy_pickle.py:193, in NumpyArrayWrapper.read_array(self, unpickler, ensure_native_byte_order)
#     184 # This is not a real file. We have to read it the
#     185 # memory-intensive way.
#     186 # crc32 module fails on reads greater than 2 ** 32 bytes,
#    (...)    189 # of the read. In non-chunked case count < max_read_count, so
#     190 # only one read is performed.
#     191 max_read_count = BUFFER_SIZE // min(BUFFER_SIZE, self.dtype.itemsize)
# --> 193 array = unpickler.np.empty(count, dtype=self.dtype)
#     194 for i in range(0, count, max_read_count):
#     195     read_count = min(max_read_count, count - i)
#
# MemoryError: Unable to allocate 10.0 MiB for an array with shape (1313070,) and data type float64

# %%
print(f"Known Sun parameters : log_age : {sun_params["log_age"]}, metallicity : {sun_params["metallicity"]}, log_Teff : {sun_params["log_Teff"]}, log_g : {sun_params["log_g"]}")
print(f"Predicted Sun parameters : star_mass : {star_mass1}, log_R : {log_R1}")
print(f"Expected Sun parameters : star_mass : {sun_params["star_mass"]}, log_R : {sun_params["log_R"]}")

print()
# pas les bonnes valeurs, à relancer au dessus
# Out:
# Known Sun parameters : log_age : 9.65, metallicity : 0, log_Teff : 3.76, log_g : 4.44
# Predicted Sun parameters : star_mass : 0.7022778183365211, log_R : -0.3371989673284035
# Expected Sun parameters : star_mass : 1, log_R : 0

# %%
star_mass1, log_R1, log_Teff2, log_g2, log_R2 = first_method(arcturus_params["log_age"], arcturus_params["metallicity"], arcturus_params["log_Teff"], arcturus_params["log_g"], 1, 
                                                             pre_path + path_to_final_models_A + "RF_500_estimators_compress_3.pkl",
                                                             pre_path + path_to_final_models_B + "KNN_compress_0.pkl")

# %%
print(f"Known arcturus parameters : log_age : {arcturus_params["log_age"]}, metallicity : {arcturus_params["metallicity"]}, log_Teff : {arcturus_params["log_Teff"]}, log_g : {arcturus_params["log_g"]}")
print(f"Predicted arcturus parameters : star_mass : {star_mass1}, log_R : {log_R1}")
print(f"Expected arcturus parameters : star_mass : {arcturus_params["star_mass"]}, log_R : {arcturus_params["log_R"]}")

print()
# Out:
# Known arcturus parameters : log_age : 9.89, metallicity : -0.5, log_Teff : 3.63, log_g : 1.66
# Predicted arcturus parameters : star_mass : 0.4938962878325663, log_R : -0.4309138300074091
# Expected arcturus parameters : star_mass : 1.08, log_R : 1.39

# %% [markdown]
# ### KNN

# %%
star_mass1, log_R1, log_Teff2, log_g2, log_R2 = first_method(sun_params["log_age"], sun_params["metallicity"], sun_params["log_Teff"], sun_params["log_g"], 1, 
                                                             pre_path + path_to_final_models_A + "KNN_compress_0.pkl",
                                                             pre_path + path_to_final_models_B + "KNN_compress_0.pkl")

# %%
print(f"Known Sun parameters : log_age : {sun_params["log_age"]}, metallicity : {sun_params["metallicity"]}, log_Teff : {sun_params["log_Teff"]}, log_g : {sun_params["log_g"]}")
print(f"Predicted Sun parameters : star_mass : {star_mass1}, log_R : {log_R1}")
print(f"Expected Sun parameters : star_mass : {sun_params["star_mass"]}, log_R : {sun_params["log_R"]}")

print()
# Out:
# Known Sun parameters : log_age : 9.65, metallicity : 0, log_Teff : 3.76, log_g : 4.44
# Predicted Sun parameters : star_mass : 0.8295893593762569, log_R : -0.03035923546174113
# Expected Sun parameters : star_mass : 1, log_R : 0

# %%
star_mass1, log_R1, log_Teff2, log_g2, log_R2 = first_method(arcturus_params["log_age"], arcturus_params["metallicity"], arcturus_params["log_Teff"], arcturus_params["log_g"], 1, 
                                                             pre_path + path_to_final_models_A + "KNN_compress_0.pkl",
                                                             pre_path + path_to_final_models_B + "KNN_compress_0.pkl")

# %%
print(f"Known arcturus parameters : log_age : {arcturus_params["log_age"]}, metallicity : {arcturus_params["metallicity"]}, log_Teff : {arcturus_params["log_Teff"]}, log_g : {arcturus_params["log_g"]}")
print(f"Predicted arcturus parameters : star_mass : {star_mass1}, log_R : {log_R1}")
print(f"Expected arcturus parameters : star_mass : {arcturus_params["star_mass"]}, log_R : {arcturus_params["log_R"]}")

print()
# Out:
# Known arcturus parameters : log_age : 9.89, metallicity : -0.5, log_Teff : 3.63, log_g : 1.66
# Predicted arcturus parameters : star_mass : 0.8295893638143893, log_R : -0.03035922984695698
# Expected arcturus parameters : star_mass : 1.08, log_R : 1.39
