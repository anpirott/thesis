# %% [markdown]
# ## Import

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.neural_network import MLPRegressor

# %%
from ML.utils.utils import *
from ML.utils.Data_preparator import Data_preparator
from ML.utils.Model_evaluator import Model_evaluator
from physics.Iso_data_handler import Iso_data_handler
from physics.Data_visualiser import Data_visualiser

# %%
pre_path = "../../../../../../../"
physical_model = "MIST"
path_to_data = pre_path + "data/MIST_v1.2_vvcrit0.0_basic_isos/"
path_to_results = pre_path + "results/model_A/test_models/"
path_to_predictions = pre_path + "predictions/model_A/test_models/"
tag = "test_categories"
output_parameters = ['mass', 'radius']

# %% [markdown]
# ## Data preparation
#
# This notebook contains the results of the model which are trained using all the data from MIST and filtered on the phases

# %%
iso_handler = Iso_data_handler(path_to_data, 
                              ['log10_isochrone_age_yr', 'log_Teff', 'log_g', 'phase', 'metallicity', 'star_mass', 'log_R'], 
                              physical_model, reclassify=True)

iso_df = iso_handler.get_isochrone_dataframe()
# display(iso_df)
# data_visualiser = Data_visualiser(iso_df, physical_model)
# data_visualiser.plot_Kiel([], [0.0])
# Out:
# Reading MIST dataframe from csv file...

# %%
phase_filtered_iso_df = Data_preparator.filter_data(iso_df, {'phase':[0, 2, 3, 4, 5]})
display(phase_filtered_iso_df)
# data_visualiser_phase_filtered = Data_visualiser(phase_filtered_iso_df, physical_model)
# data_visualiser_phase_filtered.plot_Kiel([], [0.0])
# Out:
#          log10_isochrone_age_yr  log_Teff     log_g  phase  metallicity  \
# 0                           5.0  4.494412  4.346972    0.0        -0.25
# 1                           5.0  4.497517  4.345776    0.0        -0.25
# 2                           5.0  4.500556  4.344580    0.0        -0.25
# 3                           5.0  4.504040  4.343050    0.0        -0.25
# 4                           5.0  4.507576  4.341483    0.0        -0.25
# ...                         ...       ...       ...    ...          ...
# 1140739                    10.3  3.425746 -0.551440    5.0         0.50
# 1140740                    10.3  3.426469 -0.560350    5.0         0.50
# 1140741                    10.3  3.427744 -0.566057    5.0         0.50
# 1140742                    10.3  3.429413 -0.569225    5.0         0.50
# 1140743                    10.3  3.431389 -0.569398    5.0         0.50
#
#          star_mass     log_R
# 0        13.584360  0.610679
# 1        13.765512  0.614753
# 2        13.942887  0.618755
# 3        14.591712  0.624670
# 4        15.426062  0.631187
# ...            ...       ...
# 1140739   0.602856  2.384899
# 1140740   0.598549  2.387797
# 1140741   0.594116  2.389036
# 1140742   0.589648  2.388981
# 1140743   0.585631  2.387582
#
# [1140744 rows x 7 columns]

# %%
print_all_uniques(phase_filtered_iso_df)
# Out:
# log10_isochrone_age_yr  : Range : 5.0 - 10.3, Mean : 8.4657, Median : 8.55
#
# log_Teff  : Range : 3.34 - 5.3788, Mean : 3.8298, Median : 3.6739
#
# log_g  : Range : -1.14 - 6.2594, Mean : 2.0665, Median : 2.005
#
# Values in phase column : 0.0, 2.0, 3.0, 4.0, 5.0
#
# Values in metallicity column : -0.25, -0.5, -0.75, -1.0, -1.25, -1.5, -1.75, -2.0, -2.5, -3.0, -3.5, -4.0, 0.0, 0.25, 0.5
#
# star_mass  : Range : 0.1 - 298.5448, Mean : 7.5368, Median : 2.0818
#
# log_R  : Range : -1.0 - 3.1298, Mean : 1.3949, Median : 1.5001

# %%
X_train, X_ivs, y_train, y_ivs, categories_train, categories_ivs = \
    Data_preparator.split_data(phase_filtered_iso_df, x_cols=['log10_isochrone_age_yr', 'log_Teff', 'log_g', 'metallicity'], 
                               y_cols=['star_mass', 'log_R'], categories_cols=['phase'], random_state=12, print_stats=True)
categories_name = ["phase"]

print(X_train.shape, X_ivs.shape)
print(y_train.shape, y_ivs.shape)
print(categories_train.shape, categories_ivs.shape)
# Out:
# Training set statistics:
# Range in train data for the star_mass parameter : 0.0999979840073621 - 298.5447575808816
# Median value in train data for the star_mass parameter: 2.0816081316727946
# Mean value in train data for the star_mass parameter: 7.558407372495925
#
# Range in train data for the log_R parameter : -0.9974747647513328 - 3.129269620812593
# Median value in train data for the log_R parameter: 1.4993114860984695
# Mean value in train data for the log_R parameter: 1.3944707591667809
#
# Testing set statistics:
# Range in test data for the star_mass parameter : 0.0999981896729906 - 296.5221171165397
# Median value in test data for the star_mass parameter: 2.082595606409119
# Mean value in test data for the star_mass parameter: 7.471864103970097
#
# Range in test data for the log_R parameter : -0.9974234436680278 - 3.1297545143214007
# Median value in test data for the log_R parameter: 1.5026448988619927
# Mean value in test data for the log_R parameter: 1.396340263115711
#
# (855558, 4) (285186, 4)
# (855558, 2) (285186, 2)
# (855558, 1) (285186, 1)

# %% [markdown]
# ## Model training

# %% [markdown]
# ### Linear regression

# %%
lr_evaluator = Model_evaluator("linear_regression", path=path_to_results, physical_model=physical_model, output_parameters=output_parameters)

# %%
lr_evaluator.evaluate_Kfold_results(LinearRegression, X_train, y_train, categories_train, categories_name, path_to_predictions, tag, random_state=12, override=False, use_preds=False, save=False, show=False) #, override=False, use_preds=True)
# Out:
# test_categories train data :
# Global_1.0_metrics.csv
# True
# existe
# phase_0.0_metrics.csv
# True
# phase_2.0_metrics.csv
# True
# phase_3.0_metrics.csv
# True
# phase_4.0_metrics.csv
# True
# phase_5.0_metrics.csv
# True
# mass results for the Global category with a value of 1.0
#   value range :  0.0999979840073621 - 298.5447575808816
#   RVE :  0.3333512379514473
#   RMSE :  16.7885674879178
#   MAE :  6.988910313277603
#   MedAE :  2.7343547993562622
#   CORR :  0.5773657750071854
#   MAX_ER :  257.21540163374084
#   Percentiles :
#     75th percentile :  9.185313998759973
#     90th percentile :  15.617280085586943
#     95th percentile :  18.21414883699739
#     99th percentile :  69.78471008063474
#
# radius results for the Global category with a value of 1.0
#   value range :  -0.9974747647513328 - 3.129269620812593
#   RVE :  0.9897611137480969
#   RMSE :  0.09617751115675367
#   MAE :  0.07195174148370423
#   MedAE :  0.05483596363024501
#   CORR :  0.9948673850057176
#   MAX_ER :  0.48899646293087007
#   Percentiles :
#     75th percentile :  0.10008776536594953
#     90th percentile :  0.15489263402054904
#     95th percentile :  0.2013109382576544
#     99th percentile :  0.28425901367673334
#
# mass results for the phase category with a value of 0.0
#   value range :  0.0999979840073621 - 298.5447575808816
#   RVE :  0.27106458392624055
#   RMSE :  22.3791370688482
#   MAE :  13.22023481220837
#   MedAE :  11.59419191229083
#   CORR :  0.5323260018606589
#   MAX_ER :  257.21540163374084
#   Percentiles :
#     75th percentile :  15.840592353455747
#     90th percentile :  18.48622845917761
#     95th percentile :  20.401348548261225
#     99th percentile :  101.05238801083435
#
# radius results for the phase category with a value of 0.0
#   value range :  -0.9974747647513328 - 3.0827540579576227
#   RVE :  0.9655145379641561
#   RMSE :  0.10991897372439777
#   MAE :  0.08656742689857565
#   MedAE :  0.06968407453176642
#   CORR :  0.9826130877462592
#   MAX_ER :  0.48589006867375195
#   Percentiles :
#     75th percentile :  0.12499567172313275
#     90th percentile :  0.1865626482775193
#     95th percentile :  0.21967381619427953
#     99th percentile :  0.26896877996916857
#
# mass results for the phase category with a value of 2.0
#   value range :  0.6538581961218565 - 283.7634895243517
#   RVE :  0.3099241764763535
#   RMSE :  24.837159794826867
#   MAE :  9.79333924012701
#   MedAE :  4.427411878321513
#   CORR :  0.5810701302871768
#   MAX_ER :  248.38959195229725
#   Percentiles :
#     75th percentile :  10.595366819317821
#     90th percentile :  14.561868307901186
#     95th percentile :  25.665881997414044
#     99th percentile :  139.57206423465695
#
# radius results for the phase category with a value of 2.0
#   value range :  0.0909920840275404 - 2.891706235288321
#   RVE :  0.9763386441074037
#   RMSE :  0.09579171718327643
#   MAE :  0.06619487500758411
#   MedAE :  0.04802213202816036
#   CORR :  0.9890040190329744
#   MAX_ER :  0.47973863393032734
#   Percentiles :
#     75th percentile :  0.0902419100776608
#     90th percentile :  0.13388183740686702
#     95th percentile :  0.18808041503087622
#     99th percentile :  0.38332249314588024
#
# mass results for the phase category with a value of 3.0
#   value range :  0.5471115617151523 - 288.814589557117
#   RVE :  0.37274505740616626
#   RMSE :  18.503819508159424
#   MAE :  7.058127577254849
#   MedAE :  2.139862691553013
#   CORR :  0.6300746222360202
#   MAX_ER :  252.06860809312866
#   Percentiles :
#     75th percentile :  7.420954024796466
#     90th percentile :  13.341399436570832
#     95th percentile :  26.10602899294237
#     99th percentile :  85.83517792794129
#
# radius results for the phase category with a value of 3.0
#   value range :  -0.3445863859219699 - 3.129269620812593
#   RVE :  0.9773694317745389
#   RMSE :  0.10707930375483961
#   MAE :  0.07690379625088639
#   MedAE :  0.05534834367131791
#   CORR :  0.9905159277359878
#   MAX_ER :  0.48899646293087007
#   Percentiles :
#     75th percentile :  0.10876089879140155
#     90th percentile :  0.1602247297665247
#     95th percentile :  0.2317767505240047
#     99th percentile :  0.3598930520595844
#
# mass results for the phase category with a value of 4.0
#   value range :  0.6475951144603956 - 102.39310942879668
#   RVE :  0.6389820933903894
#   RMSE :  5.533467142386774
#   MAE :  2.512981445527111
#   MedAE :  1.1985077080229964
#   CORR :  0.8018051094431983
#   MAX_ER :  71.66982786880213
#   Percentiles :
#     75th percentile :  2.374443907001579
#     90th percentile :  6.009655732477767
#     95th percentile :  8.80505062823971
#     99th percentile :  20.401889792331986
#
# radius results for the phase category with a value of 4.0
#   value range :  0.182160977276469 - 3.07966114450144
#   RVE :  0.980655524199676
#   RMSE :  0.10591947228921893
#   MAE :  0.08584755128269107
#   MedAE :  0.07743252559150493
#   CORR :  0.9921835127050896
#   MAX_ER :  0.3961081167349296
#   Percentiles :
#     75th percentile :  0.12161065112859992
#     90th percentile :  0.16482642626137858
#     95th percentile :  0.20531031725086388
#     99th percentile :  0.26825180490441164
#
# mass results for the phase category with a value of 5.0
#   value range :  0.5087345425706472 - 88.34044865035551
#   RVE :  -2.1599958856292525
#   RMSE :  2.288230170110493
#   MAE :  1.7337302014474305
#   MedAE :  1.337091681623431
#   CORR :  0.6559902507655142
#   MAX_ER :  65.56935630164132
#   Percentiles :
#     75th percentile :  2.486776957244919
#     90th percentile :  3.8563221283749822
#     95th percentile :  4.5373786492409796
#     99th percentile :  6.635546036289453
#
# radius results for the phase category with a value of 5.0
#   value range :  0.1720036399281386 - 3.0540038967643097
#   RVE :  0.9301067330774089
#   RMSE :  0.07585327156957622
#   MAE :  0.05713348950343548
#   MedAE :  0.04546498192286785
#   CORR :  0.9678717033050379
#   MAX_ER :  0.3952177861838404
#   Percentiles :
#     75th percentile :  0.0771953103870262
#     90th percentile :  0.11815657793597427
#     95th percentile :  0.15261092172557203
#     99th percentile :  0.24972152908963824

# %%
lr_evaluator.evaluate_Kfold_results(LinearRegression, X_train, y_train, categories_train, categories_name, path_to_predictions, tag, random_state=12, override=False, use_preds=True, save=False, show=True) #, override=False, use_preds=True)
# Out:
# test_categories train data :
# Evaluating predictions...
#
# mass results for the phase category with a value of 0.0
#   value range :  0.0999979840073621 - 298.5447575808816
#   RVE :  0.27106458392624055
#   RMSE :  22.3791370688482
#   MAE :  13.22023481220837
#   MedAE :  11.59419191229083
#   CORR :  0.5323260018606589
#   MAX_ER :  257.21540163374084
#   Percentiles :
#     75th percentile :  15.840592353455747
#     90th percentile :  18.48622845917761
#     95th percentile :  20.401348548261225
#     99th percentile :  101.05238801083435
# mass results for the phase category with a value of 2.0
#   value range :  0.6538581961218565 - 283.7634895243517
#   RVE :  0.3099241764763535
#   RMSE :  24.837159794826867
#   MAE :  9.79333924012701
#   MedAE :  4.427411878321513
#   CORR :  0.5810701302871768
#   MAX_ER :  248.38959195229725
#   Percentiles :
#     75th percentile :  10.595366819317821
#     90th percentile :  14.561868307901186
#     95th percentile :  25.665881997414044
#     99th percentile :  139.57206423465695
# mass results for the phase category with a value of 3.0
#   value range :  0.5471115617151523 - 288.814589557117
#   RVE :  0.37274505740616626
#   RMSE :  18.503819508159424
#   MAE :  7.058127577254849
#   MedAE :  2.139862691553013
#   CORR :  0.6300746222360202
#   MAX_ER :  252.06860809312866
#   Percentiles :
#     75th percentile :  7.420954024796466
#     90th percentile :  13.341399436570832
#     95th percentile :  26.10602899294237
#     99th percentile :  85.83517792794129
# mass results for the phase category with a value of 4.0
#   value range :  0.6475951144603956 - 102.39310942879668
#   RVE :  0.6389820933903894
#   RMSE :  5.533467142386774
#   MAE :  2.512981445527111
#   MedAE :  1.1985077080229964
#   CORR :  0.8018051094431983
#   MAX_ER :  71.66982786880213
#   Percentiles :
#     75th percentile :  2.374443907001579
#     90th percentile :  6.009655732477767
#     95th percentile :  8.80505062823971
#     99th percentile :  20.401889792331986
# mass results for the phase category with a value of 5.0
#   value range :  0.5087345425706472 - 88.34044865035551
#   RVE :  -2.1599958856292525
#   RMSE :  2.288230170110493
#   MAE :  1.7337302014474305
#   MedAE :  1.337091681623431
#   CORR :  0.6559902507655142
#   MAX_ER :  65.56935630164132
#   Percentiles :
#     75th percentile :  2.486776957244919
#     90th percentile :  3.8563221283749822
#     95th percentile :  4.5373786492409796
#     99th percentile :  6.635546036289453
# mass results for the Global category with a value of 1.0
#   value range :  0.0999979840073621 - 298.5447575808816
#   RVE :  0.3333512379514473
#   RMSE :  16.7885674879178
#   MAE :  6.988910313277603
#   MedAE :  2.7343547993562622
#   CORR :  0.5773657750071854
#   MAX_ER :  257.21540163374084
#   Percentiles :
#     75th percentile :  9.185313998759973
#     90th percentile :  15.617280085586943
#     95th percentile :  18.21414883699739
#     99th percentile :  69.78471008063474
# radius results for the phase category with a value of 0.0
#   value range :  -0.9974747647513328 - 3.0827540579576227
#   RVE :  0.9655145379641561
#   RMSE :  0.10991897372439777
#   MAE :  0.08656742689857565
#   MedAE :  0.06968407453176642
#   CORR :  0.9826130877462592
#   MAX_ER :  0.48589006867375195
#   Percentiles :
#     75th percentile :  0.12499567172313275
#     90th percentile :  0.1865626482775193
#     95th percentile :  0.21967381619427953
#     99th percentile :  0.26896877996916857
# radius results for the phase category with a value of 2.0
#   value range :  0.0909920840275404 - 2.891706235288321
#   RVE :  0.9763386441074037
#   RMSE :  0.09579171718327643
#   MAE :  0.06619487500758411
#   MedAE :  0.04802213202816036
#   CORR :  0.9890040190329744
#   MAX_ER :  0.47973863393032734
#   Percentiles :
#     75th percentile :  0.0902419100776608
#     90th percentile :  0.13388183740686702
#     95th percentile :  0.18808041503087622
#     99th percentile :  0.38332249314588024
# radius results for the phase category with a value of 3.0
#   value range :  -0.3445863859219699 - 3.129269620812593
#   RVE :  0.9773694317745389
#   RMSE :  0.10707930375483961
#   MAE :  0.07690379625088639
#   MedAE :  0.05534834367131791
#   CORR :  0.9905159277359878
#   MAX_ER :  0.48899646293087007
#   Percentiles :
#     75th percentile :  0.10876089879140155
#     90th percentile :  0.1602247297665247
#     95th percentile :  0.2317767505240047
#     99th percentile :  0.3598930520595844
# radius results for the phase category with a value of 4.0
#   value range :  0.182160977276469 - 3.07966114450144
#   RVE :  0.980655524199676
#   RMSE :  0.10591947228921893
#   MAE :  0.08584755128269107
#   MedAE :  0.07743252559150493
#   CORR :  0.9921835127050896
#   MAX_ER :  0.3961081167349296
#   Percentiles :
#     75th percentile :  0.12161065112859992
#     90th percentile :  0.16482642626137858
#     95th percentile :  0.20531031725086388
#     99th percentile :  0.26825180490441164
# radius results for the phase category with a value of 5.0
#   value range :  0.1720036399281386 - 3.0540038967643097
#   RVE :  0.9301067330774089
#   RMSE :  0.07585327156957622
#   MAE :  0.05713348950343548
#   MedAE :  0.04546498192286785
#   CORR :  0.9678717033050379
#   MAX_ER :  0.3952177861838404
#   Percentiles :
#     75th percentile :  0.0771953103870262
#     90th percentile :  0.11815657793597427
#     95th percentile :  0.15261092172557203
#     99th percentile :  0.24972152908963824
# radius results for the Global category with a value of 1.0
#   value range :  -0.9974747647513328 - 3.129269620812593
#   RVE :  0.9897611137480969
#   RMSE :  0.09617751115675367
#   MAE :  0.07195174148370423
#   MedAE :  0.05483596363024501
#   CORR :  0.9948673850057176
#   MAX_ER :  0.48899646293087007
#   Percentiles :
#     75th percentile :  0.10008776536594953
#     90th percentile :  0.15489263402054904
#     95th percentile :  0.2013109382576544
#     99th percentile :  0.28425901367673334
