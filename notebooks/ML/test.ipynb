# %%
from ML.utils.utils import *

# %%
compare_metrics(r"C:\Users\antoi\Code\unif\MA2\thesis\results\K_fold", 
                ["KNN"], 
                ["MIST"], 
                ["Base", "phase_filtered"], 
                ["mass", "radius"])
# Out:
#                                                                      RVE  \
# model physical_model filter         output_parameter
# KNN   MIST           Base           mass              0.9904012013411723
#                                     radius             0.999833901666557
#                      phase_filtered mass              0.9895916504979603
#                                     radius            0.9998970891526346
#
#                                                                       RMSE  \
# model physical_model filter         output_parameter
# KNN   MIST           Base           mass                 2.014748025450398
#                                     radius            0.012250269140419087
#                      phase_filtered mass                 2.725540200848424
#                                     radius            0.007487659862369321
#
#                                                                        MAE  \
# ...
