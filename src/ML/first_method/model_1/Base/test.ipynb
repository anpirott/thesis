# %%
import sys, os
print(sys.executable)
print(sys.path) # TODO régler le problème de path
print("In module products sys.path[0], __package__ ==", sys.path[0], __package__) # TODO régler le problème de path
# Out:
# c:\Users\antoi\AppData\Local\Programs\Python\Python312\python.exe
# ['c:\\Users\\antoi\\Code\\unif\\MA2\\Thèse\\src\\ML\\first_method\\model_1\\Base', 'c:\\Users\\antoi\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'c:\\Users\\antoi\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'c:\\Users\\antoi\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'c:\\Users\\antoi\\AppData\\Local\\Programs\\Python\\Python312', '', 'c:\\Users\\antoi\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages', 'c:\\Users\\antoi\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\win32', 'c:\\Users\\antoi\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\antoi\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\Pythonwin']
# In module products sys.path[0], __package__ == c:\Users\antoi\Code\unif\MA2\Thèse\src\ML\first_method\model_1\Base None

# %%
import os
print(os.getcwd())
os.chdir(r"c:\Users\antoi\Code\unif\MA2\Thèse") 
print(os.getcwd())
# Out:
# c:\Users\antoi\Code\unif\MA2\Thèse
# c:\Users\antoi\Code\unif\MA2\Thèse

# %%
print(os.listdir("."))
print(os.listdir("./src"))
# Out:
# ['.git', '.gitignore', '.ipynb_checkpoints', 'data', 'img', 'model', 'predictions', 'results', 'src', 'Thèse.code-workspace', '__init__.py', '__pycache__']
# ['ML', 'physics', '__init__.py', '__pycache__']

# %%
from src.ML.utils.utils import *
from src.ML.utils.Iso_data_handler import Iso_data_handler
from src.ML.utils.Data_preparator import Data_preparator
from src.ML.utils.Model_trainer import Model_trainer
from src.ML.utils.Model_evaluator import Model_evaluator
